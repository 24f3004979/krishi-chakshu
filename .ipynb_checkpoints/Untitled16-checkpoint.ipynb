# %%
# Install kagglehub if not already installed
# %pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /usr/local/lib/python3.12/dist-packages (from kagglehub) (0.1.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub) (26.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (5.29.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2026.4.22)

# %%
import kagglehub
import os

# Download the latest version of the dataset
dataset_path = kagglehub.dataset_download("vipoooool/new-plant-diseases-dataset")

print(f"Path to dataset files: {dataset_path}")

# List the contents of the downloaded dataset directory
print("Contents of the downloaded dataset:")
for root, dirs, files in os.walk(dataset_path):
    level = root.replace(dataset_path, '').count(os.sep)
    indent = ' ' * 4 * (level)
    print(f'{indent}{os.path.basename(root)}/')
    subindent = ' ' * 4 * (level + 1)
    for f in files:
        print(f'{subindent}{f}')
# Out:
# Downloading to /root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/2.archive...
# 100%|██████████| 2.70G/2.70G [00:23<00:00, 123MB/s]
# Extracting files...
# Streaming output truncated to the last 5000 lines.
#                     2ddd4ad3-221e-4400-a188-0c5ae7a18403___JR_HL 8154_180deg.JPG
#                     458e551e-4674-4f35-8d75-8c5de29b35b9___JR_HL 5999.JPG
#                     abc2d827-8c14-4a55-90d0-101d05624c5d___JR_HL 7839.JPG
#                     3c02c8e5-b648-40ad-b119-0d9f66fc2b6c___JR_HL 8146_new30degFlipLR.JPG
#                     6ab630ac-c705-4aa8-82ec-1b618cc400f4___JR_HL 8257.JPG
#                     5eb3b605-abc6-472a-a8bb-11c6533f2306___JR_HL 7840.JPG
#                     f2833b90-ad7d-4bd8-bb88-9f97d0517c98___JR_HL 8325.JPG
#                     fd4cbc98-dde3-45ce-b794-f6b037eed2b9___JR_HL 7606.JPG
#                     f7b9603d-96a2-4689-b86b-a1e1a53322f1___JR_HL 8385.JPG
#                     06f73502-5694-494a-b3cd-d4bf7bf75172___JR_HL 7692.JPG
#                     3b0f8dbb-905b-4bdc-b4c6-231a22a47287___JR_HL 7610_180deg.JPG
#                     caf87fb1-fb9e-46f1-9b25-a1586f502886___JR_HL 7989.JPG
#                     9d370ceb-40c7-4160-af0f-c8b748d1d250___JR_HL 8741.JPG
#                     7ed4a087-3cef-4012-8450-18c0487362da___JR_HL 8434.JPG
#                     ff5d7b23-41d6-43ff-8bf5-d7ddf13a412b___JR_HL 8675.JPG
#                     1a629a1c-1000-48ce-a7d8-2064aa7e24ae___JR_HL 6001_flipTB.JPG
#                     4ce9b335-f4f7-4637-8317-16e010700ed6___JR_HL 8727_new30degFlipLR.JPG
#                     193e6efe-152b-41ed-b77f-4b9268342162___JR_HL 8341.JPG
#                     5d306c3a-6006-4508-b575-f3f6b83859e7___JR_HL 7677_flipTB.JPG
#                     a87fefe4-6f62-46e2-90b9-273ba9997ed1___JR_HL 8292.JPG
#                     47299b1d-0dbc-4ecd-80c3-3c0561ad48d3___JR_HL 8889.JPG
#                     5e1b5fa9-892b-4e60-91f9-4647d6d9574c___JR_HL 7633_flipTB.JPG
#                     9178dc46-0a7b-460a-9f22-094275a54b5e___JR_HL 5861.JPG
#                     8568ef1d-e8b7-4a15-b0cf-39800013e611___JR_HL 5840.JPG
#                     d670dc7a-8f79-477b-8cb3-170466f71667___JR_HL 8848.JPG
#                     5eb3b605-abc6-472a-a8bb-11c6533f2306___JR_HL 7840_180deg.JPG
#                     0e69c47d-72c6-4fc6-9437-910c95b183dc___JR_HL 8113_new30degFlipLR.JPG
#                     ffd8d1a7-1596-4c8a-bd05-1e284b8cfaa5___JR_HL 8266.JPG
#                     f42a7c9b-92e0-461b-b470-463a6f0b7aff___JR_HL 8747.JPG
#                     3e2945ba-7e94-4faa-9877-5133350e8733___JR_HL 7640.JPG
#                     206fc5a6-80c8-4e7f-8673-2a80b4593b76___JR_HL 8170.JPG
#                     00100ffa-095e-4881-aebf-61fe5af7226e___JR_HL 7886.JPG
#                     1dd1b153-8ded-439f-8c9e-c9970c67e642___JR_HL 8163_flipTB.JPG
#                     9cba3cb9-ae33-4809-b502-aa0611885127___JR_HL 8780.JPG
#                     94a7acd4-cd80-4d84-a837-0702cb946d52___JR_HL 8795.JPG
#                     cddc5f8d-749e-42d7-a453-cf9a9bc24992___JR_HL 8256.JPG
#                     0b796b7a-dfc8-47f7-9970-8373263c6408___JR_HL 5948_180deg.JPG
#                     7a6e3db8-ff01-4fb8-888c-0bda136900c6___JR_HL 8835.JPG
#                     0c002246-262c-46d7-9995-bd1e1b2737d9___JR_HL 7969_180deg.JPG
#                     d2fed0c2-a307-4390-b7a8-47fabfcf3590___JR_HL 8296.JPG
#                     5fb4892e-0745-4492-b26c-74508c60cb28___JR_HL 7973_180deg.JPG
#                     4cdfdfb8-1efa-4a4f-af25-1e968c3aa38c___JR_HL 7607_new30degFlipLR.JPG
#                     0bb97c36-159d-4ee2-8b06-1fbf3f533af5___JR_HL 8345_newPixel25.JPG
#                     6506ee29-4743-4023-a584-17c40b4e45a0___JR_HL 7827.JPG
#                     b7d4bf27-7ed1-4ba3-9b4b-8c9a8f19c4ee___JR_HL 8653.JPG
#                     2c8d77dd-0173-41d0-9e95-9e11092af9a8___JR_HL 8737_newPixel25.JPG
#                     f3e7e5bc-bcdc-4dc8-a6cf-86a42df59c7f___JR_HL 7799.JPG
#                     e0d0a755-6ed0-4cf1-b35d-87547f87a17a___JR_HL 8565.JPG
#                     a92580d4-0c78-42d8-9808-a0d698b12c50___JR_HL 8698.JPG
#                     f9ac8fd3-552c-4ae4-a71a-8fe295c3d118___JR_HL 8891.JPG
#                     002f87b7-e1a5-49e5-a422-bb423630ded5___JR_HL 8068.JPG
#                     0fbb1d8d-63ff-406f-9abe-d555e4fb2de9___JR_HL 5877_flipTB.JPG
#                     5e1b5fa9-892b-4e60-91f9-4647d6d9574c___JR_HL 7633_newPixel25.JPG
#                     d97b0635-c850-4406-b2d0-3217511b496c___JR_HL 8719.JPG
#                     3355f3b6-7d93-4409-9e6f-6344b660e70f___JR_HL 8349.JPG
#                     5ee3b3d6-51d7-4106-a7be-c194dd0b762a___JR_HL 7656_180deg.JPG
#                     5ff1097d-5e9e-40bc-8987-ccf15d465d77___JR_HL 8081_newPixel25.JPG
#                     ec363e4b-79c9-460a-a6a4-cac25a71d6ba___JR_HL 8478.JPG
#                     ebf34e5a-adb5-4cef-b916-793f09b7314b___JR_HL 8171.JPG
#                     7da94264-f28b-4db8-8476-6fb2a0961e39___JR_HL 8427.JPG
#                     13e593a4-59cf-4271-be0e-e2761634015d___JR_HL 8414.JPG
#                     0dd09705-5593-4d01-9a9b-c1d5857daf92___JR_HL 8212_newPixel25.JPG
#                     47c2ad4e-4eca-4597-9784-c3d99444bf29___JR_HL 8450.JPG
#                     0de13a24-e542-45a2-be5a-8db7d8d858db___JR_HL 5982_new30degFlipLR.JPG
#                     2c8dc060-822b-4027-afb0-ed2284ff471b___JR_HL 8800_newPixel25.JPG
#                     0d4f19fe-9e85-4689-9c99-0b01a58db9f4___JR_HL 8032_newPixel25.JPG
#                     4dae1983-04d3-44f9-a226-e94f256677e0___JR_HL 8355_flipTB.JPG
#                     da3feeb4-b339-4f86-82fd-ad83ac6636be___JR_HL 8493.JPG
#                     338ebacf-1cf2-48e7-a69a-708b37f4210b___JR_HL 8821.JPG
#                     1a93f310-cd75-4af6-96d3-690180b4542a___JR_HL 5850_flipTB.JPG
#                     084a1485-7006-4277-bd4f-5b9e766cfd24___JR_HL 7892.JPG
#                     5d5bbf38-ae12-4229-b6cb-54f0d2583628___JR_HL 8797_180deg.JPG
#                     fb6f5d31-176f-4694-9178-0732fb1efcf5___JR_HL 5868.JPG
#                     8de02bb2-f5ca-478b-b6c6-b488c329da35___JR_HL 7942.JPG
#                     f064af9b-a2db-499b-9731-a4078a10bf6a___JR_HL 8898.JPG
#                     4d525b16-48dc-40af-9721-024f002d5929___JR_HL 5970.JPG
#                     7298eb6a-8db7-40dc-9256-aca7772c02af___JR_HL 8739.JPG
#                     7b3b16d2-e0d2-4c91-acc1-3778b3b99ea9___JR_HL 8095.JPG
#                     5bf67b4a-9506-4696-888e-d607a10d7cfb___JR_HL 8506_new30degFlipLR.JPG
#                     ed98eb62-1955-4542-8850-ff2865c3d521___JR_HL 7940.JPG
#                     5a204a79-b860-4364-a3c3-df8f67751eb8___JR_HL 8748_new30degFlipLR.JPG
#                     4b305da8-ccc7-4c6c-938c-cef12420aaab___JR_HL 5954_180deg.JPG
#                     06ae69f3-53f7-4ad8-b6b0-185dd26b2fc0___JR_HL 7971.JPG
#                     1daf2391-f049-4e01-b229-ffd7c00a1b73___JR_HL 8119_new30degFlipLR.JPG
#                     d21298a3-abb3-44b3-bcc9-43aadf320d22___JR_HL 5990.JPG
#                     79fb9f7d-f4e1-4e0e-9968-b2e3ab9f8953___JR_HL 8409.JPG
#                     ad1303c4-8c71-484d-aa80-2f43e8cce03d___JR_HL 8207.JPG
#                     0371d114-2c42-40c5-b2cd-acf2072520e2___JR_HL 7914.JPG
#                     0d4f19fe-9e85-4689-9c99-0b01a58db9f4___JR_HL 8032_new30degFlipLR.JPG
#                     2b7b288c-141a-495f-9df0-3199a2815c9a___JR_HL 8731_180deg.JPG
#                     bcc57d25-c93c-4fa1-8df7-bdb4ae717233___JR_HL 8259.JPG
#                     1c665f14-938a-4563-8613-031a2cb04453___JR_HL 5815_180deg.JPG
#                     a029b826-1974-448d-b4f5-6a2edb66f0a3___JR_HL 7792.JPG
#                     6a6a7f87-4efb-43c7-ae36-1f9db31246f2___JR_HL 7703.JPG
#                     707da75e-4924-4033-b141-e8a391f39741___JR_HL 5853.JPG
#                     6beaecfa-1194-470b-9004-fe2eaf8df406___JR_HL 5923_flipTB.JPG
#                     1b71a13e-9f6d-4321-be6e-8a7410b76f0e___JR_HL 7724_flipTB.JPG
#                     1b2c7e1e-2f0a-4e74-9932-d26118020ffc___JR_HL 8590_newPixel25.JPG
#                     0a3f2927-4410-46a3-bfda-5f4769a5aaf8___JR_HL 8275_180deg.JPG
#                     5f95cd89-5dfd-4b90-8f3a-7aa5a18020fa___JR_HL 8006_flipTB.JPG
#                     01d03cb9-4505-458c-a6dc-648dedccd71a___JR_HL 8474_180deg.JPG
#                     05f73b75-e898-4752-9c9b-ae745994eb01___JR_HL 8801_newPixel25.JPG
#                     13da19c9-4e58-4315-8607-1bf0e33a0cb7___JR_HL 8104.JPG
#                     5cad2f55-2c15-4b55-b148-abac485b6757___JR_HL 8052_180deg.JPG
#                     5f4577b0-b161-4839-8556-cdbd49303e30___JR_HL 5941_new30degFlipLR.JPG
#                     70ca0253-15fc-4525-8a78-65c813bd2992___JR_HL 7807.JPG
#                     1a629a1c-1000-48ce-a7d8-2064aa7e24ae___JR_HL 6001_newPixel25.JPG
#                     c225f3a3-270a-4ae9-a44d-b35c12db7e46___JR_HL 8110.JPG
#                     31394cd0-c576-4d84-9318-63e7a4ee4170___JR_HL 8640.JPG
#                     8e6e9efb-4150-491b-a60e-bee4024d6791___JR_HL 5919.JPG
#                     1b2c7e1e-2f0a-4e74-9932-d26118020ffc___JR_HL 8590_new30degFlipLR.JPG
#                     2f2aa4d8-cb43-4745-8cac-7560829ba950___JR_HL 8020.JPG
#                     126ffc98-0b54-4c66-a827-8bd4b7153259___JR_HL 7833.JPG
#                     0eeb924f-88db-44e6-a278-e016fa2d25a4___JR_HL 8016_flipTB.JPG
#                     ce09803f-c791-4ace-a81f-65ad4730822a___JR_HL 5901.JPG
#                     d15d99e1-1f77-4c74-ae6a-4db663e00f39___JR_HL 5959.JPG
#                     18cf27f2-1bd9-46b6-bcc4-98ff09ee37c1___JR_HL 8671.JPG
#                     0ade14b6-8937-43ea-93eb-98343af6bae7___JR_HL 8026_newPixel25.JPG
#                     5e276091-f62f-4eb4-9ba4-21e8892d2175___JR_HL 8101.JPG
#                     cc230c78-9e6a-467e-a5e4-19c64e82488a___JR_HL 8717.JPG
#                     74757941-c844-4b45-9eb5-b8cf04cb779d___JR_HL 5842.JPG
#                     573a1adf-4134-43f4-919c-939c0bb9a8da___JR_HL 7847.JPG
#                     32c5b4b4-9380-4ea6-90fb-099e569c7390___JR_HL 8413.JPG
#                     3e26a2d8-a7f6-4d3f-bcb7-63ab63b0ff39___JR_HL 8043_new30degFlipLR.JPG
#                     3bf6ef5b-f492-4aee-ae35-bd5a0260fdaf___JR_HL 7988.JPG
#                     81b24c43-b33a-4271-bd32-9457982b02ee___JR_HL 7965.JPG
#                     36e6c861-dfbe-4452-bb94-be96ad479290___JR_HL 8086.JPG
#                     3bcf009f-b16c-4b7e-83e0-d0859bb10dde___JR_HL 8408_flipTB.JPG
#                     9a528ba1-d798-4eef-9d1f-5b09485879c6___JR_HL 8626.JPG
#                     a4c24951-a967-469c-8d14-0d2dc25cfc9d___JR_HL 5821.JPG
#                     3b5f6152-09c6-4458-8e7a-fb0b1ff43ee8___JR_HL 5851_new30degFlipLR.JPG
#                     2d5f93aa-ee53-49eb-ac82-cd0d4b9359c6___JR_HL 8481.JPG
#                     4ebbed7f-321d-45e8-839e-b1af56445be5___JR_HL 6007_newPixel25.JPG
#                     af86218b-d013-4cf3-93ac-d4d57b769f84___JR_HL 8440.JPG
#                     5c7dc582-9234-4b2b-88d8-0ece8dd19a80___JR_HL 8585_180deg.JPG
#                     4e9af7bf-96f5-4973-8470-0db94ef8e375___JR_HL 7896_flipTB.JPG
#                     f2cf1271-b257-452e-8c4f-1db1ff8babd5___JR_HL 5883.JPG
#                     dbe9b4f1-d676-42fc-abca-8cf6fe58eda7___JR_HL 8516.JPG
#                     f457076f-aab1-496e-a4d8-9fefb1af279a___JR_HL 8754.JPG
#                     6189bc8c-6309-4692-8fa2-efe95f3c27d1___JR_HL 7802.JPG
#                     d44e4a80-d921-4792-8a5f-121c84951a7b___JR_HL 8309.JPG
#                     61e598a1-aaef-48ef-b2d3-773619d25b21___JR_HL 7910.JPG
#                     83825263-0e8f-4e27-a6e2-b432323efe49___JR_HL 7593.JPG
#                     3e75d3f9-4e1b-4f09-94e2-e55a9c4d860e___JR_HL 5978_180deg.JPG
#                     c013ccc6-b716-4945-b256-ca39c5e9a201___JR_HL 8842.JPG
#                     e2895bd7-f8f5-46ea-86b1-d90fe9bc0800___JR_HL 8254.JPG
#                     ca1cc01b-2a40-4d7a-994c-307c8e82e745___JR_HL 8392.JPG
#                     3d9886b0-d3cc-42d2-a41a-ec934b971bc9___JR_HL 8775_newPixel25.JPG
#                     0354e474-d930-4098-97f8-0acee01817ea___JR_HL 7623.JPG
#                     674a896b-ff59-42df-8ffb-1f422c2084aa___JR_HL 8089.JPG
#                     e6184b41-1a46-47f9-bcc7-d9f16859e50d___JR_HL 8208.JPG
#                     02a7d2e5-9169-4856-9683-d4fa9894e012___JR_HL 8002_newPixel25.JPG
#                     8bd3098b-4e5d-49d5-be7e-f32da29c75f0___JR_HL 8125.JPG
#                     efdafba8-8b81-462a-83d6-7b064ed28a4d___JR_HL 8228.JPG
#                     ef91d789-9549-42a6-b48e-7695ccd64a1f___JR_HL 7586.JPG
#                     a4be7277-1e8b-41b5-ab42-0a75aab76a46___JR_HL 8798.JPG
#                     ab429711-fce5-4ae7-a8d0-7a2db40da25d___JR_HL 8014.JPG
#                     b704a626-1cb5-47a8-a8b5-e6df7b2a895d___JR_HL 8096.JPG
#                     3a66348b-a6b7-42ee-9411-9575a4240c6f___JR_HL 8627.JPG
#                     261f9a0f-eccc-41fb-be35-cabed2531059___JR_HL 8722.JPG
#                     4696cbe7-0515-4dbf-a3f6-067d6358816f___JR_HL 8443.JPG
#                     03ab4bf1-bae1-4031-ac4d-14e43a29c397___JR_HL 8013_new30degFlipLR.JPG
#                     38a83def-19c0-4d20-99a7-b1a43d7f929f___JR_HL 5897.JPG
#                     f5e369a3-421e-43b9-ab00-840e7535a5eb___JR_HL 8076.JPG
#                     4d525b16-48dc-40af-9721-024f002d5929___JR_HL 5970_flipTB.JPG
#                     cf507d7d-0635-4123-8988-fcd92ed17d76___JR_HL 7968.JPG
#                     02a7d2e5-9169-4856-9683-d4fa9894e012___JR_HL 8002.JPG
#                     ae016efb-ee4a-457c-8e91-788ddbbdaee4___JR_HL 7715.JPG
#                     1bbdce5c-a65c-4ddc-81b7-6f80e6254734___JR_HL 8387_flipTB.JPG
#                     4eee40c4-029f-49eb-a918-1aeee490ccdf___JR_HL 8401_newPixel25.JPG
#                     d2e09fdd-8ee6-4cd1-8bd4-16124dc16962___JR_HL 7918.JPG
#                     2fa76dae-f2a2-4527-b7c7-3c6f5b74a8e7___JR_HL 8114_new30degFlipLR.JPG
#                     5a6ed509-461a-4ad4-bf52-fe967df0fc09___JR_HL 8598_180deg.JPG
#                     e218ac01-833d-42c9-b0d5-8e2719d8308b___JR_HL 8560.JPG
#                     03138bf7-1441-4df8-88a2-7e71b84f6bf0___JR_HL 5823.JPG
#                     2accd1d7-e6b4-4114-9f8b-11130d583320___JR_HL 8841_180deg.JPG
#                     f2b739b9-a463-4ee1-96bf-b5cfe6acb66d___JR_HL 5844.JPG
#                     3d9886b0-d3cc-42d2-a41a-ec934b971bc9___JR_HL 8775.JPG
#                     0ba474dd-0cfd-4fd2-a58c-8e3d18dbe7c3___JR_HL 8395.JPG
#                     9ae3484d-54c9-431d-ae40-59729ca60af8___JR_HL 8634.JPG
#                     b12059e3-404f-441a-9875-4af81aa3bd63___JR_HL 8570.JPG
#                     2d34f331-50b9-4d90-851c-4b0d2ebc4f31___JR_HL 8724.JPG
#                     b32eec71-c780-4649-af2b-9e233995994f___JR_HL 8513.JPG
#                     0e5d9ac1-4de8-491e-ab95-809850866805___JR_HL 8534_new30degFlipLR.JPG
#                     cad06bac-877d-468b-81f4-2e2a60051352___JR_HL 7592.JPG
#                     985f0d8c-db2c-470c-87a2-5d923bc8da7e___JR_HL 8790.JPG
#                     447aa7fa-b251-4687-a25d-bf314eaf3f7e___JR_HL 8063.JPG
#                     e464db4e-8538-40a8-9012-7a5143bdf693___JR_HL 7882.JPG
#                     433b061f-73ad-430f-9ad8-f6fc4c7577af___JR_HL 7941.JPG
#                     7c6366da-565f-4314-b58d-a5665b6f15af___JR_HL 8112.JPG
#                     1f700218-0a6a-47ad-a7fa-ded709ab4d2a___JR_HL 5930_flipTB.JPG
#                     1dd1b153-8ded-439f-8c9e-c9970c67e642___JR_HL 8163_new30degFlipLR.JPG
#                     eb92da7b-8c89-4353-958c-960fd5917d9f___JR_HL 7900.JPG
#                     fb02614c-dcbd-4e7d-9ec6-ab3c5bf267ad___JR_HL 7626.JPG
#                     927fa6d6-6d56-4035-af12-a915a50d86a2___JR_HL 8445.JPG
#                     939d5042-a50f-4c4e-9f07-74437d88cd85___JR_HL 7883.JPG
#                     c03b9066-4feb-42f2-afa5-05918d7de56e___JR_HL 8167.JPG
#                     4dae1983-04d3-44f9-a226-e94f256677e0___JR_HL 8355_new30degFlipLR.JPG
#                     4b305da8-ccc7-4c6c-938c-cef12420aaab___JR_HL 5954_new30degFlipLR.JPG
#                     dfeb1e66-f94b-4ad4-9ad3-ba50d9ac1a2d___JR_HL 7752.JPG
#                     07f381f7-bc63-4e41-8bcc-6c5954a14c03___JR_HL 8326.JPG
#                     0f56ffda-5d57-4a61-8f7f-37f22a02520a___JR_HL 8589_newPixel25.JPG
#                     f06eae04-68c4-482c-b78c-7213afe6e759___JR_HL 8011.JPG
#                     cec3cfff-3d00-46cf-8a8e-b7438ec7901e___JR_HL 7810.JPG
#                     fbe21117-1f7e-4681-9e8c-e1741c8878dc___JR_HL 7574.JPG
#                     9810e1af-6c21-4297-b835-330674a5f9d8___JR_HL 8609.JPG
#                     0760194c-efdd-4065-babb-a12f3b7881a6___JR_HL 7591.JPG
#                     2492565a-7851-43ab-a1c2-41b3e0117b4a___JR_HL 7701.JPG
#                     0c102dad-d31f-469b-89d1-6fe7bf93708c___JR_HL 7689_180deg.JPG
#                     1c41486f-bb0d-4808-b980-9fa4739f2ad3___JR_HL 8459_newPixel25.JPG
#                     6f566315-ae34-49ad-b00a-be421af17746___JR_HL 8746.JPG
#                     1a1a389d-f186-4481-8a5c-b8c6f864ad7f___JR_HL 8649_new30degFlipLR.JPG
#                     f2eeb551-94e8-4ac2-a5de-4702e6349f42___JR_HL 8761.JPG
#                     6beaecfa-1194-470b-9004-fe2eaf8df406___JR_HL 5923.JPG
#                     bb4b37a6-9666-4a7d-ac49-99bb785d2dc0___JR_HL 7566.JPG
#                     1b574484-60cd-4ae4-83ed-511a5ae07ea8___JR_HL 7849_180deg.JPG
#                     3acd00fb-4abe-4762-8a73-07c909a5883d___JR_HL 7736_new30degFlipLR.JPG
#                     c60a1541-bc20-4ab7-9e14-d2ca5e01e14d___JR_HL 8832.JPG
#                     90e840e0-3b8c-4100-8340-ef0ed67e5972___JR_HL 8367.JPG
#                     8dfad1c7-cec1-4d8d-99c6-e7504965b1f8___JR_HL 8642.JPG
#                     ae44c6d0-d29c-4f66-9960-40a019bbc838___JR_HL 7779.JPG
#                     48704549-8dc8-45f4-ac1f-2cd3cdb2a6d9___JR_HL 8251.JPG
#                     4cff9a88-e36d-4c5a-aa11-9812ef5b063a___JR_HL 5940_newPixel25.JPG
#                     342c87ae-db00-4ba8-9029-a91ba10b4d77___JR_HL 8397.JPG
#                     3bcf009f-b16c-4b7e-83e0-d0859bb10dde___JR_HL 8408.JPG
#                     99fc2c08-25c4-47a6-9e0f-a7b8c4f3e683___JR_HL 7831.JPG
#                     2d71f791-64fd-4f1a-97f6-812780014edd___JR_HL 7653.JPG
#                     b7103e2b-ef67-441b-b462-be6f0513dee0___JR_HL 8452.JPG
#                     5a204a79-b860-4364-a3c3-df8f67751eb8___JR_HL 8748.JPG
#                     ed406606-b59d-4a80-8184-ae8ecfda15af___JR_HL 8618.JPG
#                     5ea0d081-386e-4acf-9986-86112d1993ff___JR_HL 8373_flipTB.JPG
#                     4eee40c4-029f-49eb-a918-1aeee490ccdf___JR_HL 8401_flipTB.JPG
#                     05f73b75-e898-4752-9c9b-ae745994eb01___JR_HL 8801.JPG
#                     6bc90016-1508-43ff-8b1e-c2013f236337___JR_HL 8645.JPG
#                     c6111f5b-213f-4a67-bdda-7bb5af53c637___JR_HL 7637.JPG
#                     3b79de24-6a09-4d8d-a49e-610438a4de32___JR_HL 8606_new30degFlipLR.JPG
#                     3f3b903c-cfeb-4574-8be7-1580296d7c2f___JR_HL 5865_new30degFlipLR.JPG
#                     0e2afa6e-568c-4694-babd-dc15057b53b3___JR_HL 8475_flipTB.JPG
#                     fec718e1-5498-4c71-802a-d4689ebd69cc___JR_HL 8230.JPG
#                     6526a25c-f7ee-42ac-8a8a-d24a0a067218___JR_HL 8161.JPG
#                     02a7d2e5-9169-4856-9683-d4fa9894e012___JR_HL 8002_180deg.JPG
#                     65561d5c-c914-4cd0-90c5-e5bf47c8855b___JR_HL 8371.JPG
#                     7e48d50d-d877-4b5d-9aad-6a451e0ba067___JR_HL 8103.JPG
#                     647d9500-2864-4b98-bbd2-b4ac4b42abbf___JR_HL 7917.JPG
#                     4d5c943b-7c66-4f5d-85e3-d8e2f8c3e096___JR_HL 7727_newPixel25.JPG
#                     7267607f-acf4-40fb-b691-e46ade9b87c9___JR_HL 8758.JPG
#                     2fefe600-7bb1-4edd-86e7-0847c9e0e33c___JR_HL 8750_new30degFlipLR.JPG
#                     0c93ef1a-ccc8-4a62-9353-308e7da3ac3e___JR_HL 8245.JPG
#                     faac0cc4-4c25-4962-9a6d-6203a1b02af3___JR_HL 8415.JPG
#                     3ba0eff1-bb0f-4624-8693-1890087db1d3___JR_HL 8510.JPG
#                     48f5f336-54af-4415-be68-d23b38fcdd42___JR_HL 7631.JPG
#                     3dbd080a-21d0-4fb0-8c31-9638c6030943___JR_HL 5817_new30degFlipLR.JPG
#                     4ebbed7f-321d-45e8-839e-b1af56445be5___JR_HL 6007_new30degFlipLR.JPG
#                     cddaf3ef-06ec-40ac-b3d1-cd7e0c9a129f___JR_HL 8035.JPG
#                     b555e97b-a736-41c1-ab8f-43cadf71ae81___JR_HL 8000.JPG
#                     2b0eaba8-5c38-4eb2-8629-7b967cfd2b20___JR_HL 8062_newPixel25.JPG
#                     2359f487-7e4a-4480-a788-72fbc570afba___JR_HL 7739.JPG
#                     0de13a24-e542-45a2-be5a-8db7d8d858db___JR_HL 5982_newPixel25.JPG
#                     8b1bc870-8cff-476f-b8cb-e17ab5e1e2d7___JR_HL 8845.JPG
#                     8957c413-e9c6-4f8e-a889-43980e565fe2___JR_HL 5950.JPG
#                     a9a683f3-e87f-4cd9-8930-65a8c13b519b___JR_HL 7889.JPG
#                     1bfbdcd9-68ae-4676-9693-5f02fd310860___JR_HL 8715_new30degFlipLR.JPG
#                     3c9d9b2b-23de-48f6-98cf-cedf3d86359b___JR_HL 7599_new30degFlipLR.JPG
#                     4960c513-0f3b-49a0-91f7-e54561f5c1f7___JR_HL 5933.JPG
#                     cebd3420-b698-43d1-a961-aeeb850a130f___JR_HL 8693.JPG
#                     2e28e6a0-2e0b-4284-a9f5-74e5dfac142d___JR_HL 8451_new30degFlipLR.JPG
#                     159d7508-24db-416a-8eb1-22c1cb38edf3___JR_HL 8234.JPG
#                     fa421fcb-ba24-4562-bf15-0ba854194d70___JR_HL 7641.JPG
#                     1bd09026-a26c-46be-b5ec-850a287c6cb5___JR_HL 5972_newPixel25.JPG
#                     cc953a5e-f81b-4224-9690-c38ae63281bb___JR_HL 8579.JPG
#                     03e8ce3f-9bb5-481c-945b-1fa7d5da09e3___JR_HL 7583_newPixel25.JPG
#                     1dcc5be2-abd6-4fb3-8e75-d75b7a123e45___JR_HL 8763_flipTB.JPG
#                     1d9f7d60-de05-420d-b620-63d0d1670b76___JR_HL 8837.JPG
#                     4a4478b6-4d10-4973-b884-548ff3e1b444___JR_HL 8428_flipTB.JPG
#                     4531baee-70c8-4504-82f1-5cb38c857928___JR_HL 8710.JPG
#                     1aa25bab-008c-4114-9832-096d81592dd9___JR_HL 7992_180deg.JPG
#                     2ba359a8-68ff-4f4b-9c8d-10cab127b257___JR_HL 8294_flipTB.JPG
#                     b66d486a-9cc5-448a-8e5d-ff2b6ca718d4___JR_HL 7756.JPG
#                     9a477ad1-c362-4a16-baa0-5282e592f12a___JR_HL 7791.JPG
#                     1dcc5be2-abd6-4fb3-8e75-d75b7a123e45___JR_HL 8763_newPixel25.JPG
#                     5bf67b4a-9506-4696-888e-d607a10d7cfb___JR_HL 8506_180deg.JPG
#                     f298f2b7-b63a-4e66-886e-fc14bb42bff9___JR_HL 7665.JPG
#                     0b76f650-27cf-4b62-b3ad-c97d81e0db0c___JR_HL 8554_newPixel25.JPG
#                     a630dfe7-57e4-4053-9045-5168f8e0a4b3___JR_HL 8044.JPG
#                     4afa2688-a33f-4adf-a0f5-18f9c5e7e848___JR_HL 8714_flipTB.JPG
#                     6e418c92-e6e2-46c9-b1fb-96f3e87c2bb2___JR_HL 8616_180deg.JPG
#                     80351989-5dc7-487b-abcc-3a561ec6e5d8___JR_HL 8774.JPG
#                     10b46a95-02c6-4a1c-98e5-904b3e3e7e0d___JR_HL 7679.JPG
#                     5ee3b3d6-51d7-4106-a7be-c194dd0b762a___JR_HL 7656_newPixel25.JPG
#                     a9a25726-1cd3-4a87-b26a-328f35c3cb05___JR_HL 8725.JPG
#                     fa07a6ab-030d-46dd-bca0-ae32ccdbf5c3___JR_HL 7564.JPG
#                     87a97810-bd20-4f2f-8a20-1953664f8576___JR_HL 7602.JPG
#                     5af94784-1208-4c66-b95d-5743128bde63___JR_HL 7711_180deg.JPG
#                     87c36fb4-0ad9-4386-8324-25e21df2a7d4___JR_HL 8547.JPG
#                     6c88680c-ed4b-45ba-a8d0-90d6ee26d618___JR_HL 7925_newPixel25.JPG
#                     03c966a7-ac9e-4c8e-965a-6c0e7289a0e8___JR_HL 8509_new30degFlipLR.JPG
#                     002f87b7-e1a5-49e5-a422-bb423630ded5___JR_HL 8068_flipTB.JPG
#                     3ede2904-b21a-4b6a-940b-062c21ff71fa___JR_HL 7613.JPG
#                     0eb476b9-8b21-4b24-adef-7db813abbca3___JR_HL 7926_newPixel25.JPG
#                     fc9c2e07-7e01-459e-9725-9c2dd619c14f___JR_HL 8372.JPG
#                     b3025d7b-862b-4ec3-9724-982a12e305e5___JR_HL 7804.JPG
#                     03a4f6f6-9c17-4310-921b-5dbf97df630a___JR_HL 8571_180deg.JPG
#                     3949ee17-d163-4713-bcaa-523e87cd3871___JR_HL 8109.JPG
#                     1bb25702-cb7c-4ff1-9f08-41153553fd58___JR_HL 8364_new30degFlipLR.JPG
#                     eaf12b28-cd51-40f3-9298-532c676eb55f___JR_HL 7688.JPG
#                     0e05c3e0-7766-4049-b7a8-563b5c028c33___JR_HL 8828_flipTB.JPG
#                     8bd3df6b-9344-49ee-8597-776ba6b54317___JR_HL 8404.JPG
#                     e6a3e0cb-e1d4-4440-9440-f0b4f489ecc4___JR_HL 8742.JPG
#                     4d212bb1-b0dc-46cc-b09c-6fa484bdfc36___JR_HL 8380_new30degFlipLR.JPG
#                     28e50a98-883a-418d-bbcb-01b8e44a11b5___JR_HL 8160.JPG
#                     4e6e9475-7cdb-443b-aacf-3e10d937e1a3___JR_HL 8290_180deg.JPG
#                     1f12962f-8c78-44dd-a2fc-fac013a76475___JR_HL 8489.JPG
#                     c6b87f19-e8b4-437c-b0c0-13b3038e55be___JR_HL 8830.JPG
#                     c2f95f90-fac7-42e5-b6dd-789f8f2a50d9___JR_HL 8567.JPG
#                     1bd09026-a26c-46be-b5ec-850a287c6cb5___JR_HL 5972_new30degFlipLR.JPG
#                     d5164fae-b799-4dcd-b66d-1e7643bb0fc3___JR_HL 8215.JPG
#                     51e49986-3954-472f-8504-a95452b0fc88___JR_HL 7666.JPG
#                 Apple___Apple_scab/
#                     023123cb-7b69-4c9f-a521-766d7c8543bb___FREC_Scab 3487.JPG
#                     e893d964-8a40-46f5-b8ae-0a0f0cd79296___FREC_Scab 3333_new30degFlipLR.JPG
#                     fcd4d0fd-30c9-4b05-b0ea-ca74fd3cad72___FREC_Scab 3510.JPG
#                     abd8b296-db97-40c0-af5b-39e03f4dec16___FREC_Scab 3041_270deg.JPG
#                     be076652-b1bd-430c-a752-db525c1dfcfd___FREC_Scab 3367_90deg.JPG
#                     dbf66e2f-cf58-418c-9dcd-14254af3ddb1___FREC_Scab 2934_new30degFlipLR.JPG
#                     058d5e64-2c57-45ba-94cb-ac83fd1885a0___FREC_Scab 3181_270deg.JPG
#                     3f65aa69-06c9-423f-ac7a-e2ab6edf63ca___FREC_Scab 3360.JPG
#                     63a29431-0e93-4e5d-b28d-3956edd10d01___FREC_Scab 3197_90deg.JPG
#                     88079400-60e9-4317-b917-0bee6c8c16f5___FREC_Scab 3411_new30degFlipLR.JPG
#                     7c83792f-d375-42fb-a5a0-1bc2cb3a8eff___FREC_Scab 2914_270deg.JPG
#                     fcb1ce1e-f60c-4a65-bfa4-157009760dad___FREC_Scab 3052_90deg.JPG
#                     8edca1d5-7ab9-47b6-bdd0-b61e4a11621e___FREC_Scab 3512_90deg.JPG
#                     1ceeeee0-40bd-4ac9-8a57-59385bf5df8a___FREC_Scab 3001_new30degFlipLR.JPG
#                     59c9641b-c84e-4595-8f2c-13b5f914aa4a___FREC_Scab 3060.JPG
#                     716a13b6-1747-40d8-96d7-5ec1c183b3b5___FREC_Scab 3004_new30degFlipLR.JPG
#                     9dac36c9-3c32-44be-8752-0f03666cbb76___FREC_Scab 3365.JPG
#                     fd5a96b7-6623-41cc-b34c-3b940ea27286___FREC_Scab 3013.JPG
#                     9431682d-6de3-4b1f-bdde-11b706fe2e85___FREC_Scab 3029_new30degFlipLR.JPG
#                     7c83792f-d375-42fb-a5a0-1bc2cb3a8eff___FREC_Scab 2914_90deg.JPG
#                     b3b884bb-55ff-42dd-81d6-d8260acd4ad5___FREC_Scab 3281_new30degFlipLR.JPG
#                     b84c8919-1f8c-4751-a759-e0ec84839020___FREC_Scab 3264_270deg.JPG
#                     650f4395-7428-404a-b65c-8fd36f204dd6___FREC_Scab 3111_90deg.JPG
#                     afab688d-242c-4e62-abef-ba277df5a76d___FREC_Scab 3188_90deg.JPG
#                     53fe6519-da0a-4183-80d6-a18828a33223___FREC_Scab 3283_270deg.JPG
#                     a93dc267-cd94-49fd-9766-8afe67ba747a___FREC_Scab 3125_90deg.JPG
#                     32550bbb-cdf1-4805-8167-27dc5a8e87d2___FREC_Scab 3195_90deg.JPG
#                     462f0ef8-5460-4f5c-8935-62a204d3fc08___FREC_Scab 2924_90deg.JPG
#                     675f0b56-9d0b-45b3-8c8e-820efae75274___FREC_Scab 3006.JPG
#                     60226bd7-db11-4d7e-ba29-a5136f6bebe0___FREC_Scab 3470.JPG
#                     fb942296-ba33-40e5-ada0-6700365cf71d___FREC_Scab 2919_90deg.JPG
#                     6a61688a-c972-4f8f-b3b7-46fd00264240___FREC_Scab 3271_270deg.JPG
#                     f6144504-015b-426e-a967-0712cf7621e4___FREC_Scab 3420_new30degFlipLR.JPG
#                     8c72c236-8f13-4087-8d1d-f365211563f0___FREC_Scab 3196_90deg.JPG
#                     40d60cf0-1311-40c7-9e7e-579e74c92027___FREC_Scab 3136_new30degFlipLR.JPG
#                     d652b023-0ade-4f34-a490-206a87489e5e___FREC_Scab 3066_90deg.JPG
#                     0537ad56-3d24-4e97-a947-65b9b37f8988___FREC_Scab 3079.JPG
#                     91decba3-10b0-4d3e-974c-bcc7729e867d___FREC_Scab 3527_270deg.JPG
#                     2dd8b8f8-46b0-4bc6-b817-ea7163f4b28b___FREC_Scab 3473.JPG
#                     69a10285-eacb-4c83-b410-18e62bf33ef9___FREC_Scab 2908_270deg.JPG
#                     7ead14ac-9bdd-42a9-bde9-b70d8b6694b7___FREC_Scab 3356.JPG
#                     ef359032-085f-44ba-a63d-493a1724eca4___FREC_Scab 3202_new30degFlipLR.JPG
#                     1d9d67e2-5603-4710-ae2b-6cb0b922ae61___FREC_Scab 3122_270deg.JPG
#                     0896ecbc-1af2-4868-8279-ed302acb29bc___FREC_Scab 3339.JPG
#                     52d5723a-b498-4759-89a1-a7d815689716___FREC_Scab 3034_new30degFlipLR.JPG
#                     d7bdef33-fa84-4240-a931-8a568d62cee7___FREC_Scab 2946_new30degFlipLR.JPG
#                     b8199a66-9ef5-498c-b55d-9a05d67433a5___FREC_Scab 2920.JPG
#                     5d398d0d-256d-4de5-8dcd-f3b455da2b76___FREC_Scab 3522_270deg.JPG
#                     f33a08e5-03bb-4b97-991c-a1332866043d___FREC_Scab 2923_new30degFlipLR.JPG
#                     470bece4-7eb2-4ec1-917a-278559afe463___FREC_Scab 3250_90deg.JPG
#                     d94dd9a8-f2ad-45c4-bf45-3a361f5e2efa___FREC_Scab 3442_270deg.JPG
#                     4abca5eb-2376-4551-be42-25bbb5400fc7___FREC_Scab 3268_90deg.JPG
#                     795c112f-bd6c-4d70-8986-b1c2fb62cbf2___FREC_Scab 3384.JPG
#                     fcb1ce1e-f60c-4a65-bfa4-157009760dad___FREC_Scab 3052.JPG
#                     43712608-0fa2-4be2-91a0-242aca469cb4___FREC_Scab 2985_270deg.JPG
#                     e181fe6a-6865-4ae7-8b3e-0ce6f70ac63b___FREC_Scab 3223_new30degFlipLR.JPG
#                     de6e3dd8-b2b8-4bce-aa4f-83cc514f2007___FREC_Scab 3511_270deg.JPG
#                     0d8d5b80-962d-4381-8d3b-9eca3f2f1bb0___FREC_Scab 3449_new30degFlipLR.JPG
#                     cb36375a-3a30-4d01-8764-358eb6300f16___FREC_Scab 3378_90deg.JPG
#                     258ce9eb-2b67-475b-b09c-0bc83b0987f1___FREC_Scab 3033_270deg.JPG
#                     00075aa8-d81a-4184-8541-b692b78d398a___FREC_Scab 3335_new30degFlipLR.JPG
#                     5893bd90-486f-42cf-9fcd-a4dc1e208246___FREC_Scab 3236_270deg.JPG
#                     4abca5eb-2376-4551-be42-25bbb5400fc7___FREC_Scab 3268_new30degFlipLR.JPG
#                     ced72cdb-0358-420c-abdd-1c94ba303435___FREC_Scab 3217_new30degFlipLR.JPG
#                     7b7c32e3-68f8-4280-acda-4c6e67f4725f___FREC_Scab 3340_90deg.JPG
#                     334f8e1a-5989-476e-88f4-8a45c304e12c___FREC_Scab 3035.JPG
#                     85aad925-f1e2-463e-840b-266d49a56d1f___FREC_Scab 3100_new30degFlipLR.JPG
#                     bc7769cc-805e-42ef-bbcf-0c134ff03276___FREC_Scab 2909_new30degFlipLR.JPG
#                     15bfa086-7d4a-43c0-800d-2fe8255ba50c___FREC_Scab 3150_90deg.JPG
#                     fed05dda-1d4d-4de4-bbf2-517640b3c999___FREC_Scab 3446_new30degFlipLR.JPG
#                     8edca1d5-7ab9-47b6-bdd0-b61e4a11621e___FREC_Scab 3512.JPG
#                     40a5e87c-ee32-4d67-9b28-926e94638a1d___FREC_Scab 3251_90deg.JPG
#                     2c648fcd-d637-4559-beaa-9dd6079646fb___FREC_Scab 3213_90deg.JPG
#                     6e17c808-c071-4eae-befd-bf7e2ed0d9e1___FREC_Scab 3256_90deg.JPG
#                     b4162101-daaa-4e98-bd83-e00f38cf5946___FREC_Scab 2968_new30degFlipLR.JPG
#                     ce7338f4-ed12-4014-8d2f-4b674b672357___FREC_Scab 3532_90deg.JPG
#                     073b509f-c1ea-4e61-881b-2e874c5f4199___FREC_Scab 3286_new30degFlipLR.JPG
#                     7ed79254-3e04-4e08-9c80-088cd9d7d8c9___FREC_Scab 3310_new30degFlipLR.JPG
#                     91decba3-10b0-4d3e-974c-bcc7729e867d___FREC_Scab 3527_new30degFlipLR.JPG
#                     32454154-edbf-464f-8097-e99a3d9a15af___FREC_Scab 2936_270deg.JPG
#                     45ee8aaa-1a08-46ed-8ac8-bba8e40c61d6___FREC_Scab 2986_270deg.JPG
#                     b4b9c80a-f741-416d-a7e6-6d9566ea731e___FREC_Scab 3399.JPG
#                     b10dceaa-a764-46b4-bd61-bc9fb13579ca___FREC_Scab 3141.JPG
#                     64e20068-6685-4a30-a812-fd817117d628___FREC_Scab 3485.JPG
#                     1547f817-6a4d-4cbc-8ce0-7dff293562ee___FREC_Scab 3194_90deg.JPG
#                     dce5b716-54ad-420c-911c-476b838c4be9___FREC_Scab 3045_new30degFlipLR.JPG
#                     8e04135b-2279-43a7-af41-147d96395478___FREC_Scab 3143_90deg.JPG
#                     7bf25c0a-6594-4777-9a67-49a6487bb203___FREC_Scab 2993_new30degFlipLR.JPG
#                     895252c3-5047-4e87-8e13-2cdd765f3e0a___FREC_Scab 3056_90deg.JPG
#                     cd7234b0-3c97-4763-9d16-5a97c87140f7___FREC_Scab 3207_new30degFlipLR.JPG
#                     7897b5dc-7aa6-48b2-8c18-a30fcd6cae94___FREC_Scab 3203_90deg.JPG
#                     376aaef3-8649-43aa-89f8-166bd349a3d3___FREC_Scab 3064_new30degFlipLR.JPG
#                     fb942296-ba33-40e5-ada0-6700365cf71d___FREC_Scab 2919.JPG
#                     f0b1c450-fdbd-402f-9309-e7d5d06bc0e7___FREC_Scab 3210_270deg.JPG
#                     f9e4b1bc-36b0-40df-bb48-4e6ed48ec8b5___FREC_Scab 3514_90deg.JPG
#                     dc12e2fd-e41b-43b5-9874-09661913316e___FREC_Scab 3073_new30degFlipLR.JPG
#                     67f122a8-fb8f-4b8c-bd45-3cf11db238b8___FREC_Scab 3140_new30degFlipLR.JPG
#                     45ee8aaa-1a08-46ed-8ac8-bba8e40c61d6___FREC_Scab 2986_90deg.JPG
#                     84ba6fe9-427e-415b-8bfe-a1f8670e1537___FREC_Scab 3530_270deg.JPG
#                     320dff9e-6d59-4bec-9e7c-930444343e3b___FREC_Scab 3398_270deg.JPG
#                     0b1e31fa-cbc0-41ed-9139-c794e6855e82___FREC_Scab 3089_90deg.JPG
#                     e8f5c962-6f40-443e-9913-5a43b5f2ef07___FREC_Scab 3191_270deg.JPG
#                     4a50158d-dcd0-4a1f-885e-2d9b16a4e344___FREC_Scab 3205_270deg.JPG
#                     c563cf1c-da17-4c03-b3e8-b306334e0270___FREC_Scab 2933_new30degFlipLR.JPG
#                     89937e2f-6ec2-483d-9ba4-1c7c61859cb0___FREC_Scab 3394_270deg.JPG
#                     98e6e72f-092d-41dc-93e1-22bfc1ea2abd___FREC_Scab 2953_new30degFlipLR.JPG
#                     2c7ca7c8-1a6c-4811-b9b0-b054c11a5397___FREC_Scab 3260_90deg.JPG
#                     95c2cc04-5581-48ca-8001-9644bb488b12___FREC_Scab 3163_90deg.JPG
#                     4b4b59d5-3c6d-4ce5-b349-616fecb850ff___FREC_Scab 3447_90deg.JPG
#                     8df36a92-b562-4bff-975b-ff08d8da40f6___FREC_Scab 3119_270deg.JPG
#                     536ce9e9-6c98-42c6-9447-f38073b3e9da___FREC_Scab 3222_270deg.JPG
#                     dfa24368-8ba9-4c02-9c3e-9e9a62a8d479___FREC_Scab 3215_new30degFlipLR.JPG
#                     9474d631-06bc-45e0-bdcc-2aff28b34856___FREC_Scab 3358_new30degFlipLR.JPG
#                     63a29431-0e93-4e5d-b28d-3956edd10d01___FREC_Scab 3197.JPG
#                     f8ef99d9-9d01-4aeb-9248-e8c312c9a981___FREC_Scab 3129_270deg.JPG
#                     db71d62d-b06f-4aa2-a512-d3e5956fcffe___FREC_Scab 3444_270deg.JPG
#                     ba94f188-df0b-41fd-94e3-f0ed4924e23e___FREC_Scab 3102_new30degFlipLR.JPG
#                     9431682d-6de3-4b1f-bdde-11b706fe2e85___FREC_Scab 3029.JPG
#                     e7115dcb-8124-42c9-bf6b-40740173d2ba___FREC_Scab 3353.JPG
#                     5581f206-7305-4430-be5f-8de62689fb70___FREC_Scab 2918_new30degFlipLR.JPG
#                     af82e889-9ec0-437c-85b8-7a6a5caf73a1___FREC_Scab 3338_270deg.JPG
#                     f141c7f9-66b7-4052-b5c7-db3df1a894f2___FREC_Scab 3261_270deg.JPG
#                     b4b9c80a-f741-416d-a7e6-6d9566ea731e___FREC_Scab 3399_new30degFlipLR.JPG
#                     d01086a5-c14e-424a-8825-47343752c0a0___FREC_Scab 3170_90deg.JPG
#                     b8199a66-9ef5-498c-b55d-9a05d67433a5___FREC_Scab 2920_new30degFlipLR.JPG
#                     affb666c-6915-48e6-ba8a-92385af75826___FREC_Scab 3395_270deg.JPG
#                     da09f1db-51a0-4142-855a-7783a3f92114___FREC_Scab 2978_90deg.JPG
#                     98f72edf-a354-43de-8734-a697d8cdd3f5___FREC_Scab 3400.JPG
#                     a5ed05d8-9815-41b7-b481-332e48cfde56___FREC_Scab 3415_270deg.JPG
#                     c270319e-61d4-4376-a3e8-b159ff712dd4___FREC_Scab 3401_270deg.JPG
#                     83dc6270-1c10-4c76-a1a2-6b562fcb4e4c___FREC_Scab 3478_90deg.JPG
#                     b4162101-daaa-4e98-bd83-e00f38cf5946___FREC_Scab 2968_90deg.JPG
#                     eda0a3b5-fe6e-4646-acc6-7db5179e3e96___FREC_Scab 3380.JPG
#                     ed33dbe0-edc4-4ad8-85c2-0495f384e3fe___FREC_Scab 3467.JPG
#                     15bfa086-7d4a-43c0-800d-2fe8255ba50c___FREC_Scab 3150.JPG
#                     ca37bd3e-47ec-415d-8012-81e4efcc6be5___FREC_Scab 2917.JPG
#                     40a5e87c-ee32-4d67-9b28-926e94638a1d___FREC_Scab 3251_new30degFlipLR.JPG
#                     abfd8972-51b1-4715-a358-54e8e2afa071___FREC_Scab 3267.JPG
#                     5dbcba87-93fa-4c21-8abd-bc20c93b359f___FREC_Scab 3258.JPG
#                     06cf74b6-d895-4a09-b3b1-bc63579f8c33___FREC_Scab 3128_90deg.JPG
#                     70fa2c8f-5657-444f-b57b-3ad6755acc74___FREC_Scab 3275_270deg.JPG
#                     f0b1c450-fdbd-402f-9309-e7d5d06bc0e7___FREC_Scab 3210.JPG
#                     64e20068-6685-4a30-a812-fd817117d628___FREC_Scab 3485_90deg.JPG
#                     9100bed7-65dd-4425-840b-503f9db78ef8___FREC_Scab 3076_new30degFlipLR.JPG
#                     06cf74b6-d895-4a09-b3b1-bc63579f8c33___FREC_Scab 3128_270deg.JPG
#                     34c2823b-d1c5-4bd8-a5a7-74bdef959e10___FREC_Scab 3484.JPG
#                     8c72c236-8f13-4087-8d1d-f365211563f0___FREC_Scab 3196_270deg.JPG
#                     9fd8d7c3-3321-49fc-a7dc-165ccc353c78___FREC_Scab 3177_90deg.JPG
#                     9f815013-3c21-403b-80ca-c69cd82d6251___FREC_Scab 2963.JPG
#                     b7740d56-4540-44f5-82c4-3916da0cba20___FREC_Scab 3229_new30degFlipLR.JPG
#                     afc6c0d9-46a0-4275-a2f5-bb241017dbe4___FREC_Scab 3020_270deg.JPG
#                     ba325c11-e91c-4f5e-9ae0-76f8f0bb24df___FREC_Scab 3523_new30degFlipLR.JPG
#                     3652fd23-ba4c-4958-8db8-3aff8f614dfd___FREC_Scab 3377_new30degFlipLR.JPG
#                     9e399a72-a81f-4a43-8542-ebc4e96ba346___FREC_Scab 2930_new30degFlipLR.JPG
#                     84ba6fe9-427e-415b-8bfe-a1f8670e1537___FREC_Scab 3530_new30degFlipLR.JPG
#                     1a41bab0-45e0-4dda-a798-9bf4a998f1b6___FREC_Scab 3450_90deg.JPG
#                     6e17c808-c071-4eae-befd-bf7e2ed0d9e1___FREC_Scab 3256.JPG
#                     09e40e4f-f8bc-4537-b20d-0b244760dbf4___FREC_Scab 3216_new30degFlipLR.JPG
#                     c27b45af-c362-4d37-ab5b-ee197a3670de___FREC_Scab 3521_270deg.JPG
#                     ac3ae45a-aaff-44c0-979d-6a2a8ba50ccf___FREC_Scab 3520_90deg.JPG
#                     8e04135b-2279-43a7-af41-147d96395478___FREC_Scab 3143.JPG
#                     85aad925-f1e2-463e-840b-266d49a56d1f___FREC_Scab 3100.JPG
#                     2a97b29d-8a63-47ab-bd5b-c14832a586c8___FREC_Scab 3242_90deg.JPG
#                     bf9a1cb3-baa2-42f6-881b-c77864b3019c___FREC_Scab 3189.JPG
#                     61373045-a7a5-4213-94fb-7d81638d5561___FREC_Scab 3430_new30degFlipLR.JPG
#                     5d398d0d-256d-4de5-8dcd-f3b455da2b76___FREC_Scab 3522_90deg.JPG
#                     60f3ba82-caf1-4cf7-998c-b0005458fa38___FREC_Scab 3226.JPG
#                     b4dd08e1-926f-41e0-b266-c2f37cea3203___FREC_Scab 3030_90deg.JPG
#                     84e61e7e-f106-442c-a954-63dc3a57d5d5___FREC_Scab 3057_90deg.JPG
#                     5c0af4dd-f185-4fc9-ae2c-a697a235d660___FREC_Scab 2955.JPG
#                     afab688d-242c-4e62-abef-ba277df5a76d___FREC_Scab 3188_270deg.JPG
#                     6a006aa9-a9f2-4269-9fd9-7a879f01faf1___FREC_Scab 3117_90deg.JPG
#                     bdaae6b2-8ff5-4a4c-9286-a2393063cdaf___FREC_Scab 3491_270deg.JPG
#                     fc9c12dc-1bdb-402d-ada8-dc1b33c84d5b___FREC_Scab 2932_new30degFlipLR.JPG
#                     99a971b6-cd13-4ed2-8fc5-0d6769945578___FREC_Scab 3130.JPG
#                     34c37353-8429-499e-bd38-ac7501f79e90___FREC_Scab 3501_270deg.JPG
#                     24d43ad3-24e6-4236-8ef7-59b268520ca3___FREC_Scab 3533.JPG
#                     be23de1a-2db8-4d7f-8b5f-cee56829d49c___FREC_Scab 2991_90deg.JPG
#                     2c89ceaf-748c-4371-80d0-d01855f04a92___FREC_Scab 2962_90deg.JPG
#                     748e82aa-02b1-4ca7-9fd3-e0184f20644f___FREC_Scab 3354.JPG
#                     7ead14ac-9bdd-42a9-bde9-b70d8b6694b7___FREC_Scab 3356_270deg.JPG
#                     63a29431-0e93-4e5d-b28d-3956edd10d01___FREC_Scab 3197_new30degFlipLR.JPG
#                     d08d117d-d394-4e24-83c2-cd7fd96894ce___FREC_Scab 3093_270deg.JPG
#                     86054e9e-26b4-42b5-b192-58ddee7b0c34___FREC_Scab 3011_new30degFlipLR.JPG
#                     495816a8-4d85-47a5-9aca-a09f3f30a068___FREC_Scab 3443_new30degFlipLR.JPG
#                     d730c2c9-ac5f-4c4e-b568-2f3e8b43b1a9___FREC_Scab 3074.JPG
#                     246c33b0-fac8-4cca-ae8b-17947338b8b2___FREC_Scab 3091_90deg.JPG
#                     2a800c84-902e-4aa8-af13-4e020d6f17dd___FREC_Scab 3124.JPG
#                     63cf5c0e-0a65-4261-9034-ba75466ee918___FREC_Scab 3385.JPG
#                     43712608-0fa2-4be2-91a0-242aca469cb4___FREC_Scab 2985_90deg.JPG
#                     6171eecd-e385-4010-b9cd-5982f4674fee___FREC_Scab 2911.JPG
#                     84e61e7e-f106-442c-a954-63dc3a57d5d5___FREC_Scab 3057.JPG
#                     d48c6280-ceec-4b35-bc04-bbbf56995203___FREC_Scab 3262_new30degFlipLR.JPG
#                     4098b029-fcda-4d2f-9703-c16e6e5fae49___FREC_Scab 3455_270deg.JPG
#                     97d9b70c-15fc-4463-a7cd-129e7bccef1c___FREC_Scab 2910_90deg.JPG
#                     0340dc35-5215-48ab-8db7-06af99fcb358___FREC_Scab 2966_90deg.JPG
#                     35694cb9-efe9-441a-a810-13e065de7925___FREC_Scab 3320_new30degFlipLR.JPG
#                     808207df-2000-4050-a720-bd23997710b8___FREC_Scab 3270.JPG
#                     e3891103-ded4-418f-bae1-91c282a30dcb___FREC_Scab 3159_new30degFlipLR.JPG
#                     1f98b949-4df2-45cf-8572-3b4a753be21a___FREC_Scab 2907_90deg.JPG
#                     0b1e31fa-cbc0-41ed-9139-c794e6855e82___FREC_Scab 3089.JPG
#                     f684504f-ca6d-4f06-bb0e-2b296e3829b8___FREC_Scab 3314_new30degFlipLR.JPG
#                     2bc50b52-0d7d-41a3-be8a-8d070341d87f___FREC_Scab 3476_new30degFlipLR.JPG
#                     276ed34e-9987-4b38-b83b-8626504fc204___FREC_Scab 3050_new30degFlipLR.JPG
#                     b963d384-123e-48e5-ac66-a1e87f33ba0b___FREC_Scab 3021_90deg.JPG
#                     cb36375a-3a30-4d01-8764-358eb6300f16___FREC_Scab 3378.JPG
#                     7dbdcba3-395b-413e-bc22-cd0d0e11a1c9___FREC_Scab 3363_90deg.JPG
#                     fcee4ece-01ce-45aa-a0f1-f20aa2ec8efb___FREC_Scab 3325_new30degFlipLR.JPG
#                     76e50482-74b2-468f-8556-7669e1682f1e___FREC_Scab 3323.JPG
#                     ae035eb1-0214-4964-b018-14fca52713fc___FREC_Scab 3166_new30degFlipLR.JPG
#                     a3824376-87d9-464c-b78e-e35d029d43f2___FREC_Scab 3249_270deg.JPG
#                     6b784953-7e31-4cec-a3d5-82f3b6bbdd00___FREC_Scab 3352_new30degFlipLR.JPG
#                     38e76f0a-63cb-460a-b0fa-f20e561dc2c0___FREC_Scab 3481.JPG
#                     9082fc1b-6621-48be-9953-50d3de9a6661___FREC_Scab 3065_90deg.JPG
#                     47ebb7a4-a8e0-4a57-95e5-dd8e9d1235a2___FREC_Scab 3147.JPG
#                     8a8f8dd2-a938-4288-a8ec-56ef0aaa2d4f___FREC_Scab 2947_new30degFlipLR.JPG
#                     2f1e68c0-c059-46fd-bbf3-f160817abdc3___FREC_Scab 3535_270deg.JPG
#                     dc12e2fd-e41b-43b5-9874-09661913316e___FREC_Scab 3073.JPG
#                     2d5265d2-be99-4e9f-a085-d309cc01b751___FREC_Scab 3023.JPG
#                     0a5e9323-dbad-432d-ac58-d291718345d9___FREC_Scab 3417_new30degFlipLR.JPG
#                     cbbdd77b-93f5-4f45-b35d-2b05ab1c8eb4___FREC_Scab 3465.JPG
#                     e3891103-ded4-418f-bae1-91c282a30dcb___FREC_Scab 3159.JPG
#                     3c27bbd7-b305-4ab0-8a85-5061363cf632___FREC_Scab 3183_270deg.JPG
#                     d1745979-75a6-4b00-a544-cf5ba043e7e0___FREC_Scab 3330.JPG
#                     321c7135-853f-444d-9952-a893e660d966___FREC_Scab 2958_new30degFlipLR.JPG
#                     8c916434-af92-4360-9833-0422aa510f7e___FREC_Scab 3245_270deg.JPG
#                     4940cd87-695e-4f4d-8a45-5490812447cc___FREC_Scab 3044_270deg.JPG
#                     d608ac35-eaf8-43e2-b429-f9b433126023___FREC_Scab 3386_270deg.JPG
#                     f9e4b1bc-36b0-40df-bb48-4e6ed48ec8b5___FREC_Scab 3514.JPG
#                     659a6491-b20d-4ff6-a3be-243266b4df0c___FREC_Scab 3155_270deg.JPG
#                     201d8b27-5a38-43e5-8065-f7fe039ad781___FREC_Scab 3058_270deg.JPG
#                     cb36375a-3a30-4d01-8764-358eb6300f16___FREC_Scab 3378_270deg.JPG
#                     7f4d7ebc-7d2b-454f-8f61-b5dc469a16b7___FREC_Scab 3010_90deg.JPG
#                     afab688d-242c-4e62-abef-ba277df5a76d___FREC_Scab 3188_new30degFlipLR.JPG
#                     f27fd3ff-a3b7-486a-883c-f91488883555___FREC_Scab 3158_90deg.JPG
#                     2bc018ba-3c49-4cf4-9411-a93b7b196f45___FREC_Scab 3326.JPG
#                     3dd3d59c-be2a-4f29-8fa1-d4f37d7fb894___FREC_Scab 3412_270deg.JPG
#                     72d9363f-1e23-4154-92bd-5f34a149d444___FREC_Scab 2980_270deg.JPG
#                     8edca1d5-7ab9-47b6-bdd0-b61e4a11621e___FREC_Scab 3512_270deg.JPG
#                     c270319e-61d4-4376-a3e8-b159ff712dd4___FREC_Scab 3401.JPG
#                     66fab3e4-d6e3-4a6d-aff0-4fe011ef8eb3___FREC_Scab 3153.JPG
#                     23466313-6a2c-46e7-ad89-1f95dd2d3b40___FREC_Scab 3517_270deg.JPG
#                     2f1e68c0-c059-46fd-bbf3-f160817abdc3___FREC_Scab 3535_90deg.JPG
#                     eda0a3b5-fe6e-4646-acc6-7db5179e3e96___FREC_Scab 3380_270deg.JPG
#                     4a50158d-dcd0-4a1f-885e-2d9b16a4e344___FREC_Scab 3205_90deg.JPG
#                     453b09e4-6469-47f9-8599-f87e1d6eddf3___FREC_Scab 3048_270deg.JPG
#                     9082fc1b-6621-48be-9953-50d3de9a6661___FREC_Scab 3065.JPG
#                     81c34d6d-e734-4ee7-9645-0f8f80c809c7___FREC_Scab 3276_90deg.JPG
#                     f3b61d33-8875-46a0-be57-ad3bda4cb5c6___FREC_Scab 3243_270deg.JPG
#                     774fb249-80b5-4575-ab5a-5459a9c14ef6___FREC_Scab 3024.JPG
#                     ac61c972-546d-4977-ac4a-085f98bbf206___FREC_Scab 3308_90deg.JPG
#                     f684504f-ca6d-4f06-bb0e-2b296e3829b8___FREC_Scab 3314.JPG
#                     815d2612-ee00-407a-8a0d-d0d94c7e0a9f___FREC_Scab 3461_270deg.JPG
#                     9474d631-06bc-45e0-bdcc-2aff28b34856___FREC_Scab 3358_90deg.JPG
#                     e0bf6219-02d8-4255-88e2-a99afb1ad355___FREC_Scab 3515_new30degFlipLR.JPG
#                     bdaae6b2-8ff5-4a4c-9286-a2393063cdaf___FREC_Scab 3491_new30degFlipLR.JPG
#                     dc12e2fd-e41b-43b5-9874-09661913316e___FREC_Scab 3073_90deg.JPG
#                     44b52928-c5dd-48f4-b2c8-b128032c49dd___FREC_Scab 3518_90deg.JPG
#                     9431682d-6de3-4b1f-bdde-11b706fe2e85___FREC_Scab 3029_270deg.JPG
#                     6b9ef56b-3338-4d2b-a5e4-a1547234e6d6___FREC_Scab 3474.JPG
#                     7e4bbd7a-b494-426f-9f08-755ce4a399e7___FREC_Scab 3331_270deg.JPG
#                     14c623e5-051c-42f6-9e4f-f7a93e6a723c___FREC_Scab 2965_90deg.JPG
#                     d72cdbbd-7982-4198-8bf7-a053ed69bba1___FREC_Scab 3529_90deg.JPG
#                     7c0710e7-2ad4-44c4-a6f6-ffeb5573f8e7___FREC_Scab 3208_90deg.JPG
#                     41c2bb79-44fb-48f4-864f-eec35e3442f5___FREC_Scab 2931_270deg.JPG
#                     c9535536-7e19-474d-9ea2-734d4576e6b7___FREC_Scab 2977.JPG
#                     246c33b0-fac8-4cca-ae8b-17947338b8b2___FREC_Scab 3091_270deg.JPG
#                     0b1e31fa-cbc0-41ed-9139-c794e6855e82___FREC_Scab 3089_270deg.JPG
#                     6823f5d3-b27b-4a34-a417-5fc5bd99f9d7___FREC_Scab 2975_90deg.JPG
#                     bbcecb36-bad4-4aa5-812b-00a402427943___FREC_Scab 3279_90deg.JPG
#                     fb911d9c-0445-4d0f-886e-50458b82d6c2___FREC_Scab 2972_90deg.JPG
#                     75eca8b6-4446-4bf4-9d10-7d38ed44199a___FREC_Scab 3475_270deg.JPG
# ...
#                     82bee6cc-67db-4e6c-a430-30791dfc0c60___R.S_HL 0629 copy_flipLR.jpg
#                     b64f0fd8-4000-4675-81f9-e692a477a3ac___R.S_HL 8067 copy 2.jpg
#                     67f39579-aba1-4989-a9b8-6e85544cf210___R.S_HL 7991 copy.jpg
#                     9202cb6d-a5bd-4cb7-860e-47f7299712ef___R.S_HL 8117 copy 2.jpg
#                     2d04e6d6-acd5-4af9-887c-f76fc8371669___R.S_HL 7959 copy 3.jpg
#                     ac10769f-266b-452e-b8ab-671bd3df69c2___R.S_HL 8344 copy_flipLR.jpg
#                     c26d104a-87bd-4fc0-a94b-5df3a638a3a4___R.S_HL 8039 copy.jpg
#                     fdf1ccaa-1464-4159-bb51-5cf5dfb4b3c9___R.S_HL 7902 copy 2_flipLR.jpg
#                     58f71b31-7e05-4036-985d-ffa20976c668___R.S_HL 8063 copy_flipLR.jpg
#                     16abbd76-6b06-4645-9b18-98ee16e9c067___R.S_HL 8230 copy_flipLR.jpg
#                     9cd620cd-c044-4da1-aa74-7656bd38b68b___R.S_HL 8335 copy 3.jpg
#                     9faacf6a-f638-435a-8994-f1418b332199___R.S_HL 8102 copy 2.jpg
#                     dc1b347c-03b4-468d-9c9a-bebdc467d3c0___R.S_HL 0650 copy_flipLR.jpg
#                     cb08f6cf-4701-475a-b589-d3f486a672a5___R.S_HL 7898 copy.jpg
#                     c7356006-ca58-4bfd-acb1-5ccd6dbf9d4b___R.S_HL 8310 copy 2_flipLR.jpg
#                     8b4dc6b9-d18a-42bf-b417-e2f3da7d3864___R.S_HL 8276 copy.jpg
#                     cba024bb-6180-4f1e-ad79-57b35c035a60___R.S_HL 8237 copy.jpg
#                     bad97c4f-6d48-4637-b496-0d74f579db66___R.S_HL 5549 copy.jpg
#                     3d85d62d-8a88-48eb-85a5-a283c670a453___R.S_HL 7972 copy 2.jpg
#                     02ab8d66-0385-43db-855a-ea5f8811ebd5___R.S_HL 7954 copy.jpg
#                     aa330d9f-d7a0-4bad-8f95-d6e11a1f95bf___R.S_HL 7893 copy_flipLR.jpg
#                     9275afa7-daf0-4052-b092-47d36132e69d___R.S_HL 8189 copy 2_flipLR.jpg
#                     da7362e5-f442-44f3-aeb8-6523e0a2d9c1___R.S_HL 7957 copy_flipLR.jpg
#                     16826b2f-b614-47ed-bd5c-198c0054723a___R.S_HL 0634 copy 2_flipLR.jpg
#                     3e1226c4-baf1-46fa-8253-e777ca911e2f___R.S_HL 8345 copy_flipLR.jpg
#                     be6d71ee-50b2-4d39-9710-a314214240a0___R.S_HL 5507 copy 3_flipLR.jpg
#                     4a54e4fc-cc6f-47f9-b41e-f9d34c94abbd___R.S_HL 8200 copy 2.jpg
#                     0809c606-2a44-4c38-be5b-6321859d8829___R.S_HL 8137 copy.jpg
#                     8b05f3d8-87a6-4a3e-8ff9-62bce57f9047___R.S_HL 8057 copy_flipLR.jpg
#                     d976fc74-23c2-4c34-a068-db120a61fe0f___R.S_HL 5561 copy_flipLR.jpg
#                     3fdabf59-5491-411c-b61e-c3fc0bbb3831___R.S_HL 8097 copy.jpg
#                     b789776e-6be7-407a-95b3-fd6783c5f03d___R.S_HL 8022 copy_flipLR.jpg
#                     1b1d1d6a-efe6-4c39-91a6-5d289b4e469b___R.S_HL 5525 copy 2_flipLR.jpg
#                     e786d1da-3a80-4f33-89cd-b5fdee3d3318___R.S_HL 8197 copy.jpg
#                     59f7744f-c282-416c-8387-cdbbb195cd4f___R.S_HL 7928 copy_flipLR.jpg
#                     4003f1ff-d041-4e9e-b021-d7cacb9b016f___R.S_HL 8051 copy 2_flipLR.jpg
#                     adf0af30-e4b2-4b2e-ab74-105b6fabc813___R.S_HL 7993 copy_flipLR.jpg
#                     70381b2f-7964-4252-a44a-f63a2c35a71c___R.S_HL 7914 copy 2_flipLR.jpg
#                     dcf1eb1d-f35f-4dfe-9f07-028ddf3abbc3___R.S_HL 8293 copy 2_flipLR.jpg
#                     639a8321-f780-4a3d-aeb6-7f08b61cf6c5___R.S_HL 8246 copy_flipLR.jpg
#                     625ae925-ee23-46fb-a5fb-535b92c248be___R.S_HL 5543 copy_flipLR.jpg
#                     1d424e91-e89b-4cf8-a0e9-48fc345cb9c4___R.S_HL 8299 copy.jpg
#                     106155b4-c159-401a-9ca2-ef3e2f4c2baf___R.S_HL 7983 copy.jpg
#                     d665d2c7-6f91-4852-a1e5-923a9b494ae5___R.S_HL 7992 copy_flipLR.jpg
#                     641fd2fc-a98e-44c7-bac6-5e626aad8747___R.S_HL 8140 copy.jpg
#                     1009c64f-a31c-49fb-9eb4-b6373a588dd0___R.S_HL 5490 copy 3.jpg
#                     abcb076f-c7b8-4feb-98aa-2e65669af656___R.S_HL 7886 copy 2_flipLR.jpg
#                     5b34f21e-9ae1-4213-80b1-b7dfc281e251___R.S_HL 5493 copy_flipLR.jpg
#                     68b3c76b-d08f-498d-bc5e-ddf54af4fd73___R.S_HL 8027 copy.jpg
#                     39569763-d4ed-4687-82c6-c389496b7819___R.S_HL 8183 copy 2_flipLR.jpg
#                     c73b4c12-ccbf-4ba9-8dd9-aba377680518___R.S_HL 5497 copy 2.jpg
#                     433a363a-c354-4972-bd8c-b3fcee49a336___R.S_HL 8302 copy 2_flipLR.jpg
#                     9b89434d-522e-49de-9587-80055bef7a7d___R.S_HL 0609_flipLR.JPG
#                     0f1f7e10-1ca9-488c-8c59-a736d0d7fb4d___R.S_HL 8040 copy_flipLR.jpg
#                     59633534-1c22-49c5-a8c8-909653945bf7___R.S_HL 7912 copy 2.jpg
#                     57e69775-d8c7-4701-9f93-f88dfa27e7f2___R.S_HL 8190 copy.jpg
#                     3ca66c86-4b6e-423d-b721-e11ddc503946___R.S_HL 8267 copy.jpg
#                     0fc33543-ee37-47e4-9207-5c4e5ee8302c___R.S_HL 8257 copy.jpg
#                     d3acd928-1f63-4192-8da5-8ebc84caacc2___R.S_HL 5521 copy.jpg
#                     dbbbc6e0-d26e-443d-a962-5ee4dc35ba79___R.S_HL 0636 copy.jpg
#                     4a960b84-d0be-4118-83bf-24c46678b7f6___R.S_HL 0624 copy 2.jpg
#                     8cdec02e-6273-452f-8681-1319a74d3698___R.S_HL 8185 copy 2_flipLR.jpg
#                     2e92fc34-9521-45e4-8219-3f0aa89650d8___R.S_HL 7907 copy 2.jpg
#                     3cdfb19e-a67f-4944-8b4f-89b60f9f36fb___R.S_HL 8221 copy 3_flipLR.jpg
#                     992ddc51-df49-400f-afd5-cf311bc1d558___R.S_HL 8007 copy.jpg
#                     8ebcdebd-d838-43da-b6fe-395879008848___R.S_HL 8145 copy_flipLR.jpg
#                     a31089a1-47b6-417f-b9ce-41465ff8279e___R.S_HL 8031 copy 2.jpg
#                     0ee6c8d6-534f-4fc5-92bb-fac9d226c70b___R.S_HL 8011 copy.jpg
#                     169f4815-9403-4002-b463-b578b3cf4323___R.S_HL 7929 copy_flipLR.jpg
#                     69164aa5-b1d2-4f9c-af47-54b6fa610296___R.S_HL 8080 copy 2.jpg
#                     b27ca23d-e90c-4087-8421-dec6e1876c89___R.S_HL 8075 copy.jpg
#                     40457fb6-406d-479f-a788-36851a0ff426___R.S_HL 8303 copy 2_flipLR.jpg
#                     6a94d8f3-e2c7-4c1b-a0fe-04f2d01241a5___R.S_HL 8125 copy.jpg
#                     0618b46e-b4fb-4069-9b95-6c6c2387688a___R.S_HL 0609 copy 3_flipLR.jpg
#                     8b05f3d8-87a6-4a3e-8ff9-62bce57f9047___R.S_HL 8057 copy.jpg
#                     af25549e-f09a-4fa5-958b-aa9c49ac6119___R.S_HL 8122 copy 2.jpg
#                     94ca39a0-d4df-44c6-b5cc-a38a754506e5___R.S_HL 0601 copy 3_flipLR.jpg
#                     67580ca9-48d4-485a-8f99-bd68c56e89c2___R.S_HL 8340 copy 2.jpg
#                     02ab8d66-0385-43db-855a-ea5f8811ebd5___R.S_HL 7954 copy_flipLR.jpg
#                     feddfdfa-14e3-4919-a527-814888364871___R.S_HL 5530 copy_flipLR.jpg
#                     c6d72b1a-9f34-4d50-8c80-a5628f60fc21___R.S_HL 8117 copy.jpg
#                     e83663a8-93f0-470c-8f43-7366bb3d8233___R.S_HL 7908 copy 2_flipLR.jpg
#                     4c8d1ae5-019c-45ef-9151-ed904f18ca00___R.S_HL 7909 copy_flipLR.jpg
#                     c0c11e94-597e-4a17-94f2-8cb6e06ddb7d___R.S_HL 8086 copy_flipLR.jpg
#                     9e5d6522-3dc0-4851-84d7-5ee6a6981fb0___R.S_HL 8171 copy.jpg
#                     098a17fd-0351-4f0f-a4a8-6f2a638b4afb___R.S_HL 7897 copy 2.jpg
#                     06f252bb-2ceb-4ca3-a25b-3c8016ee7ee8___R.S_HL 5498 copy 2.jpg
#                     9ae59070-5406-477c-b806-028e83e60cb0___R.S_HL 8234 copy_flipLR.jpg
#                     e2e6d3f1-9f01-44e6-a466-0272b8663f8e___R.S_HL 8307 copy.jpg
#                     a69fb110-6abc-4025-b22a-9ce26e02a4e4___R.S_HL 7961 copy 3.jpg
#                     e9866172-d8db-4cf8-be09-8a94e31d45ee___R.S_HL 8248 copy_flipLR.jpg
#                     4a771d9d-4dc5-48dd-9b05-239246a8dc66___R.S_HL 5494 copy 2.jpg
#                     620e70fd-98d9-40c4-b9a9-803080d1d371___R.S_HL 7968 copy 2_flipLR.jpg
#                     af25549e-f09a-4fa5-958b-aa9c49ac6119___R.S_HL 8122 copy 2_flipLR.jpg
#                     f73f38b8-0938-44f2-a229-6baa3114fe40___R.S_HL 0630 copy 3_flipLR.jpg
#                     67c6930f-deba-4f88-81ac-969155f5765b___R.S_HL 8079 copy 2.jpg
#                     5558853b-3853-4ef2-9824-a73060db0b30___R.S_HL 0631 copy 3.jpg
#                     55ea99a3-17b3-4971-8159-0fa4e369c0d7___R.S_HL 8219 copy 2.jpg
#                     2130487a-e25c-4ac3-ac90-a404f2528f91___R.S_HL 8158 copy 2_flipLR.jpg
#                     cc668ee3-06c8-4bdd-8fbc-231ffb7e56c8___R.S_HL 8113 copy 2.jpg
#                     a3682b13-aca2-47d1-8e75-d7640e97af0a___R.S_HL 8006 copy_flipLR.jpg
#                     6b1b41a1-16f3-4d6f-ae52-de5d93b6c368___R.S_HL 7959 copy 2_flipLR.jpg
#                     37f6cdf3-3424-4ff9-8106-7840c506ddd8___R.S_HL 8166 copy_flipLR.jpg
#                     689e24f2-7175-49a7-9721-7461e1b977d9___R.S_HL 0649 copy 3_flipLR.jpg
#                     34c6b5a7-11ce-4be0-a7ae-e906e548d557___R.S_HL 8256 copy.jpg
#                     6209dc85-5419-4943-ac11-9a72191c4f51___R.S_HL 7916 copy 3_flipLR.jpg
#                     f21eae95-ba11-4eeb-bd33-e003535bbaea___R.S_HL 8164 copy.jpg
#                     9a11606d-02ed-43d3-af4b-da7414dfb4e7___R.S_HL 0597.JPG
#                     4f3347e6-ed68-4659-aa26-5591ea8c923e___R.S_HL 5505 copy.jpg
#                     e786d1da-3a80-4f33-89cd-b5fdee3d3318___R.S_HL 8197 copy_flipLR.jpg
#                     a8ce309e-86b8-4a8c-ad2e-0def8c89382c___R.S_HL 7890 copy 2.jpg
#                     5face5cd-e150-42f5-8ae6-eef79c43b05b___R.S_HL 8010 copy 2.jpg
#                     068794e5-0a99-405f-bbb9-1f954e11942d___R.S_HL 7909 copy 2_flipLR.jpg
#                     9ae59070-5406-477c-b806-028e83e60cb0___R.S_HL 8234 copy.jpg
#                     4c5a712f-aed9-462c-af79-4a5e215c3bf2___R.S_HL 8175 copy 2.jpg
#                     057c048a-6232-4657-8270-5a3e2d468970___R.S_HL 8240 copy_flipLR.jpg
#                     42629a94-b48b-412e-8f60-70f915fe1beb___R.S_HL 8100 copy 2.jpg
#                     854c7bc4-5439-432a-8131-4e37bcb660b3___R.S_HL 7964 copy.jpg
#                     59bc56e1-31cb-410e-a8bb-4afafb0fac7d___R.S_HL 0599 copy 2_flipLR.jpg
#                     c80028fb-0d2b-4090-b858-a22720145dc2___R.S_HL 0627 copy 3.jpg
#                     5d0e77eb-3821-403d-897d-5da32bd13656___R.S_HL 5513 copy 2_flipLR.jpg
#                     9f180540-3445-4b8f-8c7e-6a07d7b6aca5___R.S_HL 8272 copy 2.jpg
#                     7b876e0e-d6bd-4b8c-952c-d0899053246c___R.S_HL 0604 copy 2.jpg
#                     e5a2b441-8173-4c41-a56f-d359b1196719___R.S_HL 8119 copy 2.jpg
#                     bb63915e-8282-4c2b-ae08-0f0777ce27b5___R.S_HL 8074 copy 2_flipLR.jpg
#                     3e60a3ab-304e-4620-ac3a-9e255ce0c779___R.S_HL 8207 copy.jpg
#                     5c007cea-468b-4e33-aa6c-803932baf906___R.S_HL 8145 copy 2.jpg
#                     a249e3ec-00e8-4086-8c82-ab872fcbb4fe___R.S_HL 8342 copy 2_flipLR.jpg
#                     be7c9d7f-2a89-4364-9173-76eecdd3d29e___R.S_HL 8298 copy.jpg
#                     8247acdb-3c47-4f4d-b1fc-bf806dc581ee___R.S_HL 5544 copy.jpg
#                     d12e9409-9a3d-4045-9042-729b5c29a7cd___R.S_HL 8090 copy_flipLR.jpg
#                     54d2d5bb-a3b0-4039-ad5a-2736e821ea8e___R.S_HL 7965 copy 2_flipLR.jpg
#                     8032a314-0525-4400-815d-14b39d793eb9___R.S_HL 7960 copy 2_flipLR.jpg
#                     3d85d62d-8a88-48eb-85a5-a283c670a453___R.S_HL 7972 copy 2_flipLR.jpg
#                     bd16cdda-2c8d-4577-a597-a46c0222d841___R.S_HL 8281 copy_flipLR.jpg
#                     81ec1ee6-7ff1-4811-8bf0-f97870a71a84___R.S_HL 8133 copy 2_flipLR.jpg
#                     eafca683-d2e8-4edd-b62d-3e1a31bba4cb___R.S_HL 8267 copy 2_flipLR.jpg
#                     1009c64f-a31c-49fb-9eb4-b6373a588dd0___R.S_HL 5490 copy 3_flipLR.jpg
#                     4a6aa530-32c7-49fe-a18b-a069bc49073d___R.S_HL 8304 copy.jpg
#                     15bd6d09-98af-40f4-b098-77ec403911d4___R.S_HL 7926 copy_flipLR.jpg
#                     600f5c3a-2156-4485-b74a-c14a16534706___R.S_HL 7958 copy.jpg
#                     028ed539-32f5-4540-a6af-466179837de9___R.S_HL 8212 copy.jpg
#                     422a3a81-fd1c-404e-bda9-2f177d5eb2ec___R.S_HL 7988 copy 2_flipLR.jpg
#                     bea16309-36c9-4d03-a8de-747e29cba604___R.S_HL 8187 copy 2.jpg
#                     33ae3386-f7ce-4c52-92d0-13d964f1cfae___R.S_HL 8331 copy_flipLR.jpg
#                     f9b74a5f-2ccc-4c11-8472-c5270ddfbee0___R.S_HL 5517 copy 2_flipLR.jpg
#                     8063bae7-2a39-449b-b3f4-7004e86c45de___R.S_HL 8277 copy 2.jpg
#                     76bada1b-94ff-4c8c-a9b9-2f4b894faebf___R.S_HL 8133 copy.jpg
#                     26f3cea7-cffe-4d2e-8e72-491a61653fb8___R.S_HL 0626 copy 3.jpg
#                     89bb38f9-2b37-446f-97db-58e856f339ad___R.S_HL 8281 copy 2_flipLR.jpg
#                     c61a25a0-5163-4c93-b487-f73220bc90dc___R.S_HL 5560 copy_flipLR.jpg
#                     65182820-6207-4a47-b757-9b5ae02b80ef___R.S_HL 8218 copy 2.jpg
#                     2515cbc5-85fa-47cd-81ce-dc2cac6819a5___R.S_HL 8297 copy_flipLR.jpg
#                     365694a5-6ad3-46c2-a929-5de7b0dce2e2___R.S_HL 8066 copy.jpg
#                     a35d50c8-99a0-486c-85f4-2eaa3b8395c8___R.S_HL 0626 copy 2_flipLR.jpg
#                     333922bd-09d6-4039-9975-894d77fec8eb___R.S_HL 5496 copy_flipLR.jpg
#                     642c6d64-e53b-4d7b-951a-d00aaf805c32___R.S_HL 8213 copy.jpg
#                     641fd2fc-a98e-44c7-bac6-5e626aad8747___R.S_HL 8140 copy_flipLR.jpg
#                     e3423491-ff2a-4fcc-ad1b-2c0eb5b9adac___R.S_HL 8316 copy_flipLR.jpg
#                     6672927f-9c4b-4c78-a733-1b6a9607764a___R.S_HL 5512 copy 2_flipLR.jpg
#                     f538f7b9-6522-4def-a7e9-907baec0591c___R.S_HL 8229 copy 2.jpg
#                     69a9dfab-d6fd-42da-a0fe-6f46b4bb0a1e___R.S_HL 8272 copy 3_flipLR.jpg
#                     445d1b31-6f77-4597-9ded-4b94581dfa75___R.S_HL 5531 copy_flipLR.jpg
#                     c671c535-9c69-4935-9cc8-0f187b4df44e___R.S_HL 8045 copy 2_flipLR.jpg
#                     0a68ef5a-027c-41ae-b227-159dae77d3dd___R.S_HL 7969 copy_flipLR.jpg
#                     c936eeae-4d4b-4c8c-8ef4-5cb2277a85a5___R.S_HL 8222 copy.jpg
#                     457d6124-02df-4915-b8b1-21e6d987019e___R.S_HL 7949 copy 2_flipLR.jpg
#                     7cb008fd-2be4-415d-bc80-912dbf959aa4___R.S_HL 7884 copy.jpg
#                     7e705f3a-846b-4815-bb4a-99c7024030ab___R.S_HL 7989 copy_flipLR.jpg
#                     5c2c74b7-5687-4109-a5ce-0694f72f8095___R.S_HL 5534 copy.jpg
#                     f092f9e8-3b8e-4ec5-b5a4-024f74c1d5f6___R.S_HL 7997 copy_flipLR.jpg
#                     fb9ebab9-26e6-459c-8b74-8fd04fbf0f89___R.S_HL 7960 copy_flipLR.jpg
#                     64d75b51-f153-4bb5-84b4-d7fcb8279f25___R.S_HL 8018 copy 2_flipLR.jpg
#                     7c7e1c48-88cd-4ea5-8e34-ce9a2a164880___R.S_HL 8300 copy.jpg
#                     7d9bd969-4031-45d2-b07a-26020da47471___R.S_HL 7924 copy.jpg
#     test/
#         test/
#             TomatoHealthy1.JPG
#             AppleCedarRust3.JPG
#             CornCommonRust1.JPG
#             TomatoEarlyBlight3.JPG
#             AppleScab1.JPG
#             CornCommonRust2.JPG
#             TomatoHealthy4.JPG
#             TomatoEarlyBlight2.JPG
#             PotatoHealthy2.JPG
#             PotatoEarlyBlight2.JPG
#             PotatoHealthy1.JPG
#             PotatoEarlyBlight3.JPG
#             TomatoEarlyBlight4.JPG
#             TomatoEarlyBlight5.JPG
#             TomatoYellowCurlVirus1.JPG
#             AppleScab3.JPG
#             AppleCedarRust2.JPG
#             TomatoEarlyBlight1.JPG
#             TomatoYellowCurlVirus3.JPG
#             TomatoEarlyBlight6.JPG
#             TomatoHealthy3.JPG
#             TomatoYellowCurlVirus2.JPG
#             TomatoYellowCurlVirus5.JPG
#             TomatoYellowCurlVirus4.JPG
#             AppleCedarRust4.JPG
#             PotatoEarlyBlight1.JPG
#             AppleCedarRust1.JPG
#             TomatoYellowCurlVirus6.JPG
#             AppleScab2.JPG
#             PotatoEarlyBlight5.JPG
#             PotatoEarlyBlight4.JPG
#             TomatoHealthy2.JPG
#             CornCommonRust3.JPG

# %%
import matplotlib.pyplot as plt
import os
import random
from PIL import Image

def display_random_images(dataset_root_path, num_images=5):
    """
    Displays a specified number of random images from the dataset.

    Args:
        dataset_root_path (str): The root path of the dataset (e.g., the 'PlantVillage' folder).
        num_images (int): The number of random images to display.
    """
    all_image_paths = []
    for root, _, files in os.walk(dataset_root_path):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
                all_image_paths.append(os.path.join(root, file))

    if not all_image_paths:
        print("No images found in the specified dataset path.")
        return

    selected_images = random.sample(all_image_paths, min(num_images, len(all_image_paths)))

    plt.figure(figsize=(15, 5 * len(selected_images)))
    for i, img_path in enumerate(selected_images):
        try:
            img = Image.open(img_path)
            # Extract label from the parent directory name
            label = os.path.basename(os.path.dirname(img_path))
            if label == 'train' or label == 'val' or label == 'test': # Handle cases where direct parent is train/val/test
                label = os.path.basename(os.path.dirname(os.path.dirname(img_path)))

            plt.subplot(len(selected_images), 3, i*3 + 1) # Adjust subplot layout for better display
            plt.imshow(img)
            plt.title(f"Label: {label}\nFile: {os.path.basename(img_path)}", fontsize=8)
            plt.axis('off')
        except Exception as e:
            print(f"Could not load image {img_path}: {e}")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Now, let's try displaying a few random images from the training subset of the dataset. The `dataset_path` variable points to the root of the downloaded dataset.

# %%
import os # Ensure os is imported for path operations

# The dataset_path is '/root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2'
# The 'train' folder is nested inside 'New Plant Diseases Dataset(Augmented)' which is nested again.
train_data_root_path = os.path.join(dataset_path, 'New Plant Diseases Dataset(Augmented)', 'New Plant Diseases Dataset(Augmented)')
train_data_path = os.path.join(train_data_root_path, 'train')

print(f"Attempting to access: {train_data_path}")

if os.path.exists(train_data_path):
    print(f"Path '{train_data_path}' exists. Proceeding to display images.")
    display_random_images(train_data_path, num_images=6)
else:
    print(f"Error: Path '{train_data_path}' does not exist. Please check the dataset structure.")
    # Further debugging for the user if the path still doesn't exist
    print(f"Contents of dataset_path ({dataset_path}): {os.listdir(dataset_path) if os.path.exists(dataset_path) else 'Path does not exist.'}")
    parent_dir_one = os.path.join(dataset_path, 'New Plant Diseases Dataset(Augmented)')
    if os.path.exists(parent_dir_one):
        print(f"Contents of first 'New Plant Diseases Dataset(Augmented)' folder: {os.listdir(parent_dir_one)}")
        parent_dir_two = os.path.join(parent_dir_one, 'New Plant Diseases Dataset(Augmented)')
        if os.path.exists(parent_dir_two):
            print(f"Contents of second 'New Plant Diseases Dataset(Augmented)' folder: {os.listdir(parent_dir_two)}")
            # Check for 'train' directory directly here
            train_check = os.path.join(parent_dir_two, 'train')
            if os.path.exists(train_check):
                print(f"'train' directory found at: {train_check}")
# Out:
# Attempting to access: /root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train
# Path '/root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train' exists. Proceeding to display images.

# %% [markdown]
# ## Data Exploration and Feature Extraction
#
# Let's begin by understanding the dataset structure and distribution of classes.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths for train, validation, and test datasets
# Re-using train_data_root_path from the previous cell for consistency
valid_data_path = os.path.join(train_data_root_path, 'valid')
test_data_path = os.path.join(dataset_path, 'test', 'test') # The top-level 'test' folder contains another 'test' folder

print(f"Train Data Path: {train_data_path}")
print(f"Validation Data Path: {valid_data_path}")
print(f"Test Data Path: {test_data_path}")
# Out:
# Train Data Path: /root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train
# Validation Data Path: /root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid
# Test Data Path: /root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/test/test

# %%
def count_images_and_classes(data_path):
    """
    Counts the number of images and classes in a given dataset path.
    Assumes the structure: data_path/class_name/image.jpg
    """
    class_counts = {}
    for class_name in os.listdir(data_path):
        class_path = os.path.join(data_path, class_name)
        if os.path.isdir(class_path):
            num_images = len([f for f in os.listdir(class_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
            class_counts[class_name] = num_images
    return class_counts

# Get class distribution for the training set
train_class_counts = count_images_and_classes(train_data_path)

# Convert to DataFrame for easier plotting and analysis
train_df = pd.DataFrame(train_class_counts.items(), columns=['Class', 'Count'])

display(train_df.head())
# Out:
#                           Class  Count
# 0             Apple___Black_rot   1987
# 1               Apple___healthy   2008
# 2        Peach___Bacterial_spot   1838
# 3  Tomato___Tomato_mosaic_virus   1790
# 4          Tomato___Late_blight   1851

# %% [markdown]
# ### Training Data Class Distribution

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x='Class', y='Count', data=train_df, palette='viridis')
plt.xticks(rotation=90)
plt.title('Distribution of Plant Disease Classes in Training Set')
plt.xlabel('Plant Disease Class')
plt.ylabel('Number of Images')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3478/2694254974.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Class', y='Count', data=train_df, palette='viridis')

# %% [markdown]
# ### Validation Data Class Distribution

# %%
# Get class distribution for the validation set
valid_class_counts = count_images_and_classes(valid_data_path)
valid_df = pd.DataFrame(valid_class_counts.items(), columns=['Class', 'Count'])

display(valid_df.head())

plt.figure(figsize=(15, 8))
sns.barplot(x='Class', y='Count', data=valid_df, palette='viridis')
plt.xticks(rotation=90)
plt.title('Distribution of Plant Disease Classes in Validation Set')
plt.xlabel('Plant Disease Class')
plt.ylabel('Number of Images')
plt.tight_layout()
plt.show()
# Out:
#                           Class  Count
# 0             Apple___Black_rot    497
# 1               Apple___healthy    502
# 2        Peach___Bacterial_spot    459
# 3  Tomato___Tomato_mosaic_virus    448
# 4          Tomato___Late_blight    463
# /tmp/ipykernel_3478/3150188479.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Class', y='Count', data=valid_df, palette='viridis')

# %% [markdown]
# ### Test Data Class Distribution

# %%
# Get class distribution for the test set
# The test set images are typically not in class-labeled subdirectories
# Instead, they are directly in the test_data_path
test_image_files = [f for f in os.listdir(test_data_path) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]
total_test_images = len(test_image_files)

# Create a DataFrame to represent the total count
test_df = pd.DataFrame([{'Class': 'Total Test Images (Unlabeled)', 'Count': total_test_images}])

print(f"Total number of test images found: {total_test_images}")
display(test_df) # Display the DataFrame with total count

# Plotting (will show a single bar for total test images)
plt.figure(figsize=(8, 6)) # Adjust figure size for a single bar
sns.barplot(x='Class', y='Count', data=test_df, palette='viridis')
plt.xticks(rotation=45)
plt.title('Total Images in Test Set')
plt.xlabel('') # No specific classes to label
plt.ylabel('Number of Images')
plt.tight_layout()
plt.show()
# Out:
# Total number of test images found: 33
#                            Class  Count
# 0  Total Test Images (Unlabeled)     33
# /tmp/ipykernel_3478/1196997193.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Class', y='Count', data=test_df, palette='viridis')

# %% [markdown]
# ## Data Preparation for Model Training
#
# To prepare the images for training a deep learning model, we'll use `ImageDataGenerator` from TensorFlow/Keras. This will handle:
#
# *   **Rescaling:** Normalizing pixel values to a [0, 1] range.
# *   **Image Resizing:** Resizing all images to a consistent size (e.g., 224x224 pixels).
# *   **Batching:** Grouping images into batches for efficient model training.
# *   **Data Augmentation (for training set):** Applying transformations like rotations, shifts, and flips to the training images to increase the diversity of the training data and improve model generalization.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define image dimensions and batch size
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32

# Create ImageDataGenerator for training with augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255, # Normalize pixel values to [0, 1]
    rotation_range=40, # Randomly rotate images by up to 40 degrees
    width_shift_range=0.2, # Randomly shift images horizontally
    height_shift_range=0.2, # Randomly shift images vertically
    shear_range=0.2, # Apply shearing transformations
    zoom_range=0.2, # Apply random zoom
    horizontal_flip=True, # Randomly flip images horizontally
    fill_mode='nearest' # Fill new pixels created by transformations
)

# Create ImageDataGenerator for validation and test sets (only rescaling)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

print("ImageDataGenerators initialized.")
# Out:
# ImageDataGenerators initialized.

# %% [markdown]
# Now, let's create the actual data generators using `flow_from_directory`. These generators will load images from our defined paths, apply the preprocessing steps, and serve them in batches to the model.

# %%
# Create training data generator
train_generator = train_datagen.flow_from_directory(
    train_data_path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical' # For multi-class classification
)

# Create validation data generator
validation_generator = validation_datagen.flow_from_directory(
    valid_data_path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

# Create test data generator
# For the test set, we need to handle that images are not in subdirectories by class.
# We set class_mode=None and shuffle=False to get predictions in order.
# However, to maintain consistency with `flow_from_directory` and avoid issues with target_size, we'll assume
# the user intends to classify these directly. If labels are needed later, a custom generator might be required.
# For now, let's adapt `flow_from_directory` by pointing it to the folder containing the images directly.
# This will treat each image as its own 'class' effectively for this step if it expects subfolders, or more ideally
# if the test path only contains images, it will generate them without class labels.

# A more robust approach for test data without subfolders:
# test_generator = test_datagen.flow_from_dataframe(
#     dataframe=pd.DataFrame({'filename': test_image_files}), # Assuming test_image_files is a list of filenames
#     directory=test_data_path,
#     x_col='filename',
#     y_col=None,
#     target_size=(IMG_HEIGHT, IMG_WIDTH),
#     batch_size=BATCH_SIZE,
#     class_mode=None,
#     shuffle=False
# )

# Given `test_data_path` points directly to the images, we can use `flow_from_directory` but with a caveat:
# It expects subdirectories. Since the test data doesn't have class subdirectories, we will use `flow_from_directory`
# on the parent folder of `test_data_path` and specify `classes=[os.path.basename(test_data_path)]`.
# This effectively tells it to treat all images within `test_data_path` as one 'class'.

# Determine the parent directory of test_data_path
test_parent_path = os.path.dirname(test_data_path)
test_dir_name = os.path.basename(test_data_path)

# Create test data generator for unlabeled test images
test_generator = test_datagen.flow_from_directory(
    test_parent_path, # Point to the parent directory
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode=None, # No class labels needed for prediction
    shuffle=False, # Keep file order for potential later mapping
    classes=[test_dir_name] # Specify the 'class' as the folder name containing the images
)

print("Data generators created.")
print(f"Number of training samples: {train_generator.samples}")
print(f"Number of validation samples: {validation_generator.samples}")
print(f"Number of test samples: {test_generator.samples}")
print(f"Number of classes: {train_generator.num_classes}")
print(f"Class labels: {train_generator.class_indices}")
# Out:
# Found 70295 images belonging to 38 classes.
# Found 17572 images belonging to 38 classes.
# Found 33 images belonging to 1 classes.
# Data generators created.
# Number of training samples: 70295
# Number of validation samples: 17572
# Number of test samples: 33
# Number of classes: 38
# Class labels: {'Apple___Apple_scab': 0, 'Apple___Black_rot': 1, 'Apple___Cedar_apple_rust': 2, 'Apple___healthy': 3, 'Blueberry___healthy': 4, 'Cherry_(including_sour)___Powdery_mildew': 5, 'Cherry_(including_sour)___healthy': 6, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 7, 'Corn_(maize)___Common_rust_': 8, 'Corn_(maize)___Northern_Leaf_Blight': 9, 'Corn_(maize)___healthy': 10, 'Grape___Black_rot': 11, 'Grape___Esca_(Black_Measles)': 12, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 13, 'Grape___healthy': 14, 'Orange___Haunglongbing_(Citrus_greening)': 15, 'Peach___Bacterial_spot': 16, 'Peach___healthy': 17, 'Pepper,_bell___Bacterial_spot': 18, 'Pepper,_bell___healthy': 19, 'Potato___Early_blight': 20, 'Potato___Late_blight': 21, 'Potato___healthy': 22, 'Raspberry___healthy': 23, 'Soybean___healthy': 24, 'Squash___Powdery_mildew': 25, 'Strawberry___Leaf_scorch': 26, 'Strawberry___healthy': 27, 'Tomato___Bacterial_spot': 28, 'Tomato___Early_blight': 29, 'Tomato___Late_blight': 30, 'Tomato___Leaf_Mold': 31, 'Tomato___Septoria_leaf_spot': 32, 'Tomato___Spider_mites Two-spotted_spider_mite': 33, 'Tomato___Target_Spot': 34, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 35, 'Tomato___Tomato_mosaic_virus': 36, 'Tomato___healthy': 37}

# %% [markdown]
# ## Define and Compile the CNN Model
#
# Now, let's define the architecture of our Convolutional Neural Network (CNN). We'll start with a relatively simple sequential model that includes convolutional layers for feature extraction and dense layers for classification. We'll use `tf.keras.applications.MobileNetV2` as a base for transfer learning to leverage pre-trained weights on a large dataset, which usually leads to better performance on image tasks with limited data. This will be adapted for our specific number of classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D

# Get the number of classes from the training generator
num_classes = train_generator.num_classes

# Load the MobileNetV2 model with pre-trained weights (ImageNet) excluding the top classification layer
base_model = MobileNetV2(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), include_top=False, weights='imagenet')

# Freeze the base model layers so they are not updated during initial training
base_model.trainable = False

# Create a new model on top of the pre-trained base
model = Sequential([
    base_model,
    GlobalAveragePooling2D(), # Reduces spatial dimensions to a single vector
    Dense(128, activation='relu'), # A dense layer for further feature processing
    Dropout(0.5), # Dropout for regularization
    Dense(num_classes, activation='softmax') # Output layer for classification
])

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=0.0001), # Use a small learning rate for fine-tuning/transfer learning
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("CNN model defined and compiled using MobileNetV2 for transfer learning.")
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# CNN model defined and compiled using MobileNetV2 for transfer learning.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 38)             │         4,902 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,426,854 (9.26 MB)
#  Trainable params: 168,870 (659.65 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ## Train the Model
#
# Now we will train the defined CNN model using the `train_generator` and `validation_generator`. We'll also use `EarlyStopping` to stop training when the validation loss stops improving, and `ModelCheckpoint` to save the best model weights during training.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Define callbacks
early_stopping = EarlyStopping(
    monitor='val_loss', # Monitor validation loss
    patience=5, # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True # Restore model weights from the epoch with the best value of the monitored quantity
)

model_checkpoint = ModelCheckpoint(
    'best_plant_disease_model.keras', # Filepath to save the model
    monitor='val_loss', # Monitor validation loss
    save_best_only=True, # Save only the best model
    mode='min', # The 'best' model has the minimum validation loss
    verbose=1 # Log when model is saved
)

epochs = 20 # You can adjust the number of epochs

history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    callbacks=[early_stopping, model_checkpoint]
)

print("Model training complete.")
# Out:
# Epoch 1/20
#  184/2197 ━━━━━━━━━━━━━━━━━━━━ 1:07:15 2s/step - accuracy: 0.2300 - loss: 2.8775
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3478/67747994.py in <cell line: 0>()
#      18 epochs = 20 # You can adjust the number of epochs
#      19
# ---> 20 history = model.fit(
#      21     train_generator,
#      22     epochs=epochs,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397                 for begin_step, end_step, iterator in epoch_iterator:
#     398                     callbacks.on_train_batch_begin(begin_step)
# --> 399                     logs = self.train_function(iterator)
#     400                     callbacks.on_train_batch_end(end_step, logs)
#     401                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     239                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240             ):
# --> 241                 opt_outputs = multi_step_on_iterator(iterator)
#     242                 if not opt_outputs.has_value():
#     243                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Recommended Reading and Documentation
#
# To better understand the current and upcoming steps in building and training this plant disease detection system, here are some key topics and resources:
#
# ### 1. Convolutional Neural Networks (CNNs)
#
# *   **Concept:** CNNs are the backbone of most modern image classification models. They are designed to automatically learn spatial hierarchies of features from image data.
# *   **Recommended Reading:**
#     *   [**Deep Learning Book - Chapter 9: Convolutional Networks**](https://www.deeplearningbook.org/contents/convnets.html): A comprehensive theoretical overview.
#     *   [**Stanford CS231n: Convolutional Neural Networks for Visual Recognition**](https://cs231n.github.io/convolutional-networks/): Excellent course notes with intuitive explanations and visualizations.
#
# ### 2. Transfer Learning
#
# *   **Concept:** Transfer learning involves using a pre-trained model (like MobileNetV2 in our case) that was trained on a very large dataset (e.g., ImageNet) and adapting it to a new, but similar, task. This is highly effective when you have limited data for your specific problem.
# *   **Recommended Reading:**
#     *   [**Keras Guide: Transfer learning & fine-tuning**](https://keras.io/guides/transfer_learning/): A practical guide on how to implement transfer learning in Keras.
#     *   [**Towards Data Science: A Step-by-Step Guide to Transfer Learning for Computer Vision**](https://towardsdatascience.com/a-step-by-step-guide-to-transfer-learning-for-computer-vision-with-code-5f110757a31b): An article with code examples.
#
# ### 3. Image Data Augmentation
#
# *   **Concept:** Data augmentation is a technique to increase the diversity of your training data by applying random transformations (like rotation, shifting, zooming, flipping) to your images. This helps prevent overfitting and improves the model's generalization.
# *   **Recommended Reading:**
#     *   [**Keras Documentation: ImageDataGenerator**](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator): Official documentation for the tool we are using.
#     *   [**Analytics Vidhya: Image Augmentation for Deep Learning using Keras**](https://www.analyticsvidhya.com/blog/2019/07/build-image-classification-game-deep-learning-keras/): A blog post explaining augmentation techniques.
#
# ### 4. Model Evaluation Metrics
#
# *   **Concept:** After training, we need to evaluate how well our model performs. Key metrics include accuracy, precision, recall, F1-score, and confusion matrices.
# *   **Recommended Reading:**
#     *   [**Scikit-learn User Guide: Classification metrics**](https://scikit-learn.org/stable/modules/model_evaluation.html#classification-metrics): Overview of various classification metrics.
#     *   [**Confusion Matrix Explained**](https://www.v7labs.com/blog/confusion-matrix): An easy-to-understand explanation of confusion matrices.
#
# These resources should provide a solid foundation for understanding each step of the process. Feel free to ask if you have specific questions about any of these topics!

# %%
# This cell is just a trigger to execute the previous modified cell.
# The actual logic is in cell 7ca61d35.
print("Executing cell 7ca61d35 to analyze test data...")
# Out:
# Executing cell 7ca61d35 to analyze test data...

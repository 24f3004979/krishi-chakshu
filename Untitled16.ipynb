# %%
# Install kagglehub if not already installed
# %pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in ./.venv/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in ./.venv/lib/python3.10/site-packages (from kagglehub) (0.1.23)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from kagglehub) (26.2)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.10/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in ./.venv/lib/python3.10/site-packages (from kagglehub) (2.34.2)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.10/site-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in ./.venv/lib/python3.10/site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub) (7.35.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests->kagglehub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests->kagglehub) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.10/site-packages (from requests->kagglehub) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./.venv/lib/python3.10/site-packages (from requests->kagglehub) (2026.5.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub
import os

# Download the latest version of the dataset
dataset_path = kagglehub.dataset_download("vipoooool/new-plant-diseases-dataset")

print(f"Path to dataset files: {dataset_path}")

# List the contents of the downloaded dataset directory
print("Contents of the downloaded dataset:")
for root, dirs, files in os.walk(dataset_path):
    level = root.replace(dataset_path, '').count(os.sep)
    indent = ' ' * 4 * (level)
    print(f'{indent}{os.path.basename(root)}/')
    subindent = ' ' * 4 * (level + 1)
    for f in files:
        print(f'{subindent}{f}')
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#                 Tomato___Spider_mites Two-spotted_spider_mite/
#                     003b7929-a364-4e74-be1c-37c4c0a6ec63___Com.G_SpM_FL 1414.JPG
#                     003b7929-a364-4e74-be1c-37c4c0a6ec63___Com.G_SpM_FL 1414_180deg.JPG
#                     003b7929-a364-4e74-be1c-37c4c0a6ec63___Com.G_SpM_FL 1414_flipTB.JPG
#                     00bc7858-1dca-4bfb-a828-225f03bd72a5___Com.G_SpM_FL 9455_180deg.JPG
#                     00bc7858-1dca-4bfb-a828-225f03bd72a5___Com.G_SpM_FL 9455_flipTB.JPG
#                     00c8e9a0-1fb8-434b-8981-25511358ddc9___Com.G_SpM_FL 8717.JPG
#                     00c8e9a0-1fb8-434b-8981-25511358ddc9___Com.G_SpM_FL 8717_180deg.JPG
#                     00c8e9a0-1fb8-434b-8981-25511358ddc9___Com.G_SpM_FL 8717_flipTB.JPG
#                     00fa99e8-2605-4d72-be69-98277587d84b___Com.G_SpM_FL 1453.JPG
#                     00fa99e8-2605-4d72-be69-98277587d84b___Com.G_SpM_FL 1453_180deg.JPG
#                     0100e504-f6bc-464a-a181-38262117f30a___Com.G_SpM_FL 1202.JPG
#                     01027422-5838-4aaf-a517-01ea4e2cb6b9___Com.G_SpM_FL 9256.JPG
#                     012369f5-ca64-4811-888f-35d75f7f7c2b___Com.G_SpM_FL 8911.JPG
#                     01720a27-7595-496b-bf53-dbe5c8c1e2c3___Com.G_SpM_FL 8476.JPG
#                     0189e941-6286-4aae-bc7a-c87b2d6e0b09___Com.G_SpM_FL 1153.JPG
#                     01963a97-0507-43a6-ae4a-1afd8e0c4f3e___Com.G_SpM_FL 1217.JPG
#                     0211efc9-5409-43a7-a46b-a87d46f23fc3___Com.G_SpM_FL 9646.JPG
#                     0247236f-c1ae-4b3f-92b3-9077fe5cb3c3___Com.G_SpM_FL 8505.JPG
#                     02c791ab-ffc3-40d4-9b42-db946eee2413___Com.G_SpM_FL 1640.JPG
#                     02c791ab-ffc3-40d4-9b42-db946eee2413___Com.G_SpM_FL 1640_flipTB.JPG
#                     0315776d-6d0d-4ae2-b102-4fd0feebaa51___Com.G_SpM_FL 9375.JPG
#                     03882a7e-b80a-4c12-b4bb-5d03c88a8c4b___Com.G_SpM_FL 8730.JPG
#                     03dc4d71-45b6-4845-9f66-3b7aae5375e1___Com.G_SpM_FL 1193.JPG
#                     03dc4d71-45b6-4845-9f66-3b7aae5375e1___Com.G_SpM_FL 1193_180deg.JPG
#                     03dc4d71-45b6-4845-9f66-3b7aae5375e1___Com.G_SpM_FL 1193_flipTB.JPG
#                     03e18a00-ffbd-4863-a0c5-7c597c09b025___Com.G_SpM_FL 8798.JPG
#                     03e18a00-ffbd-4863-a0c5-7c597c09b025___Com.G_SpM_FL 8798_flipTB.JPG
#                     03fa54ef-d6cc-40f3-8ae2-469d1ab5b541___Com.G_SpM_FL 9653_flipTB.JPG
#                     0421a79d-5c62-43e8-a695-ae55f987c27e___Com.G_SpM_FL 1434.JPG
#                     04a5f541-9202-4475-b5a0-01c14543f211___Com.G_SpM_FL 8534.JPG
#                     04a5f541-9202-4475-b5a0-01c14543f211___Com.G_SpM_FL 8534_180deg.JPG
#                     04a5f541-9202-4475-b5a0-01c14543f211___Com.G_SpM_FL 8534_flipTB.JPG
#                     04b0cccf-da6f-4ad8-9ff9-0055170a990c___Com.G_SpM_FL 1284.JPG
#                     04b0cccf-da6f-4ad8-9ff9-0055170a990c___Com.G_SpM_FL 1284_180deg.JPG
#                     04b0cccf-da6f-4ad8-9ff9-0055170a990c___Com.G_SpM_FL 1284_flipTB.JPG
#                     05138887-688c-4efe-a78f-f4416c1d63b0___Com.G_SpM_FL 8767.JPG
#                     053c2c95-1110-4d4e-98d1-e189858deb3f___Com.G_SpM_FL 8449.JPG
#                     05a76480-4ffe-476f-a101-fdadd8b3fbcf___Com.G_SpM_FL 9329.JPG
#                     05a76480-4ffe-476f-a101-fdadd8b3fbcf___Com.G_SpM_FL 9329_180deg.JPG
#                     05be6ebc-1641-4707-91da-9b5650b9641a___Com.G_SpM_FL 8857_180deg.JPG
#                     05d67c02-8fb8-40dd-bbbe-efdc9837dced___Com.G_SpM_FL 1598.JPG
#                     05d67c02-8fb8-40dd-bbbe-efdc9837dced___Com.G_SpM_FL 1598_flipTB.JPG
#                     06c29099-98e3-46ae-88f9-7160c74dafea___Com.G_SpM_FL 9427.JPG
#                     06e43f45-f56b-4979-b4a3-10eafeaddf3e___Com.G_SpM_FL 9534.JPG
#                     06f22419-20df-43ab-9402-7ee76eb08921___Com.G_SpM_FL 1325.JPG
#                     072a0bb6-de84-4200-8393-9e5b28868a23___Com.G_SpM_FL 1412.JPG
#                     0730f5a3-7001-4d2c-9949-5633c30ce3a5___Com.G_SpM_FL 8809.JPG
#                     07843665-3d98-4371-873a-21b4bbe30a9d___Com.G_SpM_FL 8458.JPG
#                     0792af40-147c-400a-84e6-a0eeb25ac381___Com.G_SpM_FL 9381.JPG
#                     0794d252-5524-49d2-9871-011677db2698___Com.G_SpM_FL 8571.JPG
#                     079c26a2-0862-4062-aa4b-53a5af52350f___Com.G_SpM_FL 1497.JPG
#                     081a628a-9293-4aac-bde6-c117085132f6___Com.G_SpM_FL 9037.JPG
#                     08261e43-0fe0-42bd-9c15-3dca406ba0bf___Com.G_SpM_FL 1359.JPG
#                     085cdef7-8892-4873-a0e7-5715082762d0___Com.G_SpM_FL 8650.JPG
#                     08672d79-7f11-4900-9e12-aad35778f463___Com.G_SpM_FL 8753.JPG
#                     087cd727-92d4-4c49-a069-26b3563037e4___Com.G_SpM_FL 9573.JPG
#                     089621fa-9c68-4401-a964-ee3383a31cd6___Com.G_SpM_FL 8554.JPG
#                     08ddab1e-8a69-47b2-b0ff-6d53e6315eee___Com.G_SpM_FL 1445.JPG
#                     08e9a879-8784-4775-aeef-21fbd62dd08e___Com.G_SpM_FL 8513.JPG
#                     08f0fd0e-d4b1-400d-9df1-2d61d24c95f0___Com.G_SpM_FL 9397.JPG
#                     093aecee-3211-4aad-8f09-45ccdc92eeb6___Com.G_SpM_FL 9040.JPG
#                     09434fa9-0733-4ef5-9cc3-db29d1e3a480___Com.G_SpM_FL 1425.JPG
#                     09904a06-b32f-4db4-963f-c8dacfff6b9e___Com.G_SpM_FL 8456.JPG
#                     09dce947-bb58-46cc-bd33-5a5e75ee07f4___Com.G_SpM_FL 9019.JPG
#                     09f7d264-2fb7-48c2-adec-2bc288fb22cd___Com.G_SpM_FL 8686.JPG
#                     0a167675-0317-4105-b885-b707b6ea52cf___Com.G_SpM_FL 9327.JPG
#                     0a167675-0317-4105-b885-b707b6ea52cf___Com.G_SpM_FL 9327_180deg.JPG
#                     0a167675-0317-4105-b885-b707b6ea52cf___Com.G_SpM_FL 9327_flipTB.JPG
#                     0a1c03ea-1a2d-449e-bcc4-4a8b62febf88___Com.G_SpM_FL 9433.JPG
#                     0a1c03ea-1a2d-449e-bcc4-4a8b62febf88___Com.G_SpM_FL 9433_180deg.JPG
#                     0a1c03ea-1a2d-449e-bcc4-4a8b62febf88___Com.G_SpM_FL 9433_flipTB.JPG
#                     0a246e71-0551-4603-a017-d1dfc4ea06be___Com.G_SpM_FL 1178.JPG
#                     0a2b122a-0f23-4c92-8b7a-21b274dffbe5___Com.G_SpM_FL 9350.JPG
#                     0a2b122a-0f23-4c92-8b7a-21b274dffbe5___Com.G_SpM_FL 9350_180deg.JPG
#                     0a2b122a-0f23-4c92-8b7a-21b274dffbe5___Com.G_SpM_FL 9350_flipTB.JPG
#                     0a3ec09c-ccf4-49ab-bae2-f82f913aa9c8___Com.G_SpM_FL 9444.JPG
#                     0a3ec09c-ccf4-49ab-bae2-f82f913aa9c8___Com.G_SpM_FL 9444_180deg.JPG
#                     0a3ec09c-ccf4-49ab-bae2-f82f913aa9c8___Com.G_SpM_FL 9444_flipTB.JPG
#                     0a714292-45d6-483a-bbd0-2eab8fe72888___Com.G_SpM_FL 1496.JPG
#                     0a714292-45d6-483a-bbd0-2eab8fe72888___Com.G_SpM_FL 1496_180deg.JPG
#                     0a7714a4-530b-49e0-821f-be8d33c588ac___Com.G_SpM_FL 1775.JPG
#                     0a7714a4-530b-49e0-821f-be8d33c588ac___Com.G_SpM_FL 1775_flipTB.JPG
#                     0ac9558f-1e02-4498-9584-887627587bc0___Com.G_SpM_FL 1148.JPG
#                     0ac9558f-1e02-4498-9584-887627587bc0___Com.G_SpM_FL 1148_180deg.JPG
#                     0ac9558f-1e02-4498-9584-887627587bc0___Com.G_SpM_FL 1148_flipTB.JPG
#                     0ad80523-3f34-41ae-aec8-e676546ddde5___Com.G_SpM_FL 8489.JPG
#                     0ad80523-3f34-41ae-aec8-e676546ddde5___Com.G_SpM_FL 8489_180deg.JPG
#                     0ad80523-3f34-41ae-aec8-e676546ddde5___Com.G_SpM_FL 8489_flipTB.JPG
#                     0ade19e4-c48b-4e58-bddf-153d44d48c3e___Com.G_SpM_FL 9449_180deg.JPG
#                     0af13d73-170d-4b37-bddf-51a14e597905___Com.G_SpM_FL 1438.JPG
#                     0af13d73-170d-4b37-bddf-51a14e597905___Com.G_SpM_FL 1438_180deg.JPG
#                     0af13d73-170d-4b37-bddf-51a14e597905___Com.G_SpM_FL 1438_flipTB.JPG
#                     0b17e71c-fee6-4b5e-9a7d-8ba44d29215f___Com.G_SpM_FL 8549.JPG
#                     0b17e71c-fee6-4b5e-9a7d-8ba44d29215f___Com.G_SpM_FL 8549_180deg.JPG
#                     0b17e71c-fee6-4b5e-9a7d-8ba44d29215f___Com.G_SpM_FL 8549_flipTB.JPG
#                     0b437fa8-c1c8-45f4-b608-bdc6f7e09f84___Com.G_SpM_FL 1137.JPG
#                     0b437fa8-c1c8-45f4-b608-bdc6f7e09f84___Com.G_SpM_FL 1137_180deg.JPG
#                     0b437fa8-c1c8-45f4-b608-bdc6f7e09f84___Com.G_SpM_FL 1137_flipTB.JPG
#                     0b5cda10-da2f-4647-b159-69647b42212f___Com.G_SpM_FL 1784.JPG
#                     0b5cda10-da2f-4647-b159-69647b42212f___Com.G_SpM_FL 1784_flipTB.JPG
#                     0b891169-2116-431d-968f-d2a36bb69243___Com.G_SpM_FL 1743.JPG
#                     0b891169-2116-431d-968f-d2a36bb69243___Com.G_SpM_FL 1743_180deg.JPG
#                     0b891169-2116-431d-968f-d2a36bb69243___Com.G_SpM_FL 1743_flipTB.JPG
#                     0bb186a0-f27a-41b1-b0d2-5cf82eb87251___Com.G_SpM_FL 9018.JPG
#                     0bb186a0-f27a-41b1-b0d2-5cf82eb87251___Com.G_SpM_FL 9018_flipTB.JPG
#                     0bc5e91c-637e-4a44-a44d-3ee6c941bb96___Com.G_SpM_FL 1592.JPG
#                     0bc5e91c-637e-4a44-a44d-3ee6c941bb96___Com.G_SpM_FL 1592_flipTB.JPG
#                     0bfd3a50-768e-4661-a134-43aaee7a1c1d___Com.G_SpM_FL 8837.JPG
#                     0bfd3a50-768e-4661-a134-43aaee7a1c1d___Com.G_SpM_FL 8837_180deg.JPG
#                     0bfd3a50-768e-4661-a134-43aaee7a1c1d___Com.G_SpM_FL 8837_flipTB.JPG
#                     0c142adf-5d26-4593-a7b3-d16a07f1df33___Com.G_SpM_FL 8768_180deg.JPG
#                     0c142adf-5d26-4593-a7b3-d16a07f1df33___Com.G_SpM_FL 8768_flipTB.JPG
#                     0c2e84df-4d41-46f6-9cf9-05aea349ce18___Com.G_SpM_FL 1142.JPG
#                     0c2e84df-4d41-46f6-9cf9-05aea349ce18___Com.G_SpM_FL 1142_180deg.JPG
#                     0c817d69-a13f-47d9-be7b-a17eea45774d___Com.G_SpM_FL 8613.JPG
#                     0c817d69-a13f-47d9-be7b-a17eea45774d___Com.G_SpM_FL 8613_180deg.JPG
#                     0c817d69-a13f-47d9-be7b-a17eea45774d___Com.G_SpM_FL 8613_flipTB.JPG
#                     0cc75e2e-9e6f-4b8e-b564-3840c9ecff58___Com.G_SpM_FL 1442.JPG
#                     0cc75e2e-9e6f-4b8e-b564-3840c9ecff58___Com.G_SpM_FL 1442_180deg.JPG
#                     0cc75e2e-9e6f-4b8e-b564-3840c9ecff58___Com.G_SpM_FL 1442_flipTB.JPG
#                     0cee18fc-bbbd-40dd-8d73-93df072c09ea___Com.G_SpM_FL 8904_180deg.JPG
#                     0d5846df-f761-4d38-b10f-7bdb42b989b7___Com.G_SpM_FL 1484.JPG
#                     0d5846df-f761-4d38-b10f-7bdb42b989b7___Com.G_SpM_FL 1484_flipTB.JPG
#                     0d6a202a-046f-47b2-beec-cc6a1e7deae6___Com.G_SpM_FL 8937.JPG
#                     0d6a202a-046f-47b2-beec-cc6a1e7deae6___Com.G_SpM_FL 8937_180deg.JPG
#                     0d6a202a-046f-47b2-beec-cc6a1e7deae6___Com.G_SpM_FL 8937_flipTB.JPG
#                     0d7c22dc-323c-4979-9dad-0fdbfdeb6e4e___Com.G_SpM_FL 9038.JPG
#                     0d7c22dc-323c-4979-9dad-0fdbfdeb6e4e___Com.G_SpM_FL 9038_180deg.JPG
#                     0d7c22dc-323c-4979-9dad-0fdbfdeb6e4e___Com.G_SpM_FL 9038_flipTB.JPG
#                     0d831ad9-bc2a-4168-bbf2-6030f3f886f2___Com.G_SpM_FL 9419_180deg.JPG
#                     0d831ad9-bc2a-4168-bbf2-6030f3f886f2___Com.G_SpM_FL 9419_flipTB.JPG
#                     0d835caf-0069-4fa5-a022-c8cc7763189c___Com.G_SpM_FL 8917.JPG
#                     0d835caf-0069-4fa5-a022-c8cc7763189c___Com.G_SpM_FL 8917_180deg.JPG
#                     0d956449-8243-4229-b293-124461cc4940___Com.G_SpM_FL 9325_180deg.JPG
#                     0d956449-8243-4229-b293-124461cc4940___Com.G_SpM_FL 9325_flipTB.JPG
#                     0db2da38-8650-461a-a785-814cc442f44d___Com.G_SpM_FL 1378.JPG
#                     0db2da38-8650-461a-a785-814cc442f44d___Com.G_SpM_FL 1378_180deg.JPG
#                     0db2da38-8650-461a-a785-814cc442f44d___Com.G_SpM_FL 1378_flipTB.JPG
#                     0db59779-c927-4b54-a258-73344972746b___Com.G_SpM_FL 1752.JPG
#                     0db59779-c927-4b54-a258-73344972746b___Com.G_SpM_FL 1752_180deg.JPG
#                     0db59779-c927-4b54-a258-73344972746b___Com.G_SpM_FL 1752_flipTB.JPG
#                     0dd13a82-3fd8-426b-8a87-4e695c92d3b2___Com.G_SpM_FL 8829.JPG
#                     0dd13a82-3fd8-426b-8a87-4e695c92d3b2___Com.G_SpM_FL 8829_180deg.JPG
#                     0dd13a82-3fd8-426b-8a87-4e695c92d3b2___Com.G_SpM_FL 8829_flipTB.JPG
#                     0e05cc2b-1209-4a5a-9ae1-26b3dd13204b___Com.G_SpM_FL 8428.JPG
#                     0e05cc2b-1209-4a5a-9ae1-26b3dd13204b___Com.G_SpM_FL 8428_180deg.JPG
#                     0e05cc2b-1209-4a5a-9ae1-26b3dd13204b___Com.G_SpM_FL 8428_flipTB.JPG
#                     0e0d9560-41ee-45cf-8bea-8cddfdc04979___Com.G_SpM_FL 1159.JPG
#                     0e0d9560-41ee-45cf-8bea-8cddfdc04979___Com.G_SpM_FL 1159_flipTB.JPG
#                     0e20026b-8b12-4c86-bd41-3e10ea0fae44___Com.G_SpM_FL 1668.JPG
#                     0e20026b-8b12-4c86-bd41-3e10ea0fae44___Com.G_SpM_FL 1668_180deg.JPG
#                     0e20026b-8b12-4c86-bd41-3e10ea0fae44___Com.G_SpM_FL 1668_flipTB.JPG
#                     0e74fa9e-a63f-46b3-a976-46510e7fdfba___Com.G_SpM_FL 8579.JPG
#                     0e74fa9e-a63f-46b3-a976-46510e7fdfba___Com.G_SpM_FL 8579_180deg.JPG
#                     0e74fa9e-a63f-46b3-a976-46510e7fdfba___Com.G_SpM_FL 8579_flipTB.JPG
#                     0e9318de-e920-4d2c-bb61-5ef0a628d273___Com.G_SpM_FL 9302.JPG
#                     0e9318de-e920-4d2c-bb61-5ef0a628d273___Com.G_SpM_FL 9302_180deg.JPG
#                     0e9318de-e920-4d2c-bb61-5ef0a628d273___Com.G_SpM_FL 9302_flipTB.JPG
#                     0eead1ad-106f-4bb7-8e9e-4ed03cdeb7ab___Com.G_SpM_FL 1319_180deg.JPG
#                     0eead1ad-106f-4bb7-8e9e-4ed03cdeb7ab___Com.G_SpM_FL 1319_flipTB.JPG
#                     0eee4e0a-7952-4973-96c9-2c441f864752___Com.G_SpM_FL 8802.JPG
#                     0eee4e0a-7952-4973-96c9-2c441f864752___Com.G_SpM_FL 8802_180deg.JPG
#                     0f1049cd-1fb5-4792-9b41-8544ee1c18a7___Com.G_SpM_FL 1726.JPG
#                     0f1049cd-1fb5-4792-9b41-8544ee1c18a7___Com.G_SpM_FL 1726_180deg.JPG
#                     0f1049cd-1fb5-4792-9b41-8544ee1c18a7___Com.G_SpM_FL 1726_flipTB.JPG
#                     0f3b55b7-39de-4a05-9ed0-9ceaa32a2c34___Com.G_SpM_FL 8873.JPG
#                     0f3b55b7-39de-4a05-9ed0-9ceaa32a2c34___Com.G_SpM_FL 8873_180deg.JPG
#                     0f3b55b7-39de-4a05-9ed0-9ceaa32a2c34___Com.G_SpM_FL 8873_flipTB.JPG
#                     0f514b75-2c74-4075-b9c7-5d469ab292ba___Com.G_SpM_FL 1205_180deg.JPG
#                     0f514b75-2c74-4075-b9c7-5d469ab292ba___Com.G_SpM_FL 1205_flipTB.JPG
#                     0f6a5f32-3d95-4ef1-bc01-ba36f2efb2b4___Com.G_SpM_FL 1661.JPG
#                     0f6a5f32-3d95-4ef1-bc01-ba36f2efb2b4___Com.G_SpM_FL 1661_flipTB.JPG
#                     0f75930a-4f0c-49db-b5d8-6e4987b868eb___Com.G_SpM_FL 1729.JPG
#                     0f75930a-4f0c-49db-b5d8-6e4987b868eb___Com.G_SpM_FL 1729_180deg.JPG
#                     0f75930a-4f0c-49db-b5d8-6e4987b868eb___Com.G_SpM_FL 1729_flipTB.JPG
#                     0f94b000-c54f-45c1-b976-22cb57dda0c4___Com.G_SpM_FL 9640_180deg.JPG
#                     0f94b000-c54f-45c1-b976-22cb57dda0c4___Com.G_SpM_FL 9640_flipTB.JPG
#                     0fb21160-9113-4c5a-b1d4-7001b5253bb9___Com.G_SpM_FL 8790.JPG
#                     0fb21160-9113-4c5a-b1d4-7001b5253bb9___Com.G_SpM_FL 8790_180deg.JPG
#                     0fb21160-9113-4c5a-b1d4-7001b5253bb9___Com.G_SpM_FL 8790_flipTB.JPG
#                     1001f133-ff3e-48de-b288-5a3802d9f3e1___Com.G_SpM_FL 8621.JPG
#                     1030a8ae-d4f2-4a36-aac9-c5ca40e5ec03___Com.G_SpM_FL 9295.JPG
#                     105833d3-690a-44fa-abd7-0a8c6245f7b0___Com.G_SpM_FL 1277.JPG
#                     10742761-050e-4a3b-b3ef-cbbde8cd6d2a___Com.G_SpM_FL 8445.JPG
#                     10e51f80-5ecc-4780-81ee-5d9db5aa4e53___Com.G_SpM_FL 9408.JPG
#                     11337458-8442-4322-b615-31a57e7a8323___Com.G_SpM_FL 8840.JPG
#                     113fe47e-6d5e-47da-8653-63095a9743c8___Com.G_SpM_FL 9610.JPG
#                     11ba6d63-4c6e-4a3f-acd9-18567bab6ab9___Com.G_SpM_FL 1728.JPG
#                     12019ba6-405d-45b7-b0e6-5a6a665de0e7___Com.G_SpM_FL 8624.JPG
#                     12166ab1-12f0-4480-8734-87f8164aa178___Com.G_SpM_FL 8951.JPG
#                     123223d5-ec90-4df4-8a65-e474c88fda19___Com.G_SpM_FL 1664.JPG
#                     125b13a4-60c6-4334-bee9-a92114a7252d___Com.G_SpM_FL 9590.JPG
#                     127da090-f2c3-4634-a798-58aeef092d77___Com.G_SpM_FL 1218.JPG
#                     127e63a5-631d-4d1a-8196-300d38e00069___Com.G_SpM_FL 1590.JPG
#                     128451c9-2ad2-44b3-8188-82ee11bcb6d5___Com.G_SpM_FL 1157.JPG
#                     129160ba-d6f0-434c-b399-735d61a39a16___Com.G_SpM_FL 8628.JPG
#                     12a4f265-5ed5-4818-be8a-5225f8043446___Com.G_SpM_FL 1554.JPG
#                     12bf81ae-5831-4823-b791-64c6f2372fd4___Com.G_SpM_FL 8558.JPG
#                     1384ca63-9181-4245-b7ab-7a1f0fec34a8___Com.G_SpM_FL 9269.JPG
#                     140136da-2b1c-4a29-b984-31e693c10d1c___Com.G_SpM_FL 9442.JPG
#                     141ec6e2-9ff8-436c-9d18-9edb8b26d861___Com.G_SpM_FL 8644.JPG
#                     1425cd68-8978-4811-b591-5154974458d2___Com.G_SpM_FL 8435.JPG
#                     145e34a6-1cd6-4ac0-9091-9fa175effb81___Com.G_SpM_FL 1287.JPG
#                     145f452c-a852-4fcc-8c81-d59165ecb774___Com.G_SpM_FL 8776.JPG
#                     149e2f8c-8527-4d6b-b661-a2c1324b1fd0___Com.G_SpM_FL 1634.JPG
#                     14c0db1b-b549-4b15-82ae-9f88fe857365___Com.G_SpM_FL 9650.JPG
#                     151b5158-4ae7-42b7-bfa0-fcd68bb2167d___Com.G_SpM_FL 1524.JPG
#                     159ef3ee-ef23-4df6-b3bc-a7a8bc01aaa0___Com.G_SpM_FL 8921.JPG
#                     15bb3ac6-73b8-4e56-b70b-1bf53fdc6dba___Com.G_SpM_FL 1568.JPG
#                     15cbb6e3-420d-464c-a2e0-12ffffb68cd2___Com.G_SpM_FL 9328.JPG
#                     15f6c5bf-d689-4ffd-a27f-821c0517224c___Com.G_SpM_FL 1591.JPG
#                     16826b8c-034f-4db2-bd96-db82b5b26c67___Com.G_SpM_FL 1551.JPG
#                     1687e54f-583f-4ecb-9b63-c36ea438baba___Com.G_SpM_FL 9577.JPG
#                     16ce6128-f485-4bbf-9cf5-8cab2e872dbe___Com.G_SpM_FL 9342.JPG
#                     16d4c4ec-274a-4b5e-bfa3-6a40f90b46da___Com.G_SpM_FL 9465.JPG
#                     1744606c-1817-494d-bb7c-6ea74c9f07ec___Com.G_SpM_FL 8770.JPG
#                     174d0b38-319e-465d-bdaa-4e32693d0e91___Com.G_SpM_FL 1221.JPG
#                     1767a6b2-2764-49a1-b774-3c411337bb63___Com.G_SpM_FL 1201.JPG
#                     17f512bf-921f-4c9e-bc1d-24a330e5dd75___Com.G_SpM_FL 8527.JPG
#                     185427fc-b158-483e-8bbf-3579fc49c8dc___Com.G_SpM_FL 1428.JPG
#                     18663563-6c5e-43f0-bed8-72e7c9adc3ee___Com.G_SpM_FL 8831.JPG
#                     187be065-ec6f-4e93-a647-e7385dca9272___Com.G_SpM_FL 9305.JPG
#                     192b37de-023d-4075-a525-397353e8c93c___Com.G_SpM_FL 1690.JPG
#                     1954b3c0-6f93-40ee-9618-4efafe5d7b87___Com.G_SpM_FL 8961.JPG
#                     19cb71ea-49b7-4373-8a6b-1c8b1bf630a1___Com.G_SpM_FL 1536.JPG
#                     19cc2f74-637b-40be-9b94-615c0e0316c3___Com.G_SpM_FL 1544.JPG
#                     19e981b0-9509-4564-8ece-284d1f6b497d___Com.G_SpM_FL 1288.JPG
#                     19ee147b-41b2-424b-b532-00ff31316109___Com.G_SpM_FL 1708.JPG
#                     1b184d8e-69bf-4af8-bdb5-22f477d587c0___Com.G_SpM_FL 8993.JPG
#                     1b184d8e-69bf-4af8-bdb5-22f477d587c0___Com.G_SpM_FL 8993_180deg.JPG
#                     1b184d8e-69bf-4af8-bdb5-22f477d587c0___Com.G_SpM_FL 8993_flipTB.JPG
#                     1b43c451-503f-446e-9e31-dcfd3544fbcd___Com.G_SpM_FL 1245.JPG
#                     1b43c451-503f-446e-9e31-dcfd3544fbcd___Com.G_SpM_FL 1245_180deg.JPG
#                     1b43c451-503f-446e-9e31-dcfd3544fbcd___Com.G_SpM_FL 1245_flipTB.JPG
#                     1b50c39d-8e8c-4d76-be2d-9d2c43cf09a6___Com.G_SpM_FL 8793.JPG
#                     1b50c39d-8e8c-4d76-be2d-9d2c43cf09a6___Com.G_SpM_FL 8793_180deg.JPG
#                     1b51a575-adbd-406b-8371-754b6009e7fb___Com.G_SpM_FL 1769_flipTB.JPG
#                     1b9607e3-1eec-4a0f-876b-f7923515b7e6___Com.G_SpM_FL 9288.JPG
#                     1b9607e3-1eec-4a0f-876b-f7923515b7e6___Com.G_SpM_FL 9288_180deg.JPG
#                     1b9607e3-1eec-4a0f-876b-f7923515b7e6___Com.G_SpM_FL 9288_flipTB.JPG
#                     1ba7b39c-c687-42da-b283-edf7a03b17b7___Com.G_SpM_FL 9484.JPG
#                     1ba7b39c-c687-42da-b283-edf7a03b17b7___Com.G_SpM_FL 9484_180deg.JPG
#                     1bb271cf-e12d-4536-a164-9a6a87002cd0___Com.G_SpM_FL 1593.JPG
#                     1bb271cf-e12d-4536-a164-9a6a87002cd0___Com.G_SpM_FL 1593_180deg.JPG
#                     1bb271cf-e12d-4536-a164-9a6a87002cd0___Com.G_SpM_FL 1593_flipTB.JPG
#                     1bbcbd22-5959-4ae4-a044-85f81a1a02dd___Com.G_SpM_FL 9319.JPG
#                     1bbcbd22-5959-4ae4-a044-85f81a1a02dd___Com.G_SpM_FL 9319_180deg.JPG
#                     1bbcbd22-5959-4ae4-a044-85f81a1a02dd___Com.G_SpM_FL 9319_flipTB.JPG
#                     1beb7ab1-cb7c-4a42-a5d7-16a643c81100___Com.G_SpM_FL 9563.JPG
#                     1beb7ab1-cb7c-4a42-a5d7-16a643c81100___Com.G_SpM_FL 9563_180deg.JPG
#                     1beb7ab1-cb7c-4a42-a5d7-16a643c81100___Com.G_SpM_FL 9563_flipTB.JPG
#                     1c4723cd-8ef6-483d-ae4e-8a3112fd9766___Com.G_SpM_FL 9506.JPG
#                     1c4723cd-8ef6-483d-ae4e-8a3112fd9766___Com.G_SpM_FL 9506_180deg.JPG
#                     1c4723cd-8ef6-483d-ae4e-8a3112fd9766___Com.G_SpM_FL 9506_flipTB.JPG
#                     1c4ea24a-8e30-4fde-8ff3-32c9bbe4b432___Com.G_SpM_FL 1448.JPG
#                     1c4ea24a-8e30-4fde-8ff3-32c9bbe4b432___Com.G_SpM_FL 1448_180deg.JPG
#                     1d1c9133-33c7-476d-a358-8699d5de8e1d___Com.G_SpM_FL 8915.JPG
#                     1d1c9133-33c7-476d-a358-8699d5de8e1d___Com.G_SpM_FL 8915_180deg.JPG
#                     1d34e045-0cee-4bea-bd14-3a60de7c255e___Com.G_SpM_FL 1312.JPG
#                     1d34e045-0cee-4bea-bd14-3a60de7c255e___Com.G_SpM_FL 1312_180deg.JPG
#                     1d7350c2-9ca5-42c8-89bd-6c6f94dd6459___Com.G_SpM_FL 8803_180deg.JPG
#                     1d7350c2-9ca5-42c8-89bd-6c6f94dd6459___Com.G_SpM_FL 8803_flipTB.JPG
#                     1d7a6c32-da22-42a0-8dca-85b758836bc6___Com.G_SpM_FL 1452.JPG
#                     1d7a6c32-da22-42a0-8dca-85b758836bc6___Com.G_SpM_FL 1452_180deg.JPG
#                     1d7a6c32-da22-42a0-8dca-85b758836bc6___Com.G_SpM_FL 1452_flipTB.JPG
#                     1d7bff81-b441-4f32-8cc0-85dd50b79cf3___Com.G_SpM_FL 1443.JPG
#                     1d7bff81-b441-4f32-8cc0-85dd50b79cf3___Com.G_SpM_FL 1443_180deg.JPG
#                     1d7bff81-b441-4f32-8cc0-85dd50b79cf3___Com.G_SpM_FL 1443_flipTB.JPG
#                     1da21007-3d29-487f-b839-e835993f20d2___Com.G_SpM_FL 1389.JPG
#                     1da21007-3d29-487f-b839-e835993f20d2___Com.G_SpM_FL 1389_180deg.JPG
#                     1dac8b31-ebbc-4ff5-965c-19f58c368e9e___Com.G_SpM_FL 8843.JPG
#                     1dac8b31-ebbc-4ff5-965c-19f58c368e9e___Com.G_SpM_FL 8843_180deg.JPG
#                     1dba797c-45b1-4509-8326-753cf2cf7ebe___Com.G_SpM_FL 8515.JPG
#                     1dba797c-45b1-4509-8326-753cf2cf7ebe___Com.G_SpM_FL 8515_flipTB.JPG
#                     1dd207c1-1fbe-454a-b63f-8051bb26aea8___Com.G_SpM_FL 1161.JPG
#                     1dd207c1-1fbe-454a-b63f-8051bb26aea8___Com.G_SpM_FL 1161_180deg.JPG
#                     1dd207c1-1fbe-454a-b63f-8051bb26aea8___Com.G_SpM_FL 1161_flipTB.JPG
#                     1dde88ff-2897-4181-834f-e3629e3cd12c___Com.G_SpM_FL 9560_180deg.JPG
#                     1e06dafa-f977-4354-992e-3271f34a2344___Com.G_SpM_FL 9601.JPG
#                     1e06dafa-f977-4354-992e-3271f34a2344___Com.G_SpM_FL 9601_flipTB.JPG
#                     1e09bb35-ef0d-4efb-b3eb-320a976a5e13___Com.G_SpM_FL 1529.JPG
#                     1e09bb35-ef0d-4efb-b3eb-320a976a5e13___Com.G_SpM_FL 1529_180deg.JPG
#                     1e09bb35-ef0d-4efb-b3eb-320a976a5e13___Com.G_SpM_FL 1529_flipTB.JPG
#                     1e0e0b1b-bc70-486b-9d85-f6e3ca348516___Com.G_SpM_FL 1285.JPG
#                     1e0e0b1b-bc70-486b-9d85-f6e3ca348516___Com.G_SpM_FL 1285_180deg.JPG
#                     1e0febc9-f544-45bb-9a39-69722d288393___Com.G_SpM_FL 1578.JPG
#                     1e0febc9-f544-45bb-9a39-69722d288393___Com.G_SpM_FL 1578_180deg.JPG
#                     1e0febc9-f544-45bb-9a39-69722d288393___Com.G_SpM_FL 1578_flipTB.JPG
#                     1e2f0007-3bba-4d4c-b533-879a2be8ac04___Com.G_SpM_FL 9603_180deg.JPG
#                     1e2f0007-3bba-4d4c-b533-879a2be8ac04___Com.G_SpM_FL 9603_flipTB.JPG
#                     1e802d57-3ff5-4527-8c9a-b1b764d6ccc9___Com.G_SpM_FL 1522_180deg.JPG
#                     1ea67ad6-cd45-45f3-a5a0-30474042f0fc___Com.G_SpM_FL 9389.JPG
#                     1ea67ad6-cd45-45f3-a5a0-30474042f0fc___Com.G_SpM_FL 9389_180deg.JPG
#                     1ea67ad6-cd45-45f3-a5a0-30474042f0fc___Com.G_SpM_FL 9389_flipTB.JPG
#                     1efb352f-b742-4654-a61d-bd9d8f38049b___Com.G_SpM_FL 8638.JPG
#                     1efb352f-b742-4654-a61d-bd9d8f38049b___Com.G_SpM_FL 8638_180deg.JPG
#                     1efb352f-b742-4654-a61d-bd9d8f38049b___Com.G_SpM_FL 8638_flipTB.JPG
#                     1f100e65-f5ab-4991-8665-f9fb28f5c0e2___Com.G_SpM_FL 1179.JPG
#                     1f100e65-f5ab-4991-8665-f9fb28f5c0e2___Com.G_SpM_FL 1179_180deg.JPG
#                     1f100e65-f5ab-4991-8665-f9fb28f5c0e2___Com.G_SpM_FL 1179_flipTB.JPG
#                     1f3c081d-ddf4-48f7-884b-08b3a5b3ae0a___Com.G_SpM_FL 1307.JPG
#                     1f3c081d-ddf4-48f7-884b-08b3a5b3ae0a___Com.G_SpM_FL 1307_flipTB.JPG
#                     1f79e619-5551-4d1e-b5f9-9f097781a967___Com.G_SpM_FL 8451.JPG
#                     1f79e619-5551-4d1e-b5f9-9f097781a967___Com.G_SpM_FL 8451_flipTB.JPG
#                     1fd449fe-904b-4df4-bdb1-a6b5c701efab___Com.G_SpM_FL 9346.JPG
#                     1fd449fe-904b-4df4-bdb1-a6b5c701efab___Com.G_SpM_FL 9346_180deg.JPG
#                     1fd449fe-904b-4df4-bdb1-a6b5c701efab___Com.G_SpM_FL 9346_flipTB.JPG
#                     1ff30221-d082-4dd3-ab7b-0028ecf897db___Com.G_SpM_FL 9608.JPG
#                     1ff30221-d082-4dd3-ab7b-0028ecf897db___Com.G_SpM_FL 9608_flipTB.JPG
#                     2028bc26-062e-4113-923e-7e0f7b47ad6b___Com.G_SpM_FL 9461.JPG
#                     20630492-00f2-4da5-bda0-97c3a0bbdcc8___Com.G_SpM_FL 1150.JPG
#                     207097b4-b76a-41dc-b80f-db4f2c9f2616___Com.G_SpM_FL 1408.JPG
#                     208a5b88-1c05-4cdb-b43b-aacc6ee5647d___Com.G_SpM_FL 9280.JPG
#                     20dcc445-3179-4092-8083-0c55be8e9579___Com.G_SpM_FL 1698.JPG
#                     20f78207-e650-4e62-8648-f660f5f1eea9___Com.G_SpM_FL 9340.JPG
#                     2141c98c-1ff5-405e-9fe7-06dd14099edc___Com.G_SpM_FL 8984.JPG
#                     217c69cd-121a-4993-8537-904fa4de4d55___Com.G_SpM_FL 8807.JPG
#                     2191359a-e985-4bf9-abe2-8f4e00685701___Com.G_SpM_FL 9645.JPG
#                     21941596-620a-443c-97f9-cf4c98a4e3c5___Com.G_SpM_FL 1581.JPG
#                     21f453e9-2c35-42f3-9f9f-2a0bedee16d0___Com.G_SpM_FL 1513.JPG
#                     22219bbe-58a4-4818-b080-05ac837ef496___Com.G_SpM_FL 1261.JPG
#                     222f7028-4365-4d2e-ba07-aeb02d58f3f3___Com.G_SpM_FL 8636.JPG
#                     22372e33-7f94-48f7-b394-421d1489328a___Com.G_SpM_FL 8697.JPG
#                     2252552c-aa8f-45a4-8c26-f79fa3febf9d___Com.G_SpM_FL 8955.JPG
#                     229fce20-a0a8-4a8a-b321-b067c4565bd6___Com.G_SpM_FL 1254.JPG
#                     22b23f84-bbc6-4089-8b83-02d62411f525___Com.G_SpM_FL 8600.JPG
#                     230070e0-c6a3-497a-8e3a-77831300087d___Com.G_SpM_FL 1403.JPG
#                     2305cbc5-4e95-4258-810d-e68e7a58b6f2___Com.G_SpM_FL 1454.JPG
#                     2323078c-6ad7-4135-8310-e4bc33be299d___Com.G_SpM_FL 9647.JPG
#                     2339bb0d-0389-46c0-9c13-dd5689506143___Com.G_SpM_FL 8516.JPG
#                     23977dea-f6c3-4d90-b3bd-f6e55d41938f___Com.G_SpM_FL 1766.JPG
#                     23e37ceb-929f-43ad-86fb-7bb3b9b97820___Com.G_SpM_FL 9297.JPG
#                     23e686ff-5f19-4bda-a1f5-b66aa15b48ad___Com.G_SpM_FL 1773.JPG
#                     2451545c-3a36-49ad-ad97-b81008d9e198___Com.G_SpM_FL 1654.JPG
#                     245d8d65-da20-4d9e-9970-c3e6bbb08800___Com.G_SpM_FL 9624.JPG
#                     2482ef02-b513-41ee-95df-81ae24ef55dd___Com.G_SpM_FL 8562.JPG
#                     24fa8aac-1c5b-4bf4-81e1-be5d658e1838___Com.G_SpM_FL 9602.JPG
#                     256f372d-a298-423d-87b4-dc1019516864___Com.G_SpM_FL 1352.JPG
#                     25942223-0e8b-43f0-af12-f156ff075486___Com.G_SpM_FL 1560.JPG
#                     25e772ed-0fc2-437d-b573-5edd92bf441e___Com.G_SpM_FL 8559.JPG
#                     264feee4-5e1c-4bd4-94d8-7b27da8940d7___Com.G_SpM_FL 1613.JPG
#                     26a363c9-aa30-4e63-bdec-cc26f273656b___Com.G_SpM_FL 1351.JPG
#                     26f7efac-d767-41bd-8c47-1a6bc6928f5e___Com.G_SpM_FL 9657.JPG
#                     27074def-852f-45c0-8a45-006f8f7108c3___Com.G_SpM_FL 9633.JPG
#                     27616b26-feaf-41dd-8e23-b0c493c7a2fa___Com.G_SpM_FL 8748.JPG
#                     27644d9c-5518-4df3-9391-16bc2cba20f8___Com.G_SpM_FL 1741.JPG
#                     27e28fcf-bc3e-4c0e-96c7-a0d845064dc2___Com.G_SpM_FL 8478.JPG
#                     27eae93a-d090-4c95-9812-366f9b761b72___Com.G_SpM_FL 9279.JPG
#                     2885962a-dc26-4951-a934-34c726bc32a5___Com.G_SpM_FL 8657.JPG
#                     28bf7171-b342-4e85-95f9-bef10104b93e___Com.G_SpM_FL 1652.JPG
#                     28dbca1c-1fc6-4d8f-a1b9-c81314280954___Com.G_SpM_FL 1249.JPG
#                     28e17f4d-3d61-4a61-9be7-71aafd78864b___Com.G_SpM_FL 9312.JPG
#                     293ff774-ec52-4d5e-bc01-f7ca230b94b5___Com.G_SpM_FL 9656.JPG
#                     2960d2b0-5db9-4112-89f6-c7c0d2f01b97___Com.G_SpM_FL 8806.JPG
#                     298f6d1d-401b-498a-9909-a0e53ba0424c___Com.G_SpM_FL 8940.JPG
#                     29919d99-e33e-43f0-b313-73eef0221636___Com.G_SpM_FL 1673.JPG
#                     29e1db02-d6da-4972-a466-7ef0c2fdd2a1___Com.G_SpM_FL 9393.JPG
#                     29e4107d-ab5d-462f-bfe9-d4f440e899fb___Com.G_SpM_FL 1538.JPG
#                     2a1b18db-6bbb-4c36-ad06-bf0fcaa5c4b8___Com.G_SpM_FL 1418.JPG
#                     2a1b18db-6bbb-4c36-ad06-bf0fcaa5c4b8___Com.G_SpM_FL 1418_180deg.JPG
#                     2a1b18db-6bbb-4c36-ad06-bf0fcaa5c4b8___Com.G_SpM_FL 1418_flipTB.JPG
#                     2a686a22-3384-43b6-a0e1-4b176ebde206___Com.G_SpM_FL 9635_180deg.JPG
#                     2a686a22-3384-43b6-a0e1-4b176ebde206___Com.G_SpM_FL 9635_flipTB.JPG
#                     2a6aa96a-1916-4d47-932a-9eda7ca46c91___Com.G_SpM_FL 8497_180deg.JPG
#                     2a70c9e6-2c2f-4355-94fb-02afc8141be5___Com.G_SpM_FL 8877.JPG
#                     2a70c9e6-2c2f-4355-94fb-02afc8141be5___Com.G_SpM_FL 8877_flipTB.JPG
#                     2aa0254f-e3c8-400f-bb0c-c039f19f4aa5___Com.G_SpM_FL 1649.JPG
#                     2aa0254f-e3c8-400f-bb0c-c039f19f4aa5___Com.G_SpM_FL 1649_180deg.JPG
#                     2aa0254f-e3c8-400f-bb0c-c039f19f4aa5___Com.G_SpM_FL 1649_flipTB.JPG
#                     2ac9a09c-b68a-4dba-a5c9-ae740fc9b8d4___Com.G_SpM_FL 9651_180deg.JPG
#                     2ac9a09c-b68a-4dba-a5c9-ae740fc9b8d4___Com.G_SpM_FL 9651_flipTB.JPG
#                     2ae5364f-20a9-46e9-8ca8-e47710c50446___Com.G_SpM_FL 1295.JPG
#                     2ae5364f-20a9-46e9-8ca8-e47710c50446___Com.G_SpM_FL 1295_180deg.JPG
#                     2ae5364f-20a9-46e9-8ca8-e47710c50446___Com.G_SpM_FL 1295_flipTB.JPG
#                     2af7c6b3-d37c-4f2f-9129-ea679437740c___Com.G_SpM_FL 8545.JPG
#                     2b47c565-c37a-4bdb-baa9-b3721dbf9bb6___Com.G_SpM_FL 9326.JPG
#                     2b47c565-c37a-4bdb-baa9-b3721dbf9bb6___Com.G_SpM_FL 9326_180deg.JPG
#                     2b47c565-c37a-4bdb-baa9-b3721dbf9bb6___Com.G_SpM_FL 9326_flipTB.JPG
#                     2b86b68a-c9a0-4b37-82b6-667de062f30f___Com.G_SpM_FL 8580.JPG
#                     2b86b68a-c9a0-4b37-82b6-667de062f30f___Com.G_SpM_FL 8580_180deg.JPG
#                     2b86b68a-c9a0-4b37-82b6-667de062f30f___Com.G_SpM_FL 8580_flipTB.JPG
#                     2b92d125-cf19-499f-9987-9579b0ba695b___Com.G_SpM_FL 8591.JPG
#                     2b92d125-cf19-499f-9987-9579b0ba695b___Com.G_SpM_FL 8591_180deg.JPG
#                     2b92d125-cf19-499f-9987-9579b0ba695b___Com.G_SpM_FL 8591_flipTB.JPG
#                     2bc44ebe-0c50-4e13-b174-c7af34098ed9___Com.G_SpM_FL 9399_flipTB.JPG
#                     2c0e3e42-3856-46e3-b12f-57719eeb5ef4___Com.G_SpM_FL 9598.JPG
#                     2c0e3e42-3856-46e3-b12f-57719eeb5ef4___Com.G_SpM_FL 9598_flipTB.JPG
#                     2c2f7f98-8c5b-4981-bb74-f827c5f963fe___Com.G_SpM_FL 8734.JPG
#                     2c2f7f98-8c5b-4981-bb74-f827c5f963fe___Com.G_SpM_FL 8734_180deg.JPG
#                     2c2f7f98-8c5b-4981-bb74-f827c5f963fe___Com.G_SpM_FL 8734_flipTB.JPG
#                     2c3edf31-5e58-4122-a909-be004063db57___Com.G_SpM_FL 8839_180deg.JPG
#                     2c3edf31-5e58-4122-a909-be004063db57___Com.G_SpM_FL 8839_flipTB.JPG
#                     2cd8d4c9-6eb7-4ed2-808f-df3ae1aedf7a___Com.G_SpM_FL 9621.JPG
#                     2cd8d4c9-6eb7-4ed2-808f-df3ae1aedf7a___Com.G_SpM_FL 9621_flipTB.JPG
#                     2cf7009e-f40f-4903-9571-84784d637e7a___Com.G_SpM_FL 1328.JPG
#                     2cf7009e-f40f-4903-9571-84784d637e7a___Com.G_SpM_FL 1328_flipTB.JPG
#                     2cfa680e-a8f9-43b5-856d-cb8fe9607a73___Com.G_SpM_FL 9334.JPG
#                     2cfa680e-a8f9-43b5-856d-cb8fe9607a73___Com.G_SpM_FL 9334_180deg.JPG
#                     2cfa680e-a8f9-43b5-856d-cb8fe9607a73___Com.G_SpM_FL 9334_flipTB.JPG
#                     2d0b5528-6c40-4881-9b9d-bd2cb06a2831___Com.G_SpM_FL 1200.JPG
#                     2d0b5528-6c40-4881-9b9d-bd2cb06a2831___Com.G_SpM_FL 1200_180deg.JPG
#                     2d0b5528-6c40-4881-9b9d-bd2cb06a2831___Com.G_SpM_FL 1200_flipTB.JPG
#                     2d213315-0896-4c0b-92a6-f7d84b17775f___Com.G_SpM_FL 8884.JPG
#                     2d213315-0896-4c0b-92a6-f7d84b17775f___Com.G_SpM_FL 8884_180deg.JPG
#                     2d213315-0896-4c0b-92a6-f7d84b17775f___Com.G_SpM_FL 8884_flipTB.JPG
#                     2db25538-8655-4530-95e8-025d428e158c___Com.G_SpM_FL 9522.JPG
#                     2db25538-8655-4530-95e8-025d428e158c___Com.G_SpM_FL 9522_180deg.JPG
#                     2db25538-8655-4530-95e8-025d428e158c___Com.G_SpM_FL 9522_flipTB.JPG
#                     2db5ec80-9a7d-4963-9aaa-24014848a087___Com.G_SpM_FL 8967.JPG
#                     2db5ec80-9a7d-4963-9aaa-24014848a087___Com.G_SpM_FL 8967_180deg.JPG
#                     2db5ec80-9a7d-4963-9aaa-24014848a087___Com.G_SpM_FL 8967_flipTB.JPG
#                     2deab6b3-44aa-4ea1-8b18-13b39117ca2d___Com.G_SpM_FL 8781.JPG
#                     2deab6b3-44aa-4ea1-8b18-13b39117ca2d___Com.G_SpM_FL 8781_180deg.JPG
#                     2deab6b3-44aa-4ea1-8b18-13b39117ca2d___Com.G_SpM_FL 8781_flipTB.JPG
#                     2e1daff5-2bc2-4c45-8563-7c6a7a929ddf___Com.G_SpM_FL 9261.JPG
#                     2e1daff5-2bc2-4c45-8563-7c6a7a929ddf___Com.G_SpM_FL 9261_flipTB.JPG
#                     2e41a813-b5a7-4501-bec2-e0f2db310a2c___Com.G_SpM_FL 9570.JPG
#                     2e41a813-b5a7-4501-bec2-e0f2db310a2c___Com.G_SpM_FL 9570_flipTB.JPG
#                     2e41d72c-c68b-44f1-8380-ece84ab98bfd___Com.G_SpM_FL 1727.JPG
#                     2e41d72c-c68b-44f1-8380-ece84ab98bfd___Com.G_SpM_FL 1727_flipTB.JPG
#                     2e9248a1-78c7-4aa8-a696-ab96c6947ceb___Com.G_SpM_FL 8629.JPG
#                     2e9248a1-78c7-4aa8-a696-ab96c6947ceb___Com.G_SpM_FL 8629_180deg.JPG
#                     2e9248a1-78c7-4aa8-a696-ab96c6947ceb___Com.G_SpM_FL 8629_flipTB.JPG
#                     2eacde8c-c10b-4768-b5f8-9405673cd19b___Com.G_SpM_FL 1188.JPG
#                     2eacde8c-c10b-4768-b5f8-9405673cd19b___Com.G_SpM_FL 1188_180deg.JPG
#                     2ec0c679-521d-455f-8741-067470353fe3___Com.G_SpM_FL 8795.JPG
#                     2ec0c679-521d-455f-8741-067470353fe3___Com.G_SpM_FL 8795_180deg.JPG
#                     2ec0c679-521d-455f-8741-067470353fe3___Com.G_SpM_FL 8795_flipTB.JPG
#                     2f286777-f4b0-4b89-9d29-8942267199dd___Com.G_SpM_FL 1515.JPG
#                     2f286777-f4b0-4b89-9d29-8942267199dd___Com.G_SpM_FL 1515_180deg.JPG
#                     2f44f20c-6c77-439b-9528-f5ab5242dd4d___Com.G_SpM_FL 1483_180deg.JPG
#                     2f44f20c-6c77-439b-9528-f5ab5242dd4d___Com.G_SpM_FL 1483_flipTB.JPG
#                     2f577458-6085-4b56-9291-56a902c577d4___Com.G_SpM_FL 1466.JPG
#                     2f577458-6085-4b56-9291-56a902c577d4___Com.G_SpM_FL 1466_180deg.JPG
#                     2f577458-6085-4b56-9291-56a902c577d4___Com.G_SpM_FL 1466_flipTB.JPG
#                     2fad548e-ff9d-4f86-9831-3ce68a76da57___Com.G_SpM_FL 1203.JPG
#                     2fad548e-ff9d-4f86-9831-3ce68a76da57___Com.G_SpM_FL 1203_180deg.JPG
#                     2fad548e-ff9d-4f86-9831-3ce68a76da57___Com.G_SpM_FL 1203_flipTB.JPG
#                     2fb77f60-ae5b-40c4-b6fb-3c90ac55ccd4___Com.G_SpM_FL 9367_180deg.JPG
#                     2fb77f60-ae5b-40c4-b6fb-3c90ac55ccd4___Com.G_SpM_FL 9367_flipTB.JPG
#                     2fd0efb7-d0fd-4c57-ba78-8e6a3fc5e149___Com.G_SpM_FL 8926.JPG
#                     2fd0efb7-d0fd-4c57-ba78-8e6a3fc5e149___Com.G_SpM_FL 8926_flipTB.JPG
#                     2ff25000-2715-471d-bb1d-50af786bc8f6___Com.G_SpM_FL 8814.JPG
#                     2ff25000-2715-471d-bb1d-50af786bc8f6___Com.G_SpM_FL 8814_180deg.JPG
#                     2ff25000-2715-471d-bb1d-50af786bc8f6___Com.G_SpM_FL 8814_flipTB.JPG
#                     301b8b4c-f7d4-4626-b527-9f01cec643cf___Com.G_SpM_FL 8643.JPG
#                     301d485a-0ee5-46a8-89fd-30f8165dae18___Com.G_SpM_FL 8510.JPG
#                     3046afbf-4a9a-41fb-a64f-3f9e75af08e7___Com.G_SpM_FL 1623.JPG
#                     3049a6ad-905d-4a96-92b4-2ec045c397a1___Com.G_SpM_FL 8796.JPG
#                     305d5fd0-b63c-41d3-9980-9c6aa808b893___Com.G_SpM_FL 8473.JPG
#                     312bee2d-2595-4d86-992f-cca44dbaad4a___Com.G_SpM_FL 9492.JPG
#                     3156e176-2697-4be0-8cc7-37ce05aade4b___Com.G_SpM_FL 1431.JPG
#                     317f11f9-657f-43f7-943e-efb03cc62b40___Com.G_SpM_FL 1608.JPG
#                     31b90f40-9316-44a5-b582-a9229ac63f6d___Com.G_SpM_FL 1754.JPG
#                     31d8e0ad-c71a-47de-aa56-81a5f0910f0a___Com.G_SpM_FL 9291.JPG
#                     3203380e-f2a7-4111-8e27-3e935bc63a31___Com.G_SpM_FL 8593.JPG
#                     3237c6fb-59b2-404a-8cbc-81f5e61304d0___Com.G_SpM_FL 8611.JPG
#                     324bf28d-7005-4845-9931-012f2a972b37___Com.G_SpM_FL 1506.JPG
#                     326a53b6-1d92-475a-9a30-4fc70754eacf___Com.G_SpM_FL 8883.JPG
#                     326d232c-21f1-44c0-91a2-ce202460af8d___Com.G_SpM_FL 1360.JPG
#                     33292e63-5f81-40ef-b397-f749a1c49bbf___Com.G_SpM_FL 9515.JPG
#                     3331b5a5-229a-416e-9605-c279ec0cf414___Com.G_SpM_FL 1768.JPG
#                     333f0683-d52f-4bb8-a7ec-1c0f07164684___Com.G_SpM_FL 1147.JPG
#                     3359d10c-2afd-4734-8a71-d19d25a041a6___Com.G_SpM_FL 9016.JPG
#                     338b9a2f-bdba-40e5-a861-b354fbf3e468___Com.G_SpM_FL 8630.JPG
#                     33b4120c-378e-4902-a3e7-6411fc4f0a2a___Com.G_SpM_FL 1694.JPG
#                     33e0bed5-9b9e-46ba-9f85-42f86d6f06eb___Com.G_SpM_FL 9453.JPG
#                     33e59828-c8c1-40f8-a684-dc16fdfcd280___Com.G_SpM_FL 9510.JPG
#                     33f539bd-6537-4a8f-93da-8988cb092c56___Com.G_SpM_FL 1258.JPG
#                     340c0ead-05e3-4900-94c3-56bcba8293e6___Com.G_SpM_FL 9425.JPG
#                     3428e1fb-bc76-4492-9416-5e5e53658e45___Com.G_SpM_FL 9320.JPG
#                     3472596b-2763-4b57-a0af-43c294f7ba93___Com.G_SpM_FL 1575.JPG
#                     348aec86-49bc-4e2d-8ca7-66545421cc06___Com.G_SpM_FL 1746.JPG
#                     34dc951d-39ac-4456-8424-884d0b115170___Com.G_SpM_FL 9454.JPG
#                     34eec178-d8fe-4a7b-a1d0-c0b107a35964___Com.G_SpM_FL 9502.JPG
#                     34f4c44b-7e74-4b66-993a-27b2f7da9ab3___Com.G_SpM_FL 9604.JPG
#                     354777cd-2631-4633-a227-37a7c823a1e1___Com.G_SpM_FL 8727.JPG
#                     35b5d6a8-e3ef-4c39-86ce-25b4632e7cab___Com.G_SpM_FL 1176.JPG
#                     35be5750-5e23-472f-bfc1-2cb27687722d___Com.G_SpM_FL 1779.JPG
#                     35d2a711-e171-495c-b030-369f556b6db5___Com.G_SpM_FL 1450.JPG
#                     3621f0bd-8e40-4b1b-a6d4-23651e3b2dc2___Com.G_SpM_FL 8696.JPG
#                     365cd045-b802-4ab5-89a3-81dd5131f96b___Com.G_SpM_FL 1699.JPG
#                     36c530f3-b5e1-414b-ab82-198e8d66ebab___Com.G_SpM_FL 8460.JPG
#                     3737ae01-5cc2-4a6a-b373-b1fae745972d___Com.G_SpM_FL 8576.JPG
#                     3753178e-eee8-405a-93b3-8f34728d7210___Com.G_SpM_FL 9410.JPG
#                     37643f50-c651-4b66-863b-1c10aa4de541___Com.G_SpM_FL 9571.JPG
#                     37bf5166-693d-492b-b60e-4d76e3efca4c___Com.G_SpM_FL 1706.JPG
#                     3816382b-fc42-4661-b2fe-de651d2ca2ba___Com.G_SpM_FL 9294.JPG
#                     381feee3-bdda-4e1a-82f6-1ddd62152b63___Com.G_SpM_FL 1256.JPG
#                     3861fe05-3c70-4ca0-9729-30cbf67e475a___Com.G_SpM_FL 1564.JPG
#                     3893e563-9bd6-4df6-a8e5-1488a680bb8b___Com.G_SpM_FL 1572.JPG
#                     38be0c62-a8ce-49db-8187-294abc382ad6___Com.G_SpM_FL 8895.JPG
#                     38f3dbaa-0878-434a-ac6c-d558f6bb91a8___Com.G_SpM_FL 1206.JPG
#                     392c91dd-5517-4f68-a5c9-36f56e33d34e___Com.G_SpM_FL 1314.JPG
#                     39528564-9273-41d9-96d4-2170096eb649___Com.G_SpM_FL 8756.JPG
#                     3960b465-88b7-4198-97dd-42eaac16065f___Com.G_SpM_FL 8419.JPG
#                     39f1d7a1-98b3-48b8-91eb-3fed9bbbc6d4___Com.G_SpM_FL 1556.JPG
#                     3a190004-02f9-4284-9750-d12fe0272a6f___Com.G_SpM_FL 8922.JPG
#                     3a190004-02f9-4284-9750-d12fe0272a6f___Com.G_SpM_FL 8922_180deg.JPG
#                     3a190004-02f9-4284-9750-d12fe0272a6f___Com.G_SpM_FL 8922_flipTB.JPG
#                     3a2b3d76-060b-41c2-b6e5-44149f209b73___Com.G_SpM_FL 1321_180deg.JPG
#                     3a2b3d76-060b-41c2-b6e5-44149f209b73___Com.G_SpM_FL 1321_flipTB.JPG
#                     3a54bf13-626b-4d55-b445-127cc82a52a6___Com.G_SpM_FL 1243_flipTB.JPG
#                     3aad576c-3189-4b78-a5df-c9bac0078612___Com.G_SpM_FL 1430.JPG
#                     3aad576c-3189-4b78-a5df-c9bac0078612___Com.G_SpM_FL 1430_180deg.JPG
#                     3aad576c-3189-4b78-a5df-c9bac0078612___Com.G_SpM_FL 1430_flipTB.JPG
#                     3ad81dac-39c6-422a-95f9-1a7834d474ec___Com.G_SpM_FL 8913_flipTB.JPG
#                     3b12d772-00c3-4cf9-9e2f-25f6aa027790___Com.G_SpM_FL 1244_flipTB.JPG
#                     3b241fdb-8655-46c0-ad66-4010bca7c6f5___Com.G_SpM_FL 9017.JPG
#                     3b241fdb-8655-46c0-ad66-4010bca7c6f5___Com.G_SpM_FL 9017_180deg.JPG
#                     3b241fdb-8655-46c0-ad66-4010bca7c6f5___Com.G_SpM_FL 9017_flipTB.JPG
#                     3b26b807-0511-477d-92ff-5e84d0c4059a___Com.G_SpM_FL 8724.JPG
#                     3b26b807-0511-477d-92ff-5e84d0c4059a___Com.G_SpM_FL 8724_flipTB.JPG
#                     3b5769b2-b497-47de-9992-bc328452b1ee___Com.G_SpM_FL 8824_180deg.JPG
#                     3b5769b2-b497-47de-9992-bc328452b1ee___Com.G_SpM_FL 8824_flipTB.JPG
#                     3b62abc2-b01e-4a47-bc67-fd677a3840fe___Com.G_SpM_FL 8787_180deg.JPG
#                     3b62abc2-b01e-4a47-bc67-fd677a3840fe___Com.G_SpM_FL 8787_flipTB.JPG
#                     3b90769e-82f9-4b5f-93dd-6c2666f3c952___Com.G_SpM_FL 8924.JPG
#                     3b90769e-82f9-4b5f-93dd-6c2666f3c952___Com.G_SpM_FL 8924_flipTB.JPG
#                     3ba4c514-567a-4e4b-9d22-9cf2a957e906___Com.G_SpM_FL 1198.JPG
#                     3ba4c514-567a-4e4b-9d22-9cf2a957e906___Com.G_SpM_FL 1198_flipTB.JPG
#                     3bc0207a-406f-49e9-bf64-7082897ef2a4___Com.G_SpM_FL 1583_180deg.JPG
#                     3bc0207a-406f-49e9-bf64-7082897ef2a4___Com.G_SpM_FL 1583_flipTB.JPG
#                     3bcb18e7-7c44-4184-b02a-09eb04957be7___Com.G_SpM_FL 8943.JPG
#                     3bcb18e7-7c44-4184-b02a-09eb04957be7___Com.G_SpM_FL 8943_180deg.JPG
#                     3bcb18e7-7c44-4184-b02a-09eb04957be7___Com.G_SpM_FL 8943_flipTB.JPG
#                     3bf7ca2f-8ba9-4ec1-82a4-8e8b45bc7449___Com.G_SpM_FL 9564.JPG
#                     3bf7ca2f-8ba9-4ec1-82a4-8e8b45bc7449___Com.G_SpM_FL 9564_flipTB.JPG
#                     3c0df0a9-32f7-4f30-9b50-09aac666701e___Com.G_SpM_FL 8422.JPG
#                     3c0df0a9-32f7-4f30-9b50-09aac666701e___Com.G_SpM_FL 8422_180deg.JPG
#                     3c0df0a9-32f7-4f30-9b50-09aac666701e___Com.G_SpM_FL 8422_flipTB.JPG
#                     3c4379ee-ffcf-4387-bcc6-3e1bbb98c11e___Com.G_SpM_FL 9596.JPG
#                     3c4379ee-ffcf-4387-bcc6-3e1bbb98c11e___Com.G_SpM_FL 9596_180deg.JPG
#                     3c8199f8-aa54-47f8-9d70-1bf6cdd2e97b___Com.G_SpM_FL 9277.JPG
#                     3c8199f8-aa54-47f8-9d70-1bf6cdd2e97b___Com.G_SpM_FL 9277_180deg.JPG
#                     3c8199f8-aa54-47f8-9d70-1bf6cdd2e97b___Com.G_SpM_FL 9277_flipTB.JPG
#                     3ca50b98-7e7c-4164-b53f-abf3c28b513f___Com.G_SpM_FL 1740_180deg.JPG
#                     3ca50b98-7e7c-4164-b53f-abf3c28b513f___Com.G_SpM_FL 1740_flipTB.JPG
#                     3cf4bee8-cd23-461c-b1c4-1d857b37ad76___Com.G_SpM_FL 1223.JPG
#                     3cf4bee8-cd23-461c-b1c4-1d857b37ad76___Com.G_SpM_FL 1223_flipTB.JPG
#                     3d06d27e-cfea-40b4-ac55-9e0dc96f6b55___Com.G_SpM_FL 8596.JPG
#                     3d06d27e-cfea-40b4-ac55-9e0dc96f6b55___Com.G_SpM_FL 8596_180deg.JPG
#                     3d06d27e-cfea-40b4-ac55-9e0dc96f6b55___Com.G_SpM_FL 8596_flipTB.JPG
#                     3d240189-36f3-4468-be7e-c0db11af648b___Com.G_SpM_FL 1719.JPG
#                     3d240189-36f3-4468-be7e-c0db11af648b___Com.G_SpM_FL 1719_180deg.JPG
#                     3d240189-36f3-4468-be7e-c0db11af648b___Com.G_SpM_FL 1719_flipTB.JPG
#                     3d39341d-dbcb-4453-b193-c00d57af0fe9___Com.G_SpM_FL 1313.JPG
#                     3d39341d-dbcb-4453-b193-c00d57af0fe9___Com.G_SpM_FL 1313_180deg.JPG
#                     3d39341d-dbcb-4453-b193-c00d57af0fe9___Com.G_SpM_FL 1313_flipTB.JPG
#                     3d59267d-cf74-4354-a41c-d3f79783fcfd___Com.G_SpM_FL 8667.JPG
#                     3d59267d-cf74-4354-a41c-d3f79783fcfd___Com.G_SpM_FL 8667_180deg.JPG
#                     3d59267d-cf74-4354-a41c-d3f79783fcfd___Com.G_SpM_FL 8667_flipTB.JPG
#                     3d74d3e8-d946-4270-b762-19b0d1552351___Com.G_SpM_FL 1413.JPG
#                     3d74d3e8-d946-4270-b762-19b0d1552351___Com.G_SpM_FL 1413_180deg.JPG
#                     3d74d3e8-d946-4270-b762-19b0d1552351___Com.G_SpM_FL 1413_flipTB.JPG
#                     3d7b00e9-5e2b-4fa7-ae44-373b6f09dfe7___Com.G_SpM_FL 1393.JPG
#                     3d7b00e9-5e2b-4fa7-ae44-373b6f09dfe7___Com.G_SpM_FL 1393_flipTB.JPG
#                     3dcda958-8c55-4ef5-a7fa-f166bb69ad38___Com.G_SpM_FL 8582.JPG
#                     3dcda958-8c55-4ef5-a7fa-f166bb69ad38___Com.G_SpM_FL 8582_180deg.JPG
#                     3dcda958-8c55-4ef5-a7fa-f166bb69ad38___Com.G_SpM_FL 8582_flipTB.JPG
#                     3e20bc98-68a5-4afa-8a05-eb570630bfd4___Com.G_SpM_FL 1671.JPG
#                     3e20bc98-68a5-4afa-8a05-eb570630bfd4___Com.G_SpM_FL 1671_180deg.JPG
#                     3e20bc98-68a5-4afa-8a05-eb570630bfd4___Com.G_SpM_FL 1671_flipTB.JPG
#                     3e2da864-f81f-4cd7-8152-744782a3c7c2___Com.G_SpM_FL 8997.JPG
#                     3e2da864-f81f-4cd7-8152-744782a3c7c2___Com.G_SpM_FL 8997_180deg.JPG
# ...
#                     5b2457f5-96d5-4bcd-8025-dc55e666f660___RS_HL 0605.JPG
#                     5bded339-547a-4f93-b7cf-bbf8c948aa26___RS_HL 9748.JPG
#                     5c23afc6-7236-4f07-adcd-61b1f69e3fb2___RS_HL 9801.JPG
#                     5d11d60f-fb4a-4178-9594-d017a0f51b59___GH_HL Leaf 271.JPG
#                     5dd2a498-7eff-4da7-9c0f-8c394103e52c___RS_HL 0611.JPG
#                     5f67b4d4-4503-4149-950b-6cd08a20aaf8___RS_HL 9696.JPG
#                     5f8189f2-51cf-49b4-8a34-4955f26cf222___RS_HL 0352.JPG
#                     5faa74ba-8f46-4b2b-a7bf-3bc8d9458526___RS_HL 9741.JPG
#                     6270efe7-db0f-4953-a7c7-eb86bb8967dd___RS_HL 9761.JPG
#                     6555b55c-78bc-4391-88ed-65b596fc7e76___GH_HL Leaf 441.JPG
#                     66534b5a-a6b7-46bb-bc09-a6bba9d9a61a___GH_HL Leaf 225.2.JPG
#                     6883c31a-78b4-406a-9605-b6b31e0932cc___RS_HL 0037.JPG
#                     688c6cc1-16b4-4f4a-9491-afba5c8a64b6___GH_HL Leaf 347.JPG
#                     68e18442-2f1d-458d-b1ef-865c7390622c___RS_HL 9919.JPG
#                     68f66822-cde2-4a2c-b58e-a16900362a75___RS_HL 9674.JPG
#                     6a74d0a9-4a5e-4dc2-9e14-aeade8b0c3b2___GH_HL Leaf 400.1.JPG
#                     6b53630d-c9df-4e67-a490-b1835772d9a0___GH_HL Leaf 450.2.JPG
#                     6be1ec13-6964-4706-b94a-069d4a8592cf___GH_HL Leaf 175.1.JPG
#                     6c46af84-675e-4e35-8309-169c20ae8b62___RS_HL 0383.JPG
#                     6c5ad7e4-a826-40af-abf9-0a9e6346e656___RS_HL 0196.JPG
#                     6d4285ef-e3f2-4cd3-a873-efdd989cf1cb___RS_HL 0182.JPG
#                     6da1cf1b-a236-4d45-a390-dac6b65c45f7___GH_HL Leaf 264.JPG
#                     6dca3464-9e71-4edf-9ca5-746b5eebe418___GH_HL Leaf 352.JPG
#                     6e1abdb8-4020-48c9-9488-2d320e8d5a4d___RS_HL 0168.JPG
#                     6e41f26a-5ce7-4fba-9fb5-e6a886b55f75___GH_HL Leaf 230.JPG
#                     6e48af01-e836-4cdd-9b99-867d421c2ff3___RS_HL 9760.JPG
#                     6e583c78-1f36-4d5e-bc0e-24f3c76a2c1d___RS_HL 0284.JPG
#                     6fa01a78-0d8d-4ecf-b90f-4dbc2e89f2d9___RS_HL 0220.JPG
#                     6fc5b781-6757-459f-af96-09a67dbcb2bc___RS_HL 0607.JPG
#                     70097a25-88b2-4c9a-800b-5a978cdf4c7c___GH_HL Leaf 384.1.JPG
#                     7079935b-c669-47db-a6ae-5a12d9ccf9d7___GH_HL Leaf 331.1.JPG
#                     719352b5-1b4c-41e5-a517-3dfde18c13ef___RS_HL 0300.JPG
#                     71c4512d-05ba-456f-ba4e-f2861b7e7837___RS_HL 0390.JPG
#                     741595d0-322d-4711-9005-b1e39b9567c1___RS_HL 0491.JPG
#                     74579097-2dd7-4d15-8f73-f09e7d919b51___RS_HL 9773.JPG
#                     76284899-9c5e-44bf-a160-02649418ec49___RS_HL 0077.JPG
#                     776714ac-7a89-4449-bde9-9b9911f1a371___RS_HL 9886.JPG
#                     7a5fe2a0-ac85-4a37-b0f6-8cfc8fb21c9c___RS_HL 9865.JPG
#                     7b246e09-0a8c-4078-9e0a-6207de8dc804___RS_HL 9809.JPG
#                     7b93db88-7c70-444a-9096-1812426217f7___RS_HL 0167.JPG
#                     7ce1f8c1-1542-4d7b-be27-11e29d572283___GH_HL Leaf 508.2.JPG
#                     7f5c8018-c4c3-4471-aa30-defe910ea3d9___GH_HL Leaf 444.1.JPG
#                     7f80c0af-c88f-40ec-be87-14d7595248d8___RS_HL 9721.JPG
#                     809e36cd-8251-4fcf-854d-6b7bb2f41a64___RS_HL 0215.JPG
#                     81024038-40ff-40c4-b8f4-4a48b08032e4___RS_HL 0301.JPG
#                     81314c2b-1def-41c8-a6b4-1cd37d1e482a___RS_HL 0175.JPG
#                     81a4e19e-bbcd-4029-8a4f-ae97afe0cdcb___GH_HL Leaf 323.1.JPG
#                     82b63dfc-d0b6-4bb3-afc4-db8d61476b10___GH_HL Leaf 415.JPG
#                     84d5645b-619e-4882-a1d5-3a3abec47da3___RS_HL 0568.JPG
#                     870b4923-2db1-4e01-827b-fbea6ed404cb___RS_HL 0164.JPG
#                     878c1a99-3224-4b99-87e5-2a2c497909ca___GH_HL Leaf 274.JPG
#                     879b48e5-11f8-4989-8226-08af79bd6eb1___RS_HL 0453.JPG
#                     8811ef44-071b-430a-a0a4-989bf7668582___GH_HL Leaf 193.JPG
#                     89aa561a-1ea7-4e24-a92b-47f3dedcecdb___RS_HL 0107.JPG
#                     89ecd925-23ef-4bfe-8c55-cad05161aca2___GH_HL Leaf 236.1.JPG
#                     8a4cf703-385a-4c50-9ce2-a751ae6334e1___RS_HL 9963.JPG
#                     8c43c178-69de-4e23-a075-1f0bdbf586db___RS_HL 0637.JPG
#                     8d78a34f-1777-4bd8-a925-795c57c11787___GH_HL Leaf 429.1.JPG
#                     8f3da0fb-90a0-4eac-b065-822895c41c54___GH_HL Leaf 265.1.JPG
#                     912988d9-48b0-4a21-b3cd-1e136cbe5cc6___RS_HL 0629.JPG
#                     9299f3e8-15ee-4cf2-997a-058bb19900a5___RS_HL 9781.JPG
#                     933b7a1c-5015-48df-8c2d-b7fdf918a4db___GH_HL Leaf 490.1.JPG
#                     93e8763c-b124-48c4-bc46-df4d92625fa3___RS_HL 0261.JPG
#                     96d85e53-b980-42f7-8e3d-cd6f7ec9c287___GH_HL Leaf 520.5.JPG
#                     984d9db2-082d-446b-8991-870090c447bb___RS_HL 0274.JPG
#                     989dc406-c1db-4a9c-9cda-ae66f1288b9b___RS_HL 0032.JPG
#                     9a5d3900-8707-4088-8ec0-1fad45d8bd11___GH_HL Leaf 339.JPG
#                     9b0e031b-27c2-4c62-8923-ccc3ce5a4048___GH_HL Leaf 401.1.JPG
#                     9b668abb-fc96-412e-948f-442af45ec580___RS_HL 9972.JPG
#                     9d197d8a-3f35-401a-8aa4-39f7e69d05c5___GH_HL Leaf 326.JPG
#                     9d447b38-bd33-46f0-880b-324481fbae19___RS_HL 0366.JPG
#                     9dc940f8-cd79-4341-95ef-f845583d9dff___RS_HL 9751.JPG
#                     9dfa9d89-0a19-4e22-81c1-07c54a21f982___RS_HL 9768.JPG
#                     9e0cd9db-f893-4426-b195-5643b55e0a8d___RS_HL 0379.JPG
#                     9e43d49b-abbe-4b9b-8566-42586a58a705___RS_HL 0462.JPG
#                     9ee73ce8-ea9e-4a76-8b41-39500bdf3514___RS_HL 0110.JPG
#                     a05f8f2d-6ac6-45d8-b7ad-394bbda892fc___RS_HL 0613.JPG
#                     a0e83b60-008d-40b1-b0f4-c3c2e02d8eb3___RS_HL 0092.JPG
#                     a1414092-da7c-4e7e-9b25-6fb76e07285b___RS_HL 0247.JPG
#                     a1b90ce3-79b4-404d-a848-4471b793772f___RS_HL 0544.JPG
#                     a2118ec3-8434-4e93-8a4a-aa93262dfa76___RS_HL 0551.JPG
#                     a37b6334-5748-413a-9c7d-85c3ac8edee8___GH_HL Leaf 260.1.JPG
#                     a37f028b-6cb5-4557-8e5d-61b25830858c___RS_HL 0530.JPG
#                     a3e61ed6-3c67-48d7-af39-9a69b2c5c7bc___GH_HL Leaf 250.1.JPG
#                     a5e54e01-2cd5-482a-bfba-8728ca32473c___GH_HL Leaf 426.JPG
#                     a8036d3b-eda1-4309-b2ac-5a409963f4d7___RS_HL 9840.JPG
#                     a9c274c1-698c-4840-984b-8cb34e7ae97b___RS_HL 0224.JPG
#                     aa464ad5-f7d0-44ee-9042-fb4a4a64b7cd___RS_HL 9936.JPG
#                     aadb9f92-d885-4a69-a498-437b1edeab90___RS_HL 9959.JPG
#                     ab203172-45d2-492f-94e0-6d15a1d34209___RS_HL 9831.JPG
#                     ab43ead0-0a4c-4069-8c29-43310eb145e1___GH_HL Leaf 419.JPG
#                     abab2c83-54cb-4427-b239-7f55be4d7f78___RS_HL 9709.JPG
#                     ad270b53-60f2-4d27-8d7a-54d8f60f268b___RS_HL 0253.JPG
#                     af83b40a-8cac-4467-a44b-1a129b25e4fc___GH_HL Leaf 362.1.JPG
#                     afbedba8-4d3a-4816-9c55-bd666d262b59___RS_HL 9841.JPG
#                     b2deac55-9527-41dc-9b02-36097d4a8d21___RS_HL 0152.JPG
#                     b3e76dfe-eeb0-4edf-a93c-bb7964ff57eb___GH_HL Leaf 210.4.JPG
#                     b41196ab-88ea-4057-bf87-b1435d5a0d1d___GH_HL Leaf 258.1.JPG
#                     b66ce067-f338-4ae5-8f62-578ce164456a___RS_HL 0610.JPG
#                     b6fa2d79-dac1-42c6-a074-9d013843bb11___GH_HL Leaf 276.1.JPG
#                     b7e6f4d6-faa0-49a7-a977-53ddcaaa721e___RS_HL 0186.JPG
#                     b840daeb-319f-4cf3-b2a0-3010387fd5d3___GH_HL Leaf 493.JPG
#                     ba5a98fb-b13c-4984-984f-d05a60ad9dfb___RS_HL 9716.JPG
#                     ba6d8256-1d1e-4642-b7f1-8e0f220fb0a4___GH_HL Leaf 359.JPG
#                     bad3b814-de59-4c37-8f47-00ed153f7e4f___RS_HL 0214.JPG
#                     bb06c1c7-3f4d-45d0-8882-b2eb8861b834___GH_HL Leaf 372.JPG
#                     bb49e566-90cf-48c2-ae3a-83b7f362b703___RS_HL 0347.JPG
#                     bb8861fc-350e-49da-86aa-1b475a2d5442___GH_HL Leaf 325.JPG
#                     bc21b9df-de42-4899-991c-065035815af4___RS_HL 0569.JPG
#                     bc5e650e-075e-4359-9f31-79cd0ef3208b___RS_HL 9807.JPG
#                     bc825946-3ee5-4269-8ba4-202afc766654___RS_HL 0368.JPG
#                     bcf2a4c7-5e73-4443-b39c-74fd6895afb5___GH_HL Leaf 248.1.JPG
#                     bd531960-92ec-4745-9e25-645decb4b2b0___RS_HL 0542.JPG
#                     beaa693e-fa0d-4bde-943a-0a834f251301___RS_HL 0290.JPG
#                     bf0fa071-7128-4b45-b924-3c4b46fbf72f___RS_HL 9932.JPG
#                     c04a8a0a-2ab7-4494-9fa3-88aea29338d8___RS_HL 0015.JPG
#                     c14e3118-373b-4164-8f54-6c4239908d0f___GH_HL Leaf 488.JPG
#                     c1aad9bf-ed08-4cb9-9ef0-8c0d4a3de010___GH_HL Leaf 319.JPG
#                     c273003c-f52b-4a40-92f5-c1b8e9da53b7___RS_HL 0372.JPG
#                     c3dcca18-f12f-4a4d-a90c-563ded6c7df8___RS_HL 9691.JPG
#                     c4a30e2a-f520-4cdc-a58d-7ea1eb7c22e6___GH_HL Leaf 454.JPG
#                     c56b4a9c-dd6f-48ac-ac94-c4fbf6194031___GH_HL Leaf 364.1.JPG
#                     c5708e70-747e-44d9-ab7f-356157bfe0ec___RS_HL 9813.JPG
#                     c5db6d9e-4821-4b05-8b44-80ba702a8401___GH_HL Leaf 373.JPG
#                     c5f1eec0-35c2-43ce-8a14-575d86258f73___RS_HL 0337.JPG
#                     c7db2891-1bfa-4047-8864-66be6cc9e185___RS_HL 0162.JPG
#                     c7f91fa4-3769-45ef-a494-1669ee62ee7a___RS_HL 9812.JPG
#                     c8c7cb85-d7eb-4d60-b90e-bfe5277b79ad___GH_HL Leaf 277.JPG
#                     ca553e23-a738-485a-95e6-3b578477d3f4___RS_HL 9854.JPG
#                     ca6ad351-41f5-4893-8188-1c1c4b4184b4___GH_HL Leaf 496.4.JPG
#                     cb262ab1-f96f-4ade-80e9-d7fa2d5f9c9d___RS_HL 0361.JPG
#                     cb602835-7f6d-4926-80b4-77fe22f7ff66___GH_HL Leaf 226.JPG
#                     cdfe9df9-c3de-4660-8543-13911f281e47___RS_HL 0496.JPG
#                     ce081d63-8710-460f-9f20-cc67ef62fa37___RS_HL 9685.JPG
#                     ce303601-b655-483c-9778-3cbd317606be___RS_HL 0163.JPG
#                     ce56d8ec-bfd5-4755-8010-c42658f8d597___RS_HL 0090.JPG
#                     ce9cef60-51af-4e89-bbe7-bf463d767e99___RS_HL 0614.JPG
#                     ceb2bf82-b22d-43bb-9a32-cac11e19febd___RS_HL 0406.JPG
#                     cf021ef4-2bde-4984-8604-c813cb195fe4___RS_HL 0490.JPG
#                     cf4431f9-8b69-46dd-80fb-732f1a652027___RS_HL 0510.JPG
#                     d030352a-d87f-4ee2-a619-bc68d9896004___GH_HL Leaf 197.JPG
#                     d0d0643e-c7f1-4cf3-8399-cfd8a73d1af3___RS_HL 9650.JPG
#                     d21a242e-a9a3-4c5e-8e65-6416f84bcaec___GH_HL Leaf 510.2.JPG
#                     d2bab7ce-8028-41ed-b0a0-22472f904974___RS_HL 0528.JPG
#                     d38fc068-8503-4868-9c57-8fba55a7892d___RS_HL 0293.JPG
#                     d3997d9d-f607-44f2-9473-b41db6b1116b___GH_HL Leaf 473.JPG
#                     d454ff7e-7a9d-45c1-b7f1-d098edcb1fa7___RS_HL 0418.JPG
#                     d4fc1abf-fd0d-4625-9882-36acd3755ede___RS_HL 0307.JPG
#                     d53448cd-ddd7-4dd6-a657-c60bde629130___RS_HL 0190.JPG
#                     d578b8cd-9a1c-434b-9507-17ced7dffb34___GH_HL Leaf 249.JPG
#                     d5ccbb2a-258c-4963-bdd6-d7eb22f351a5___RS_HL 9946.JPG
#                     d75ed8c7-610e-4abd-8a3a-a08993a92df3___GH_HL Leaf 323.2.JPG
#                     d84eb3b6-3321-4034-9bcc-d2cddb8a3467___RS_HL 0053.JPG
#                     d88e3218-6639-430b-a74b-6b7353b1b964___GH_HL Leaf 377.JPG
#                     d984f436-1fde-4221-9563-82f55a42b545___RS_HL 0217.JPG
#                     da3e3bf7-80da-479b-99f1-f86f18d8a264___GH_HL Leaf 511.1.JPG
#                     de56bf63-8f55-426a-a2a1-8a8a635ad5a0___RS_HL 9747.JPG
#                     debe033e-a878-46dc-8336-8bc25811df35___GH_HL Leaf 303.JPG
#                     df35d1fb-978c-4aeb-9d6f-e7da242c81b8___RS_HL 0515.JPG
#                     e020155a-f93a-496c-adc6-1810b4cea333___GH_HL Leaf 206.JPG
#                     e12936ac-7354-434c-b857-1e742e383dd5___RS_HL 9878.JPG
#                     e1aeb847-e87b-4f24-aca7-c6e06b6c07ca___GH_HL Leaf 185.JPG
#                     e2085395-2d3c-4698-ad7f-da9fdc73c4d1___GH_HL Leaf 254.JPG
#                     e2991a66-412d-4841-8dc0-524e38338a82___GH_HL Leaf 517.1.JPG
#                     e2bd556e-fe0f-4a97-819c-83dbc4a61ac5___GH_HL Leaf 429.JPG
#                     e2f520b1-ac21-445b-9a3f-cb6e506e3044___RS_HL 0381.JPG
#                     e357a876-daff-428c-828f-7f1b6e998175___RS_HL 0593.JPG
#                     e59d735a-0312-46e4-943a-2262ea2cd502___RS_HL 0428.JPG
#                     e623a5a9-edc8-4c81-ada4-68b3ebadfc7e___RS_HL 0082.JPG
#                     e66387bd-ae03-4ba8-af0c-533900daa36c___RS_HL 0289.JPG
#                     e6fdaad9-b536-46c3-a819-faf414cfbf47___GH_HL Leaf 500.2.JPG
#                     e786ac89-29fe-47e3-b49e-b9a9ee7edd9d___GH_HL Leaf 342.1.JPG
#                     e7ab090d-f32a-46c2-b3a2-919d76437fee___RS_HL 0207.JPG
#                     e969c25d-8cc4-4730-a65b-330cd4d38c9a___GH_HL Leaf 427.JPG
#                     e9f45c75-db52-4a85-ab72-0b9adf1f047b___GH_HL Leaf 480.1.JPG
#                     ea815fb4-7c6f-4088-94d0-59609294c65e___RS_HL 9785.JPG
#                     eab401a8-c014-4a63-98d4-b6144cfc7bc9___GH_HL Leaf 289.JPG
#                     eb4c170f-af95-48f6-a5da-7e23da76a8e7___GH_HL Leaf 247.1.JPG
#                     ec1bfc74-550b-4478-95c0-d60c1379957a___RS_HL 9879.JPG
#                     ec59e000-1ee0-4998-a68f-abbfa6f6d009___RS_HL 0226.JPG
#                     ed6f80a2-c69f-4d33-ad3d-ef2186aa1db1___RS_HL 9669.JPG
#                     ee83a3b8-911e-455e-be06-20583bfb6b74___GH_HL Leaf 451.JPG
#                     efe02473-2f94-4ff5-a478-cc9d8ebd79da___RS_HL 9671.JPG
#                     f0037c61-001d-4b1f-b794-5b5ab49d50d5___RS_HL 0527.JPG
#                     f163df8f-6510-4520-82ee-779d2679af33___GH_HL Leaf 422.2.JPG
#                     f2b8486a-71c9-43e2-8eb6-36476905dd40___GH_HL Leaf 346.JPG
#                     f4d64977-50b0-4967-87cf-95f282f287d4___RS_HL 0554.JPG
#                     f65afb75-30bc-4d44-adbd-d262ebe07ad5___GH_HL Leaf 222.1.JPG
#                     f6a5a9a3-f9a6-4fad-83c3-2ce3e8618b52___RS_HL 0169.JPG
#                     f81def4f-22a7-4036-bfab-51b245f4a2ab___RS_HL 0055.JPG
#                     fc849a80-15fd-486d-bedc-0239e1278660___RS_HL 0494.JPG
#                     fd061d12-644d-4ac5-a0b5-2e88469e506b___GH_HL Leaf 414.JPG
#                     fdbbea63-18e0-401f-8269-64ba005ab53f___RS_HL 0213.JPG
#                     fe0b76dc-4263-4cda-8840-310ebe72a432___GH_HL Leaf 490.JPG
#                     fe8f8808-2631-491e-a46b-bd2a1a4958e7___GH_HL Leaf 213.1.JPG
#                     ff8b36d5-feaf-4d2d-8126-18670a312657___RS_HL 0229.JPG
#     test/
#         test/
#             AppleCedarRust1.JPG
#             AppleCedarRust2.JPG
#             AppleCedarRust3.JPG
#             AppleCedarRust4.JPG
#             AppleScab1.JPG
#             AppleScab2.JPG
#             AppleScab3.JPG
#             CornCommonRust1.JPG
#             CornCommonRust2.JPG
#             CornCommonRust3.JPG
#             PotatoEarlyBlight1.JPG
#             PotatoEarlyBlight2.JPG
#             PotatoEarlyBlight3.JPG
#             PotatoEarlyBlight4.JPG
#             PotatoEarlyBlight5.JPG
#             PotatoHealthy1.JPG
#             PotatoHealthy2.JPG
#             TomatoEarlyBlight1.JPG
#             TomatoEarlyBlight2.JPG
#             TomatoEarlyBlight3.JPG
#             TomatoEarlyBlight4.JPG
#             TomatoEarlyBlight5.JPG
#             TomatoEarlyBlight6.JPG
#             TomatoHealthy1.JPG
#             TomatoHealthy2.JPG
#             TomatoHealthy3.JPG
#             TomatoHealthy4.JPG
#             TomatoYellowCurlVirus1.JPG
#             TomatoYellowCurlVirus2.JPG
#             TomatoYellowCurlVirus3.JPG
#             TomatoYellowCurlVirus4.JPG
#             TomatoYellowCurlVirus5.JPG
#             TomatoYellowCurlVirus6.JPG

# %%
import matplotlib.pyplot as plt
import os
import random
from PIL import Image

def display_random_images(dataset_root_path, num_images=5):
    """
    Displays a specified number of random images from the dataset.

    Args:
        dataset_root_path (str): The root path of the dataset (e.g., the 'PlantVillage' folder).
        num_images (int): The number of random images to display.
    """
    all_image_paths = []
    for root, _, files in os.walk(dataset_root_path):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
                all_image_paths.append(os.path.join(root, file))

    if not all_image_paths:
        print("No images found in the specified dataset path.")
        return

    selected_images = random.sample(all_image_paths, min(num_images, len(all_image_paths)))

    plt.figure(figsize=(15, 5 * len(selected_images)))
    for i, img_path in enumerate(selected_images):
        try:
            img = Image.open(img_path)
            # Extract label from the parent directory name
            label = os.path.basename(os.path.dirname(img_path))
            if label == 'train' or label == 'val' or label == 'test': # Handle cases where direct parent is train/val/test
                label = os.path.basename(os.path.dirname(os.path.dirname(img_path)))

            plt.subplot(len(selected_images), 3, i*3 + 1) # Adjust subplot layout for better display
            plt.imshow(img)
            plt.title(f"Label: {label}\nFile: {os.path.basename(img_path)}", fontsize=8)
            plt.axis('off')
        except Exception as e:
            print(f"Could not load image {img_path}: {e}")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Now, let's try displaying a few random images from the training subset of the dataset. The `dataset_path` variable points to the root of the downloaded dataset.

# %%
import os # Ensure os is imported for path operations

# The dataset_path is '/root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2'
# The 'train' folder is nested inside 'New Plant Diseases Dataset(Augmented)' which is nested again.
train_data_root_path = os.path.join(dataset_path, 'New Plant Diseases Dataset(Augmented)', 'New Plant Diseases Dataset(Augmented)')
train_data_path = os.path.join(train_data_root_path, 'train')

print(f"Attempting to access: {train_data_path}")

if os.path.exists(train_data_path):
    print(f"Path '{train_data_path}' exists. Proceeding to display images.")
    display_random_images(train_data_path, num_images=6)
else:
    print(f"Error: Path '{train_data_path}' does not exist. Please check the dataset structure.")
    # Further debugging for the user if the path still doesn't exist
    print(f"Contents of dataset_path ({dataset_path}): {os.listdir(dataset_path) if os.path.exists(dataset_path) else 'Path does not exist.'}")
    parent_dir_one = os.path.join(dataset_path, 'New Plant Diseases Dataset(Augmented)')
    if os.path.exists(parent_dir_one):
        print(f"Contents of first 'New Plant Diseases Dataset(Augmented)' folder: {os.listdir(parent_dir_one)}")
        parent_dir_two = os.path.join(parent_dir_one, 'New Plant Diseases Dataset(Augmented)')
        if os.path.exists(parent_dir_two):
            print(f"Contents of second 'New Plant Diseases Dataset(Augmented)' folder: {os.listdir(parent_dir_two)}")
            # Check for 'train' directory directly here
            train_check = os.path.join(parent_dir_two, 'train')
            if os.path.exists(train_check):
                print(f"'train' directory found at: {train_check}")
# Out:
# Attempting to access: /home/madhavrimal/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train
# Path '/home/madhavrimal/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train' exists. Proceeding to display images.

# %% [markdown]
# ## Data Exploration and Feature Extraction
#
# Let's begin by understanding the dataset structure and distribution of classes.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths for train, validation, and test datasets
# Re-using train_data_root_path from the previous cell for consistency
valid_data_path = os.path.join(train_data_root_path, 'valid')
test_data_path = os.path.join(dataset_path, 'test', 'test') # The top-level 'test' folder contains another 'test' folder

print(f"Train Data Path: {train_data_path}")
print(f"Validation Data Path: {valid_data_path}")
print(f"Test Data Path: {test_data_path}")
# Out:
# Train Data Path: /home/madhavrimal/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train
# Validation Data Path: /home/madhavrimal/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid
# Test Data Path: /home/madhavrimal/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2/test/test

# %%
def count_images_and_classes(data_path):
    """
    Counts the number of images and classes in a given dataset path.
    Assumes the structure: data_path/class_name/image.jpg
    """
    class_counts = {}
    for class_name in os.listdir(data_path):
        class_path = os.path.join(data_path, class_name)
        if os.path.isdir(class_path):
            num_images = len([f for f in os.listdir(class_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
            class_counts[class_name] = num_images
    return class_counts

# Get class distribution for the training set
train_class_counts = count_images_and_classes(train_data_path)

# Convert to DataFrame for easier plotting and analysis
train_df = pd.DataFrame(train_class_counts.items(), columns=['Class', 'Count'])

display(train_df.head())
# Out:
#                       Class  Count
# 0        Apple___Apple_scab   2016
# 1         Apple___Black_rot   1987
# 2  Apple___Cedar_apple_rust   1760
# 3           Apple___healthy   2008
# 4       Blueberry___healthy   1816

# %% [markdown]
# ### Training Data Class Distribution

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x='Class', y='Count', data=train_df, palette='viridis')
plt.xticks(rotation=90)
plt.title('Distribution of Plant Disease Classes in Training Set')
plt.xlabel('Plant Disease Class')
plt.ylabel('Number of Images')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_16761/2694254974.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Class', y='Count', data=train_df, palette='viridis')

# %% [markdown]
# ### Validation Data Class Distribution

# %%
# Get class distribution for the validation set
valid_class_counts = count_images_and_classes(valid_data_path)
valid_df = pd.DataFrame(valid_class_counts.items(), columns=['Class', 'Count'])

display(valid_df.head())

plt.figure(figsize=(15, 8))
sns.barplot(x='Class', y='Count', data=valid_df, palette='viridis')
plt.xticks(rotation=90)
plt.title('Distribution of Plant Disease Classes in Validation Set')
plt.xlabel('Plant Disease Class')
plt.ylabel('Number of Images')
plt.tight_layout()
plt.show()
# Out:
#                       Class  Count
# 0        Apple___Apple_scab    504
# 1         Apple___Black_rot    497
# 2  Apple___Cedar_apple_rust    440
# 3           Apple___healthy    502
# 4       Blueberry___healthy    454
# /tmp/ipykernel_16761/3150188479.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Class', y='Count', data=valid_df, palette='viridis')

# %% [markdown]
# ### Test Data Class Distribution

# %%
# Get class distribution for the test set
# The test set images are typically not in class-labeled subdirectories
# Instead, they are directly in the test_data_path
test_image_files = [f for f in os.listdir(test_data_path) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]
total_test_images = len(test_image_files)

# Create a DataFrame to represent the total count
test_df = pd.DataFrame([{'Class': 'Total Test Images (Unlabeled)', 'Count': total_test_images}])

print(f"Total number of test images found: {total_test_images}")
display(test_df) # Display the DataFrame with total count

# Plotting (will show a single bar for total test images)
plt.figure(figsize=(8, 6)) # Adjust figure size for a single bar
sns.barplot(x='Class', y='Count', data=test_df, palette='viridis')
plt.xticks(rotation=45)
plt.title('Total Images in Test Set')
plt.xlabel('') # No specific classes to label
plt.ylabel('Number of Images')
plt.tight_layout()
plt.show()
# Out:
# Total number of test images found: 33
#                            Class  Count
# 0  Total Test Images (Unlabeled)     33
# /tmp/ipykernel_16761/1196997193.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Class', y='Count', data=test_df, palette='viridis')

# %% [markdown]
# ## Data Preparation for Model Training
#
# To prepare the images for training a deep learning model, we'll use `ImageDataGenerator` from TensorFlow/Keras. This will handle:
#
# *   **Rescaling:** Normalizing pixel values to a [0, 1] range.
# *   **Image Resizing:** Resizing all images to a consistent size (e.g., 224x224 pixels).
# *   **Batching:** Grouping images into batches for efficient model training.
# *   **Data Augmentation (for training set):** Applying transformations like rotations, shifts, and flips to the training images to increase the diversity of the training data and improve model generalization.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define image dimensions and batch size
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32

# Create ImageDataGenerator for training with augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255, # Normalize pixel values to [0, 1]
    rotation_range=40, # Randomly rotate images by up to 40 degrees
    width_shift_range=0.2, # Randomly shift images horizontally
    height_shift_range=0.2, # Randomly shift images vertically
    shear_range=0.2, # Apply shearing transformations
    zoom_range=0.2, # Apply random zoom
    horizontal_flip=True, # Randomly flip images horizontally
    fill_mode='nearest' # Fill new pixels created by transformations
)

# Create ImageDataGenerator for validation and test sets (only rescaling)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

print("ImageDataGenerators initialized.")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779761509.295950   16761 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1779761509.517296   16761 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779761510.709042   16761 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ImageDataGenerators initialized.

# %% [markdown]
# Now, let's create the actual data generators using `flow_from_directory`. These generators will load images from our defined paths, apply the preprocessing steps, and serve them in batches to the model.

# %%
# Create training data generator
train_generator = train_datagen.flow_from_directory(
    train_data_path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical' # For multi-class classification
)

# Create validation data generator
validation_generator = validation_datagen.flow_from_directory(
    valid_data_path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

# Create test data generator
# For the test set, we need to handle that images are not in subdirectories by class.
# We set class_mode=None and shuffle=False to get predictions in order.
# However, to maintain consistency with `flow_from_directory` and avoid issues with target_size, we'll assume
# the user intends to classify these directly. If labels are needed later, a custom generator might be required.
# For now, let's adapt `flow_from_directory` by pointing it to the folder containing the images directly.
# This will treat each image as its own 'class' effectively for this step if it expects subfolders, or more ideally
# if the test path only contains images, it will generate them without class labels.

# A more robust approach for test data without subfolders:
# test_generator = test_datagen.flow_from_dataframe(
#     dataframe=pd.DataFrame({'filename': test_image_files}), # Assuming test_image_files is a list of filenames
#     directory=test_data_path,
#     x_col='filename',
#     y_col=None,
#     target_size=(IMG_HEIGHT, IMG_WIDTH),
#     batch_size=BATCH_SIZE,
#     class_mode=None,
#     shuffle=False
# )

# Given `test_data_path` points directly to the images, we can use `flow_from_directory` but with a caveat:
# It expects subdirectories. Since the test data doesn't have class subdirectories, we will use `flow_from_directory`
# on the parent folder of `test_data_path` and specify `classes=[os.path.basename(test_data_path)]`.
# This effectively tells it to treat all images within `test_data_path` as one 'class'.

# Determine the parent directory of test_data_path
test_parent_path = os.path.dirname(test_data_path)
test_dir_name = os.path.basename(test_data_path)

# Create test data generator for unlabeled test images
test_generator = test_datagen.flow_from_directory(
    test_parent_path, # Point to the parent directory
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode=None, # No class labels needed for prediction
    shuffle=False, # Keep file order for potential later mapping
    classes=[test_dir_name] # Specify the 'class' as the folder name containing the images
)

print("Data generators created.")
print(f"Number of training samples: {train_generator.samples}")
print(f"Number of validation samples: {validation_generator.samples}")
print(f"Number of test samples: {test_generator.samples}")
print(f"Number of classes: {train_generator.num_classes}")
print(f"Class labels: {train_generator.class_indices}")
# Out:
# Found 70295 images belonging to 38 classes.
# Found 17572 images belonging to 38 classes.
# Found 33 images belonging to 1 classes.
# Data generators created.
# Number of training samples: 70295
# Number of validation samples: 17572
# Number of test samples: 33
# Number of classes: 38
# Class labels: {'Apple___Apple_scab': 0, 'Apple___Black_rot': 1, 'Apple___Cedar_apple_rust': 2, 'Apple___healthy': 3, 'Blueberry___healthy': 4, 'Cherry_(including_sour)___Powdery_mildew': 5, 'Cherry_(including_sour)___healthy': 6, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 7, 'Corn_(maize)___Common_rust_': 8, 'Corn_(maize)___Northern_Leaf_Blight': 9, 'Corn_(maize)___healthy': 10, 'Grape___Black_rot': 11, 'Grape___Esca_(Black_Measles)': 12, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 13, 'Grape___healthy': 14, 'Orange___Haunglongbing_(Citrus_greening)': 15, 'Peach___Bacterial_spot': 16, 'Peach___healthy': 17, 'Pepper,_bell___Bacterial_spot': 18, 'Pepper,_bell___healthy': 19, 'Potato___Early_blight': 20, 'Potato___Late_blight': 21, 'Potato___healthy': 22, 'Raspberry___healthy': 23, 'Soybean___healthy': 24, 'Squash___Powdery_mildew': 25, 'Strawberry___Leaf_scorch': 26, 'Strawberry___healthy': 27, 'Tomato___Bacterial_spot': 28, 'Tomato___Early_blight': 29, 'Tomato___Late_blight': 30, 'Tomato___Leaf_Mold': 31, 'Tomato___Septoria_leaf_spot': 32, 'Tomato___Spider_mites Two-spotted_spider_mite': 33, 'Tomato___Target_Spot': 34, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 35, 'Tomato___Tomato_mosaic_virus': 36, 'Tomato___healthy': 37}

# %% [markdown]
# ## Define and Compile the CNN Model
#
# Now, let's define the architecture of our Convolutional Neural Network (CNN). We'll start with a relatively simple sequential model that includes convolutional layers for feature extraction and dense layers for classification. We'll use `tf.keras.applications.MobileNetV2` as a base for transfer learning to leverage pre-trained weights on a large dataset, which usually leads to better performance on image tasks with limited data. This will be adapted for our specific number of classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D

# Get the number of classes from the training generator
num_classes = train_generator.num_classes

# Load the MobileNetV2 model with pre-trained weights (ImageNet) excluding the top classification layer
base_model = MobileNetV2(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), include_top=False, weights='imagenet')

# Freeze the base model layers so they are not updated during initial training
base_model.trainable = False

# Create a new model on top of the pre-trained base
model = Sequential([
    base_model,
    GlobalAveragePooling2D(), # Reduces spatial dimensions to a single vector
    Dense(128, activation='relu'), # A dense layer for further feature processing
    Dropout(0.5), # Dropout for regularization
    Dense(num_classes, activation='softmax') # Output layer for classification
])

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=0.0001), # Use a small learning rate for fine-tuning/transfer learning
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("CNN model defined and compiled using MobileNetV2 for transfer learning.")
model.summary()
# Out:
# I0000 00:00:1779761514.759169   16761 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4168 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 6GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# CNN model defined and compiled using MobileNetV2 for transfer learning.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 38)             │         4,902 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,426,854 (9.26 MB)
#  Trainable params: 168,870 (659.65 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ## Train the Model
#
# Now we will train the defined CNN model using the `train_generator` and `validation_generator`. We'll also use `EarlyStopping` to stop training when the validation loss stops improving, and `ModelCheckpoint` to save the best model weights during training.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Define callbacks
early_stopping = EarlyStopping(
    monitor='val_loss', # Monitor validation loss
    patience=5, # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True # Restore model weights from the epoch with the best value of the monitored quantity
)

model_checkpoint = ModelCheckpoint(
    'best_plant_disease_model.keras', # Filepath to save the model
    monitor='val_loss', # Monitor validation loss
    save_best_only=True, # Save only the best model
    mode='min', # The 'best' model has the minimum validation loss
    verbose=1 # Log when model is saved
)

epochs = 20 # You can adjust the number of epochs

history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    callbacks=[early_stopping, model_checkpoint]
)
# BUG : Requires batch training for the model
print("Model training complete.")
# Out:
# Epoch 1/20
# I0000 00:00:1779761516.458471   16761 generator_dataset_op.cc:213] Memory patch applied: M_TRIM_THRESHOLD=128 kb was set.
# I0000 00:00:1779761518.352251   16914 service.cc:153] XLA service 0x7f43c0034bb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779761518.352269   16914 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 3050 6GB Laptop GPU, Compute Capability 8.6 (Driver: 13.2.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.22.0)
# I0000 00:00:1779761518.404644   16914 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1779761518.898075   16914 cuda_dnn.cc:461] Loaded cuDNN version 92200
# I0000 00:00:1779761518.939153   16914 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_8090__.123
# I0000 00:00:1779761521.095961   16914 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# I0000 00:00:1779761521.453212   16987 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_1_6', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1779761521.587812   16985 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_1_6', 132 bytes spill stores, 132 bytes spill loads
#
# I0000 00:00:1779761521.860439   16914 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
#    1/2197 ━━━━━━━━━━━━━━━━━━━━ 7:02:28 12s/step - accuracy: 0.0312 - loss: 4.2868
# I0000 00:00:1779761527.952588   16914 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  173/2197 ━━━━━━━━━━━━━━━━━━━━ 6:08 182ms/step - accuracy: 0.0579 - loss: 3.7520
# I0000 00:00:1779761559.943430   16906 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_8090__.123
# I0000 00:00:1779761564.883167   16906 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.3216 - loss: 2.5470
# I0000 00:00:1779761957.555607   16908 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# Epoch 1: val_loss improved from None to 0.73447, saving model to best_plant_disease_model.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 467s 208ms/step - accuracy: 0.4918 - loss: 1.8411 - val_accuracy: 0.8111 - val_loss: 0.7345
# Epoch 2/20
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7060 - loss: 0.9872
# Epoch 2: val_loss improved from 0.73447 to 0.49258, saving model to best_plant_disease_model.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 369s 168ms/step - accuracy: 0.7286 - loss: 0.9061 - val_accuracy: 0.8625 - val_loss: 0.4926
# Epoch 3/20
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7753 - loss: 0.7372
# Epoch 3: val_loss improved from 0.49258 to 0.39924, saving model to best_plant_disease_model.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 388s 177ms/step - accuracy: 0.7862 - loss: 0.7001 - val_accuracy: 0.8833 - val_loss: 0.3992
# Epoch 4/20
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8109 - loss: 0.6206
# Epoch 4: val_loss improved from 0.39924 to 0.35779, saving model to best_plant_disease_model.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 419s 191ms/step - accuracy: 0.8167 - loss: 0.5981 - val_accuracy: 0.8896 - val_loss: 0.3578
# Epoch 5/20
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8297 - loss: 0.5445
# Epoch 5: val_loss improved from 0.35779 to 0.31904, saving model to best_plant_disease_model.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 419s 191ms/step - accuracy: 0.8335 - loss: 0.5365 - val_accuracy: 0.9031 - val_loss: 0.3190
# Epoch 6/20
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8439 - loss: 0.5031
# Epoch 6: val_loss improved from 0.31904 to 0.30076, saving model to best_plant_disease_model.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 417s 190ms/step - accuracy: 0.8452 - loss: 0.4934 - val_accuracy: 0.9051 - val_loss: 0.3008
# Epoch 7/20
# 1337/2197 ━━━━━━━━━━━━━━━━━━━━ 2:27 172ms/step - accuracy: 0.8536 - loss: 0.4631
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 20
#      10 model_checkpoint = ModelCheckpoint(
#      11     'best_plant_disease_model.keras', # Filepath to save the model
#      12     monitor='val_loss', # Monitor validation loss
#    (...)
#      15     verbose=1 # Log when model is saved
#      16 )
#      18 epochs = 20 # You can adjust the number of epochs
# ---> 20 history = model.fit(
#      21     train_generator,
#      22     epochs=epochs,
#      23     validation_data=validation_generator,
#      24     callbacks=[early_stopping, model_checkpoint]
#      25 )
#      27 print("Model training complete.")
#
# File ~/workspace/Projects/Krishi_chakshu/.venv/lib64/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/workspace/Projects/Krishi_chakshu/.venv/lib64/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File ~/workspace/Projects/Krishi_chakshu/.venv/lib64/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File ~/workspace/Projects/Krishi_chakshu/.venv/lib64/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/workspace/Projects/Krishi_chakshu/.venv/lib64/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/workspace/Projects/Krishi_chakshu/.venv/lib64/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/workspace/Projects/Krishi_chakshu/.venv/lib64/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/workspace/Projects/Krishi_chakshu/.venv/lib64/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/workspace/Projects/Krishi_chakshu/.venv/lib64/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/workspace/Projects/Krishi_chakshu/.venv/lib64/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/workspace/Projects/Krishi_chakshu/.venv/lib64/python3.10/site-packages/tensorflow/python/eager/context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)
#    1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~/workspace/Projects/Krishi_chakshu/.venv/lib64/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Recommended Reading and Documentation
#
# To better understand the current and upcoming steps in building and training this plant disease detection system, here are some key topics and resources:
#
# ### 1. Convolutional Neural Networks (CNNs)
#
# *   **Concept:** CNNs are the backbone of most modern image classification models. They are designed to automatically learn spatial hierarchies of features from image data.
# *   **Recommended Reading:**
#     *   [**Deep Learning Book - Chapter 9: Convolutional Networks**](https://www.deeplearningbook.org/contents/convnets.html): A comprehensive theoretical overview.
#     *   [**Stanford CS231n: Convolutional Neural Networks for Visual Recognition**](https://cs231n.github.io/convolutional-networks/): Excellent course notes with intuitive explanations and visualizations.
#
# ### 2. Transfer Learning
#
# *   **Concept:** Transfer learning involves using a pre-trained model (like MobileNetV2 in our case) that was trained on a very large dataset (e.g., ImageNet) and adapting it to a new, but similar, task. This is highly effective when you have limited data for your specific problem.
# *   **Recommended Reading:**
#     *   [**Keras Guide: Transfer learning & fine-tuning**](https://keras.io/guides/transfer_learning/): A practical guide on how to implement transfer learning in Keras.
#     *   [**Towards Data Science: A Step-by-Step Guide to Transfer Learning for Computer Vision**](https://towardsdatascience.com/a-step-by-step-guide-to-transfer-learning-for-computer-vision-with-code-5f110757a31b): An article with code examples.
#
# ### 3. Image Data Augmentation
#
# *   **Concept:** Data augmentation is a technique to increase the diversity of your training data by applying random transformations (like rotation, shifting, zooming, flipping) to your images. This helps prevent overfitting and improves the model's generalization.
# *   **Recommended Reading:**
#     *   [**Keras Documentation: ImageDataGenerator**](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator): Official documentation for the tool we are using.
#     *   [**Analytics Vidhya: Image Augmentation for Deep Learning using Keras**](https://www.analyticsvidhya.com/blog/2019/07/build-image-classification-game-deep-learning-keras/): A blog post explaining augmentation techniques.
#
# ### 4. Model Evaluation Metrics
#
# *   **Concept:** After training, we need to evaluate how well our model performs. Key metrics include accuracy, precision, recall, F1-score, and confusion matrices.
# *   **Recommended Reading:**
#     *   [**Scikit-learn User Guide: Classification metrics**](https://scikit-learn.org/stable/modules/model_evaluation.html#classification-metrics): Overview of various classification metrics.
#     *   [**Confusion Matrix Explained**](https://www.v7labs.com/blog/confusion-matrix): An easy-to-understand explanation of confusion matrices.
#
# These resources should provide a solid foundation for understanding each step of the process. Feel free to ask if you have specific questions about any of these topics!

# %%
# This cell is just a trigger to execute the previous modified cell.
# The actual logic is in cell 7ca61d35.
print("Executing cell 7ca61d35 to analyze test data...")
